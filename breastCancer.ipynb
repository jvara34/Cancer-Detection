# %%
#CNN 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pathlib

# ===== Paths & setup =====
DATA_DIR = "/home/jovyan/.cache/kagglehub/datasets/obulisainaren/multi-cancer/versions/3/Multi Cancer/Multi Cancer/Breast Cancer"   
IMG_SIZE = (256, 256)  
BATCH_SIZE = 8   
SEED = 1337

data_dir = pathlib.Path(DATA_DIR)

# ===== Dataset split: train (70%), val (15%), test (15%) =====
train_ds = keras.utils.image_dataset_from_directory(
    data_dir, labels="inferred", label_mode="int",
    image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    validation_split=0.15, subset="training", seed=SEED
)

valtest_ds = keras.utils.image_dataset_from_directory(
    data_dir, labels="inferred", label_mode="int",
    image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    validation_split=0.15, subset="validation", seed=SEED
)

# Split val/test
val_batches = int(0.5 * tf.data.experimental.cardinality(valtest_ds).numpy())
val_ds = valtest_ds.take(val_batches)
test_ds = valtest_ds.skip(val_batches)

class_names = train_ds.class_names
num_classes = len(class_names)
print("Classes:", class_names)

# ===== Prefetch for performance =====
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.shuffle(1000).prefetch(AUTOTUNE)
val_ds   = val_ds.prefetch(AUTOTUNE)
test_ds  = test_ds.prefetch(AUTOTUNE)

# ===== Data augmentation =====
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.05),
    layers.RandomZoom(0.1),
])

# ===== Baseline CNN =====
def build_baseline_cnn(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)

    x = data_augmentation(inputs)
    x = layers.Rescaling(1./255)(x)

    # Block 1
    x = layers.Conv2D(32, 3, padding="same", activation="relu")(x)
    x = layers.MaxPooling2D()(x)

    # Block 2
    x = layers.Conv2D(64, 3, padding="same", activation="relu")(x)
    x = layers.MaxPooling2D()(x)

    # Block 3
    x = layers.Conv2D(128, 3, padding="same", activation="relu")(x)
    x = layers.MaxPooling2D()(x)

    # Dense layers
    x = layers.Flatten()(x)
    x = layers.Dense(128, activation="relu")(x)
    x = layers.Dropout(0.5)(x)

    outputs = layers.Dense(num_classes, activation="softmax")(x)

    model = keras.Model(inputs, outputs)
    return model

model = build_baseline_cnn(IMG_SIZE + (3,), num_classes)

model.compile(
    optimizer="adam",
    loss=keras.losses.SparseCategoricalCrossentropy(),
    metrics=["accuracy"]
)

model.summary()

# ===== Train =====
callbacks = [
    keras.callbacks.EarlyStopping(patience=4, restore_best_weights=True, monitor="val_accuracy"),
]

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=20,
    callbacks=callbacks
)

# ===== Evaluate on test set =====
test_loss, test_acc = model.evaluate(test_ds)
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# 2025-09-13 23:38:25.211681: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-09-13 23:38:26.465738: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Found 10000 files belonging to 2 classes.
# Using 8500 files for training.
# 2025-09-13 23:38:30.249462: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 965 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:63:00.0, compute capability: 8.6
# 2025-09-13 23:38:30.251165: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 21964 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:64:00.0, compute capability: 8.6
# Found 10000 files belonging to 2 classes.
# Using 1500 files for validation.
# Classes: ['breast_benign', 'breast_malignant']
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  sequential (Sequential)     (None, 256, 256, 3)       0
#
#  rescaling (Rescaling)       (None, 256, 256, 3)       0
#
#  conv2d (Conv2D)             (None, 256, 256, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 128, 128, 32)      0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 64)      18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 64, 64, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 32, 32, 128)       0
#  g2D)
#
#  flatten (Flatten)           (None, 131072)            0
#
#  dense (Dense)               (None, 128)               16777344
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 16870850 (64.36 MB)
# Trainable params: 16870850 (64.36 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 2025-09-13 23:38:43.545302: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 318 of 1000
# 2025-09-13 23:38:53.420829: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 629 of 1000
# 2025-09-13 23:39:03.156986: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] Shuffle buffer filled.
# 2025-09-13 23:39:04.094738: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2025-09-13 23:39:04.493543: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2025-09-13 23:39:04.511591: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x56305b7cdb10 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-09-13 23:39:04.511632: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2025-09-13 23:39:04.511645: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (1): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2025-09-13 23:39:04.520140: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-09-13 23:39:04.721439: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1063/1063 [==============================] - 52s 15ms/step - loss: 0.6847 - accuracy: 0.5946 - val_loss: 0.6646 - val_accuracy: 0.5931
# Epoch 2/20
# 1063/1063 [==============================] - 15s 9ms/step - loss: 0.6481 - accuracy: 0.6673 - val_loss: 0.6083 - val_accuracy: 0.7434
# Epoch 3/20
# 1063/1063 [==============================] - 15s 9ms/step - loss: 0.5348 - accuracy: 0.7412 - val_loss: 0.4094 - val_accuracy: 0.8178
# Epoch 4/20
# 1063/1063 [==============================] - 15s 9ms/step - loss: 0.4911 - accuracy: 0.7840 - val_loss: 0.3869 - val_accuracy: 0.8537
# Epoch 5/20
# 1063/1063 [==============================] - 15s 10ms/step - loss: 0.4375 - accuracy: 0.8145 - val_loss: 0.5747 - val_accuracy: 0.8338
# Epoch 6/20
# 1063/1063 [==============================] - 15s 10ms/step - loss: 0.3806 - accuracy: 0.8446 - val_loss: 0.2020 - val_accuracy: 0.9322
# Epoch 7/20
# 1063/1063 [==============================] - 15s 9ms/step - loss: 0.3200 - accuracy: 0.8726 - val_loss: 0.3548 - val_accuracy: 0.8271
# Epoch 8/20
# 1063/1063 [==============================] - 15s 10ms/step - loss: 0.2722 - accuracy: 0.8989 - val_loss: 0.1665 - val_accuracy: 0.9388
# Epoch 9/20
# 1063/1063 [==============================] - 15s 10ms/step - loss: 0.2434 - accuracy: 0.9071 - val_loss: 0.1802 - val_accuracy: 0.9388
# Epoch 10/20
# 1063/1063 [==============================] - 15s 9ms/step - loss: 0.2323 - accuracy: 0.9145 - val_loss: 0.3029 - val_accuracy: 0.8870
# Epoch 11/20
# 1063/1063 [==============================] - 15s 10ms/step - loss: 0.2380 - accuracy: 0.9139 - val_loss: 0.2931 - val_accuracy: 0.9189
# Epoch 12/20
# 1063/1063 [==============================] - 15s 9ms/step - loss: 0.1968 - accuracy: 0.9260 - val_loss: 0.4226 - val_accuracy: 0.8777
# 94/94 [==============================] - 4s 29ms/step - loss: 0.2102 - accuracy: 0.9144
# Test accuracy: 0.9144

# %%
# ResNet
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pathlib

# ===== Paths & setup =====
DATA_DIR = "/home/jovyan/.cache/kagglehub/datasets/obulisainaren/multi-cancer/versions/3/Multi Cancer/Multi Cancer/Breast Cancer"    
IMG_SIZE = (256, 256)  
BATCH_SIZE = 8   # adjust if OOM
SEED = 1337

data_dir = pathlib.Path(DATA_DIR)

# ===== Dataset split =====
train_ds = keras.utils.image_dataset_from_directory(
    data_dir, labels="inferred", label_mode="int",
    image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    validation_split=0.15, subset="training", seed=SEED
)

valtest_ds = keras.utils.image_dataset_from_directory(
    data_dir, labels="inferred", label_mode="int",
    image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    validation_split=0.15, subset="validation", seed=SEED
)

# Split val/test
val_batches = int(0.5 * tf.data.experimental.cardinality(valtest_ds).numpy())
val_ds = valtest_ds.take(val_batches)
test_ds = valtest_ds.skip(val_batches)

class_names = train_ds.class_names
num_classes = len(class_names)
print("Classes:", class_names)

# ===== Prefetch =====
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.shuffle(1000).prefetch(AUTOTUNE)
val_ds   = val_ds.prefetch(AUTOTUNE)
test_ds  = test_ds.prefetch(AUTOTUNE)

# ===== Data augmentation =====
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.05),
    layers.RandomZoom(0.1),
])

# ===== Residual block =====
def residual_block(x, filters, downsample=False):
    shortcut = x

    # First conv
    x = layers.Conv2D(filters, 3, padding="same", strides=(2 if downsample else 1),
                      kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    # Second conv
    x = layers.Conv2D(filters, 3, padding="same", kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)

    # Match shortcut shape if downsampling
    if downsample:
        shortcut = layers.Conv2D(filters, 1, strides=2, padding="same",
                                 kernel_initializer="he_normal")(shortcut)
        shortcut = layers.BatchNormalization()(shortcut)

    # Add skip connection
    x = layers.Add()([x, shortcut])
    x = layers.ReLU()(x)
    return x

# ===== Baseline ResNet model =====
def build_resnet(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = layers.Rescaling(1./255)(x)

    # Stem
    x = layers.Conv2D(32, 7, strides=2, padding="same", kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

    # Residual blocks
    x = residual_block(x, 32)
    x = residual_block(x, 32)
    x = residual_block(x, 64, downsample=True)
    x = residual_block(x, 64)
    x = residual_block(x, 128, downsample=True)
    x = residual_block(x, 128)

    # Classifier head
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)

    model = keras.Model(inputs, outputs)
    return model

model = build_resnet(IMG_SIZE + (3,), num_classes)

model.compile(
    optimizer="adam",
    loss=keras.losses.SparseCategoricalCrossentropy(),
    metrics=["accuracy"]
)

model.summary()

# ===== Train =====
callbacks = [
    keras.callbacks.EarlyStopping(patience=4, restore_best_weights=True, monitor="val_accuracy"),
]

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=20,
    callbacks=callbacks
)

# ===== Evaluate =====
test_loss, test_acc = model.evaluate(test_ds)
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# Found 10000 files belonging to 2 classes.
# Using 8500 files for training.
# Found 10000 files belonging to 2 classes.
# Using 1500 files for validation.
# Classes: ['breast_benign', 'breast_malignant']
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  sequential_1 (Sequential)   (None, 256, 256, 3)          0         ['input_2[0][0]']
#
#  rescaling_1 (Rescaling)     (None, 256, 256, 3)          0         ['sequential_1[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 128, 128, 32)         4736      ['rescaling_1[0][0]']
#
#  batch_normalization (Batch  (None, 128, 128, 32)         128       ['conv2d_3[0][0]']
#  Normalization)
#
#  re_lu (ReLU)                (None, 128, 128, 32)         0         ['batch_normalization[0][0]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 64, 64, 32)           0         ['re_lu[0][0]']
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 32)           9248      ['max_pooling2d_3[0][0]']
#
#  batch_normalization_1 (Bat  (None, 64, 64, 32)           128       ['conv2d_4[0][0]']
#  chNormalization)
#
#  re_lu_1 (ReLU)              (None, 64, 64, 32)           0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 32)           9248      ['re_lu_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 64, 64, 32)           128       ['conv2d_5[0][0]']
#  chNormalization)
#
#  add (Add)                   (None, 64, 64, 32)           0         ['batch_normalization_2[0][0]'
#                                                                     , 'max_pooling2d_3[0][0]']
#
#  re_lu_2 (ReLU)              (None, 64, 64, 32)           0         ['add[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 64, 64, 32)           9248      ['re_lu_2[0][0]']
#
#  batch_normalization_3 (Bat  (None, 64, 64, 32)           128       ['conv2d_6[0][0]']
#  chNormalization)
#
#  re_lu_3 (ReLU)              (None, 64, 64, 32)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_7 (Conv2D)           (None, 64, 64, 32)           9248      ['re_lu_3[0][0]']
#
#  batch_normalization_4 (Bat  (None, 64, 64, 32)           128       ['conv2d_7[0][0]']
#  chNormalization)
#
#  add_1 (Add)                 (None, 64, 64, 32)           0         ['batch_normalization_4[0][0]'
#                                                                     , 're_lu_2[0][0]']
#
#  re_lu_4 (ReLU)              (None, 64, 64, 32)           0         ['add_1[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 32, 32, 64)           18496     ['re_lu_4[0][0]']
#
#  batch_normalization_5 (Bat  (None, 32, 32, 64)           256       ['conv2d_8[0][0]']
#  chNormalization)
#
#  re_lu_5 (ReLU)              (None, 32, 32, 64)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 64)           36928     ['re_lu_5[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 32, 32, 64)           2112      ['re_lu_4[0][0]']
#
#  batch_normalization_6 (Bat  (None, 32, 32, 64)           256       ['conv2d_9[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 32, 32, 64)           256       ['conv2d_10[0][0]']
#  chNormalization)
#
#  add_2 (Add)                 (None, 32, 32, 64)           0         ['batch_normalization_6[0][0]'
#                                                                     , 'batch_normalization_7[0][0]
#                                                                     ']
#
#  re_lu_6 (ReLU)              (None, 32, 32, 64)           0         ['add_2[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 32, 32, 64)           36928     ['re_lu_6[0][0]']
#
#  batch_normalization_8 (Bat  (None, 32, 32, 64)           256       ['conv2d_11[0][0]']
#  chNormalization)
#
#  re_lu_7 (ReLU)              (None, 32, 32, 64)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_12 (Conv2D)          (None, 32, 32, 64)           36928     ['re_lu_7[0][0]']
#
#  batch_normalization_9 (Bat  (None, 32, 32, 64)           256       ['conv2d_12[0][0]']
#  chNormalization)
#
#  add_3 (Add)                 (None, 32, 32, 64)           0         ['batch_normalization_9[0][0]'
#                                                                     , 're_lu_6[0][0]']
#
#  re_lu_8 (ReLU)              (None, 32, 32, 64)           0         ['add_3[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 16, 16, 128)          73856     ['re_lu_8[0][0]']
#
#  batch_normalization_10 (Ba  (None, 16, 16, 128)          512       ['conv2d_13[0][0]']
#  tchNormalization)
#
#  re_lu_9 (ReLU)              (None, 16, 16, 128)          0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  conv2d_14 (Conv2D)          (None, 16, 16, 128)          147584    ['re_lu_9[0][0]']
#
#  conv2d_15 (Conv2D)          (None, 16, 16, 128)          8320      ['re_lu_8[0][0]']
#
#  batch_normalization_11 (Ba  (None, 16, 16, 128)          512       ['conv2d_14[0][0]']
#  tchNormalization)
#
#  batch_normalization_12 (Ba  (None, 16, 16, 128)          512       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  add_4 (Add)                 (None, 16, 16, 128)          0         ['batch_normalization_11[0][0]
#                                                                     ',
#                                                                      'batch_normalization_12[0][0]
#                                                                     ']
#
#  re_lu_10 (ReLU)             (None, 16, 16, 128)          0         ['add_4[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 16, 16, 128)          147584    ['re_lu_10[0][0]']
#
#  batch_normalization_13 (Ba  (None, 16, 16, 128)          512       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  re_lu_11 (ReLU)             (None, 16, 16, 128)          0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  conv2d_17 (Conv2D)          (None, 16, 16, 128)          147584    ['re_lu_11[0][0]']
#
#  batch_normalization_14 (Ba  (None, 16, 16, 128)          512       ['conv2d_17[0][0]']
#  tchNormalization)
#
#  add_5 (Add)                 (None, 16, 16, 128)          0         ['batch_normalization_14[0][0]
#                                                                     ',
#                                                                      're_lu_10[0][0]']
#
#  re_lu_12 (ReLU)             (None, 16, 16, 128)          0         ['add_5[0][0]']
#
#  global_average_pooling2d (  (None, 128)                  0         ['re_lu_12[0][0]']
#  GlobalAveragePooling2D)
#
#  dropout_1 (Dropout)         (None, 128)                  0         ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense_2 (Dense)             (None, 2)                    258       ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 702786 (2.68 MB)
# Trainable params: 700546 (2.67 MB)
# Non-trainable params: 2240 (8.75 KB)
# __________________________________________________________________________________________________
# Epoch 1/20
# 1063/1063 [==============================] - 41s 20ms/step - loss: 0.4085 - accuracy: 0.8359 - val_loss: 5.0046 - val_accuracy: 0.5146
# Epoch 2/20
# 1063/1063 [==============================] - 24s 18ms/step - loss: 0.2748 - accuracy: 0.8913 - val_loss: 0.5368 - val_accuracy: 0.7872
# Epoch 3/20
# 1063/1063 [==============================] - 24s 18ms/step - loss: 0.2364 - accuracy: 0.9119 - val_loss: 0.3482 - val_accuracy: 0.8790
# Epoch 4/20
# 1063/1063 [==============================] - 24s 17ms/step - loss: 0.1938 - accuracy: 0.9264 - val_loss: 0.4604 - val_accuracy: 0.8444
# Epoch 5/20
# 1063/1063 [==============================] - 24s 18ms/step - loss: 0.1691 - accuracy: 0.9368 - val_loss: 0.1909 - val_accuracy: 0.9242
# Epoch 6/20
# 1063/1063 [==============================] - 23s 17ms/step - loss: 0.1498 - accuracy: 0.9427 - val_loss: 1.6203 - val_accuracy: 0.6582
# Epoch 7/20
# 1063/1063 [==============================] - 24s 18ms/step - loss: 0.1388 - accuracy: 0.9474 - val_loss: 0.2934 - val_accuracy: 0.8803
# Epoch 8/20
# 1063/1063 [==============================] - 24s 17ms/step - loss: 0.1230 - accuracy: 0.9521 - val_loss: 0.5604 - val_accuracy: 0.7606
# Epoch 9/20
# 1063/1063 [==============================] - 24s 18ms/step - loss: 0.1068 - accuracy: 0.9592 - val_loss: 0.5081 - val_accuracy: 0.8737
# 94/94 [==============================] - 2s 9ms/step - loss: 0.2211 - accuracy: 0.9171
# Test accuracy: 0.9171

# %%
# VGGNet 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pathlib

# ===== Paths & setup =====
DATA_DIR = "/home/jovyan/.cache/kagglehub/datasets/obulisainaren/multi-cancer/versions/3/Multi Cancer/Multi Cancer/Breast Cancer"   
IMG_SIZE = (256, 256)  
BATCH_SIZE = 8        
SEED = 1337

data_dir = pathlib.Path(DATA_DIR)

# ===== Dataset split: train (70%), val (15%), test (15%) =====
train_ds = keras.utils.image_dataset_from_directory(
    data_dir, labels="inferred", label_mode="int",
    image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    validation_split=0.15, subset="training", seed=SEED
)
valtest_ds = keras.utils.image_dataset_from_directory(
    data_dir, labels="inferred", label_mode="int",
    image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    validation_split=0.15, subset="validation", seed=SEED
)

# Split val/test
val_batches = int(0.5 * tf.data.experimental.cardinality(valtest_ds).numpy())
val_ds = valtest_ds.take(val_batches)
test_ds = valtest_ds.skip(val_batches)

class_names = train_ds.class_names
num_classes = len(class_names)
print("Classes:", class_names)

# ===== Prefetch for performance =====
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.shuffle(1000).prefetch(AUTOTUNE)
val_ds   = val_ds.prefetch(AUTOTUNE)
test_ds  = test_ds.prefetch(AUTOTUNE)

# ===== Data augmentation =====
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.05),
    layers.RandomZoom(0.1),
])

# ===== VGG-style block helper =====
def vgg_block(x, filters, convs=2):
    for _ in range(convs):
        x = layers.Conv2D(filters, 3, padding="same", activation="relu",
                          kernel_initializer="he_normal")(x)
    x = layers.MaxPooling2D(pool_size=2)(x)
    return x

# ===== Baseline VGG-style model (roughly VGG11/VGG13 sized) =====
def build_vgg(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = layers.Rescaling(1./255)(x)

    # VGG-style feature extractor
    x = vgg_block(x, 32, convs=1)   # Block 1
    x = vgg_block(x, 64, convs=1)   # Block 2
    x = vgg_block(x, 128, convs=2)  # Block 3
    x = vgg_block(x, 256, convs=2)  # Block 4

    # Classifier head
    x = layers.Flatten()(x)
    x = layers.Dense(256, activation="relu")(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)

    model = keras.Model(inputs, outputs)
    return model

model = build_vgg(IMG_SIZE + (3,), num_classes)

model.compile(
    optimizer="adam",
    loss=keras.losses.SparseCategoricalCrossentropy(),
    metrics=["accuracy"]
)

model.summary()

# ===== Train =====
callbacks = [
    keras.callbacks.EarlyStopping(patience=4, restore_best_weights=True, monitor="val_accuracy"),
]

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=20,
    callbacks=callbacks
)

# ===== Evaluate =====
test_loss, test_acc = model.evaluate(test_ds)
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# Found 10000 files belonging to 2 classes.
# Using 8500 files for training.
# Found 10000 files belonging to 2 classes.
# Using 1500 files for validation.
# Classes: ['breast_benign', 'breast_malignant']
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  sequential_2 (Sequential)   (None, 256, 256, 3)       0
#
#  rescaling_2 (Rescaling)     (None, 256, 256, 3)       0
#
#  conv2d_18 (Conv2D)          (None, 256, 256, 32)      896
#
#  max_pooling2d_4 (MaxPoolin  (None, 128, 128, 32)      0
#  g2D)
#
#  conv2d_19 (Conv2D)          (None, 128, 128, 64)      18496
#
#  max_pooling2d_5 (MaxPoolin  (None, 64, 64, 64)        0
#  g2D)
#
#  conv2d_20 (Conv2D)          (None, 64, 64, 128)       73856
#
#  conv2d_21 (Conv2D)          (None, 64, 64, 128)       147584
#
#  max_pooling2d_6 (MaxPoolin  (None, 32, 32, 128)       0
#  g2D)
#
#  conv2d_22 (Conv2D)          (None, 32, 32, 256)       295168
#
#  conv2d_23 (Conv2D)          (None, 32, 32, 256)       590080
#
#  max_pooling2d_7 (MaxPoolin  (None, 16, 16, 256)       0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 65536)             0
#
#  dense_3 (Dense)             (None, 256)               16777472
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 17904066 (68.30 MB)
# Trainable params: 17904066 (68.30 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 1063/1063 [==============================] - 23s 13ms/step - loss: 0.9889 - accuracy: 0.5274 - val_loss: 0.6890 - val_accuracy: 0.5093
# Epoch 2/20
# 1063/1063 [==============================] - 18s 12ms/step - loss: 0.7174 - accuracy: 0.5195 - val_loss: 0.6934 - val_accuracy: 0.4934
# Epoch 3/20
# 1063/1063 [==============================] - 18s 12ms/step - loss: 0.6933 - accuracy: 0.4993 - val_loss: 0.6928 - val_accuracy: 0.5133
# Epoch 4/20
# 1063/1063 [==============================] - 19s 12ms/step - loss: 0.6935 - accuracy: 0.4993 - val_loss: 0.6929 - val_accuracy: 0.5120
# Epoch 5/20
# 1063/1063 [==============================] - 18s 12ms/step - loss: 0.6932 - accuracy: 0.5020 - val_loss: 0.6943 - val_accuracy: 0.4920
# Epoch 6/20
# 1063/1063 [==============================] - 18s 12ms/step - loss: 0.6934 - accuracy: 0.5045 - val_loss: 0.6935 - val_accuracy: 0.4880
# Epoch 7/20
# 1063/1063 [==============================] - 18s 13ms/step - loss: 0.6932 - accuracy: 0.5055 - val_loss: 0.6934 - val_accuracy: 0.4894
# 94/94 [==============================] - 1s 6ms/step - loss: 0.6933 - accuracy: 0.5000
# Test accuracy: 0.5000

# %%
# GoogLeNet 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pathlib

# ===== Paths & setup =====
DATA_DIR = "/home/jovyan/.cache/kagglehub/datasets/obulisainaren/multi-cancer/versions/3/Multi Cancer/Multi Cancer/Breast Cancer"
IMG_SIZE = (256, 256)  
BATCH_SIZE = 8        
SEED = 1337

data_dir = pathlib.Path(DATA_DIR)

# ===== Dataset split: train (70%), val (15%), test (15%) =====
train_ds = keras.utils.image_dataset_from_directory(
    data_dir, labels="inferred", label_mode="int",
    image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    validation_split=0.15, subset="training", seed=SEED
)
valtest_ds = keras.utils.image_dataset_from_directory(
    data_dir, labels="inferred", label_mode="int",
    image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    validation_split=0.15, subset="validation", seed=SEED
)

# Split val/test
val_batches = int(0.5 * tf.data.experimental.cardinality(valtest_ds).numpy())
val_ds = valtest_ds.take(val_batches)
test_ds = valtest_ds.skip(val_batches)

class_names = train_ds.class_names
num_classes = len(class_names)
print("Classes:", class_names)

# ===== Prefetch for performance =====
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.shuffle(1000).prefetch(AUTOTUNE)
val_ds   = val_ds.prefetch(AUTOTUNE)
test_ds  = test_ds.prefetch(AUTOTUNE)

# ===== Data augmentation =====
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.05),
    layers.RandomZoom(0.1),
])

# ===== Conv -> BN -> ReLU helper =====
def CBR(x, filters, k, s=1, p="same"):
    x = layers.Conv2D(filters, k, strides=s, padding=p,
                      use_bias=False, kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    return layers.ReLU()(x)

# ===== Inception (v1-style) block =====
def inception_block(x, f1, f3r, f3, f5r, f5, fpool):
    """
    Branches:
      - 1x1
      - 1x1 -> 3x3
      - 1x1 -> 5x5 (implemented as two 3x3 for efficiency)
      - 3x3 pool -> 1x1
    """
    b1 = CBR(x, f1, 1)

    b2 = CBR(x, f3r, 1)
    b2 = CBR(b2, f3, 3)

    b3 = CBR(x, f5r, 1)
    b3 = CBR(b3, f5, 3)
    b3 = CBR(b3, f5, 3)

    b4 = layers.MaxPooling2D(3, strides=1, padding="same")(x)
    b4 = CBR(b4, fpool, 1)

    return layers.Concatenate()([b1, b2, b3, b4])

# ===== Inception Reduction block (downsampling) =====
def inception_reduction(x, f3, f5r, f5):
    """
    Branches that reduce spatial dims:
      - 3x3 stride-2
      - 1x1 -> 3x3 -> 3x3 stride-2
      - 3x3 maxpool stride-2
    """
    b1 = CBR(x, f3, 3, s=2, p="same")

    b2 = CBR(x, f5r, 1)
    b2 = CBR(b2, f5, 3)
    b2 = CBR(b2, f5, 3, s=2)

    b3 = layers.MaxPooling2D(3, strides=2, padding="same")(x)

    return layers.Concatenate()([b1, b2, b3])

# ===== Baseline Inception-style model =====
def build_inception_baseline(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = layers.Rescaling(1./255)(x)

    # Stem
    x = CBR(x, 32, 7, s=2)                # 512 -> 256
    x = layers.MaxPooling2D(3, strides=2, padding="same")(x)  # 256 -> 128
    x = CBR(x, 64, 3)

    # Inception stacks
    x = inception_block(x, f1=32, f3r=32, f3=48, f5r=8,  f5=16, fpool=16)
    x = inception_block(x, f1=48, f3r=40, f3=64, f5r=12, f5=24, fpool=24)

    # Reduction
    x = inception_reduction(x, f3=96, f5r=32, f5=48)  # 128 -> 64

    # More Inception blocks
    x = inception_block(x, f1=64, f3r=48, f3=96, f5r=16, f5=32, fpool=32)
    x = inception_block(x, f1=80, f3r=56, f3=112, f5r=20, f5=40, fpool=40)

    # Second reduction
    x = inception_reduction(x, f3=128, f5r=48, f5=80)  # 64 -> 32

    # Head
    x = inception_block(x, f1=96, f3r=64, f3=128, f5r=24, f5=48, fpool=48)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)

    return keras.Model(inputs, outputs)

model = build_inception_baseline(IMG_SIZE + (3,), num_classes)
model.compile(optimizer="adam",
              loss=keras.losses.SparseCategoricalCrossentropy(),
              metrics=["accuracy"])

model.summary()

# ===== Train =====
callbacks = [
    keras.callbacks.EarlyStopping(patience=4, restore_best_weights=True, monitor="val_accuracy"),
]

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=20,
    callbacks=callbacks
)

# ===== Evaluate =====
test_loss, test_acc = model.evaluate(test_ds)
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# Found 10000 files belonging to 2 classes.
# Using 8500 files for training.
# Found 10000 files belonging to 2 classes.
# Using 1500 files for validation.
# Classes: ['breast_benign', 'breast_malignant']
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  sequential_3 (Sequential)   (None, 256, 256, 3)          0         ['input_4[0][0]']
#
#  rescaling_3 (Rescaling)     (None, 256, 256, 3)          0         ['sequential_3[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 128, 128, 32)         4704      ['rescaling_3[0][0]']
#
#  batch_normalization_15 (Ba  (None, 128, 128, 32)         128       ['conv2d_24[0][0]']
#  tchNormalization)
#
#  re_lu_13 (ReLU)             (None, 128, 128, 32)         0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  max_pooling2d_8 (MaxPoolin  (None, 64, 64, 32)           0         ['re_lu_13[0][0]']
#  g2D)
#
#  conv2d_25 (Conv2D)          (None, 64, 64, 64)           18432     ['max_pooling2d_8[0][0]']
#
#  batch_normalization_16 (Ba  (None, 64, 64, 64)           256       ['conv2d_25[0][0]']
#  tchNormalization)
#
#  re_lu_14 (ReLU)             (None, 64, 64, 64)           0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_29 (Conv2D)          (None, 64, 64, 8)            512       ['re_lu_14[0][0]']
#
#  batch_normalization_20 (Ba  (None, 64, 64, 8)            32        ['conv2d_29[0][0]']
#  tchNormalization)
#
#  re_lu_18 (ReLU)             (None, 64, 64, 8)            0         ['batch_normalization_20[0][0]
#                                                                     ']
#
#  conv2d_27 (Conv2D)          (None, 64, 64, 32)           2048      ['re_lu_14[0][0]']
#
#  conv2d_30 (Conv2D)          (None, 64, 64, 16)           1152      ['re_lu_18[0][0]']
#
#  batch_normalization_18 (Ba  (None, 64, 64, 32)           128       ['conv2d_27[0][0]']
#  tchNormalization)
#
#  batch_normalization_21 (Ba  (None, 64, 64, 16)           64        ['conv2d_30[0][0]']
#  tchNormalization)
#
#  re_lu_16 (ReLU)             (None, 64, 64, 32)           0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  re_lu_19 (ReLU)             (None, 64, 64, 16)           0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  max_pooling2d_9 (MaxPoolin  (None, 64, 64, 64)           0         ['re_lu_14[0][0]']
#  g2D)
#
#  conv2d_26 (Conv2D)          (None, 64, 64, 32)           2048      ['re_lu_14[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 64, 64, 48)           13824     ['re_lu_16[0][0]']
#
#  conv2d_31 (Conv2D)          (None, 64, 64, 16)           2304      ['re_lu_19[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 64, 64, 16)           1024      ['max_pooling2d_9[0][0]']
#
#  batch_normalization_17 (Ba  (None, 64, 64, 32)           128       ['conv2d_26[0][0]']
#  tchNormalization)
#
#  batch_normalization_19 (Ba  (None, 64, 64, 48)           192       ['conv2d_28[0][0]']
#  tchNormalization)
#
#  batch_normalization_22 (Ba  (None, 64, 64, 16)           64        ['conv2d_31[0][0]']
#  tchNormalization)
#
#  batch_normalization_23 (Ba  (None, 64, 64, 16)           64        ['conv2d_32[0][0]']
#  tchNormalization)
#
#  re_lu_15 (ReLU)             (None, 64, 64, 32)           0         ['batch_normalization_17[0][0]
#                                                                     ']
#
#  re_lu_17 (ReLU)             (None, 64, 64, 48)           0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  re_lu_20 (ReLU)             (None, 64, 64, 16)           0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  re_lu_21 (ReLU)             (None, 64, 64, 16)           0         ['batch_normalization_23[0][0]
#                                                                     ']
#
#  concatenate (Concatenate)   (None, 64, 64, 112)          0         ['re_lu_15[0][0]',
#                                                                      're_lu_17[0][0]',
#                                                                      're_lu_20[0][0]',
#                                                                      're_lu_21[0][0]']
#
#  conv2d_36 (Conv2D)          (None, 64, 64, 12)           1344      ['concatenate[0][0]']
#
#  batch_normalization_27 (Ba  (None, 64, 64, 12)           48        ['conv2d_36[0][0]']
#  tchNormalization)
#
#  re_lu_25 (ReLU)             (None, 64, 64, 12)           0         ['batch_normalization_27[0][0]
#                                                                     ']
#
#  conv2d_34 (Conv2D)          (None, 64, 64, 40)           4480      ['concatenate[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 64, 64, 24)           2592      ['re_lu_25[0][0]']
#
#  batch_normalization_25 (Ba  (None, 64, 64, 40)           160       ['conv2d_34[0][0]']
#  tchNormalization)
#
#  batch_normalization_28 (Ba  (None, 64, 64, 24)           96        ['conv2d_37[0][0]']
#  tchNormalization)
#
#  re_lu_23 (ReLU)             (None, 64, 64, 40)           0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  re_lu_26 (ReLU)             (None, 64, 64, 24)           0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  max_pooling2d_10 (MaxPooli  (None, 64, 64, 112)          0         ['concatenate[0][0]']
#  ng2D)
#
#  conv2d_33 (Conv2D)          (None, 64, 64, 48)           5376      ['concatenate[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 64, 64, 64)           23040     ['re_lu_23[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 64, 64, 24)           5184      ['re_lu_26[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 64, 64, 24)           2688      ['max_pooling2d_10[0][0]']
#
#  batch_normalization_24 (Ba  (None, 64, 64, 48)           192       ['conv2d_33[0][0]']
#  tchNormalization)
#
#  batch_normalization_26 (Ba  (None, 64, 64, 64)           256       ['conv2d_35[0][0]']
#  tchNormalization)
#
#  batch_normalization_29 (Ba  (None, 64, 64, 24)           96        ['conv2d_38[0][0]']
#  tchNormalization)
#
#  batch_normalization_30 (Ba  (None, 64, 64, 24)           96        ['conv2d_39[0][0]']
#  tchNormalization)
#
#  re_lu_22 (ReLU)             (None, 64, 64, 48)           0         ['batch_normalization_24[0][0]
#                                                                     ']
#
#  re_lu_24 (ReLU)             (None, 64, 64, 64)           0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  re_lu_27 (ReLU)             (None, 64, 64, 24)           0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  re_lu_28 (ReLU)             (None, 64, 64, 24)           0         ['batch_normalization_30[0][0]
#                                                                     ']
#
#  concatenate_1 (Concatenate  (None, 64, 64, 160)          0         ['re_lu_22[0][0]',
#  )                                                                   're_lu_24[0][0]',
#                                                                      're_lu_27[0][0]',
#                                                                      're_lu_28[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 64, 64, 32)           5120      ['concatenate_1[0][0]']
#
#  batch_normalization_32 (Ba  (None, 64, 64, 32)           128       ['conv2d_41[0][0]']
#  tchNormalization)
#
#  re_lu_30 (ReLU)             (None, 64, 64, 32)           0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 64, 64, 48)           13824     ['re_lu_30[0][0]']
#
#  batch_normalization_33 (Ba  (None, 64, 64, 48)           192       ['conv2d_42[0][0]']
#  tchNormalization)
#
#  re_lu_31 (ReLU)             (None, 64, 64, 48)           0         ['batch_normalization_33[0][0]
#                                                                     ']
#
#  conv2d_40 (Conv2D)          (None, 32, 32, 96)           138240    ['concatenate_1[0][0]']
#
#  conv2d_43 (Conv2D)          (None, 32, 32, 48)           20736     ['re_lu_31[0][0]']
#
#  batch_normalization_31 (Ba  (None, 32, 32, 96)           384       ['conv2d_40[0][0]']
#  tchNormalization)
#
#  batch_normalization_34 (Ba  (None, 32, 32, 48)           192       ['conv2d_43[0][0]']
#  tchNormalization)
#
#  re_lu_29 (ReLU)             (None, 32, 32, 96)           0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  re_lu_32 (ReLU)             (None, 32, 32, 48)           0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  max_pooling2d_11 (MaxPooli  (None, 32, 32, 160)          0         ['concatenate_1[0][0]']
#  ng2D)
#
#  concatenate_2 (Concatenate  (None, 32, 32, 304)          0         ['re_lu_29[0][0]',
#  )                                                                   're_lu_32[0][0]',
#                                                                      'max_pooling2d_11[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 32, 32, 16)           4864      ['concatenate_2[0][0]']
#
#  batch_normalization_38 (Ba  (None, 32, 32, 16)           64        ['conv2d_47[0][0]']
#  tchNormalization)
#
#  re_lu_36 (ReLU)             (None, 32, 32, 16)           0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  conv2d_45 (Conv2D)          (None, 32, 32, 48)           14592     ['concatenate_2[0][0]']
#
#  conv2d_48 (Conv2D)          (None, 32, 32, 32)           4608      ['re_lu_36[0][0]']
#
#  batch_normalization_36 (Ba  (None, 32, 32, 48)           192       ['conv2d_45[0][0]']
#  tchNormalization)
#
#  batch_normalization_39 (Ba  (None, 32, 32, 32)           128       ['conv2d_48[0][0]']
#  tchNormalization)
#
#  re_lu_34 (ReLU)             (None, 32, 32, 48)           0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  re_lu_37 (ReLU)             (None, 32, 32, 32)           0         ['batch_normalization_39[0][0]
#                                                                     ']
#
#  max_pooling2d_12 (MaxPooli  (None, 32, 32, 304)          0         ['concatenate_2[0][0]']
#  ng2D)
#
#  conv2d_44 (Conv2D)          (None, 32, 32, 64)           19456     ['concatenate_2[0][0]']
#
#  conv2d_46 (Conv2D)          (None, 32, 32, 96)           41472     ['re_lu_34[0][0]']
#
#  conv2d_49 (Conv2D)          (None, 32, 32, 32)           9216      ['re_lu_37[0][0]']
#
#  conv2d_50 (Conv2D)          (None, 32, 32, 32)           9728      ['max_pooling2d_12[0][0]']
#
#  batch_normalization_35 (Ba  (None, 32, 32, 64)           256       ['conv2d_44[0][0]']
#  tchNormalization)
#
#  batch_normalization_37 (Ba  (None, 32, 32, 96)           384       ['conv2d_46[0][0]']
#  tchNormalization)
#
#  batch_normalization_40 (Ba  (None, 32, 32, 32)           128       ['conv2d_49[0][0]']
#  tchNormalization)
#
#  batch_normalization_41 (Ba  (None, 32, 32, 32)           128       ['conv2d_50[0][0]']
#  tchNormalization)
#
#  re_lu_33 (ReLU)             (None, 32, 32, 64)           0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  re_lu_35 (ReLU)             (None, 32, 32, 96)           0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  re_lu_38 (ReLU)             (None, 32, 32, 32)           0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  re_lu_39 (ReLU)             (None, 32, 32, 32)           0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  concatenate_3 (Concatenate  (None, 32, 32, 224)          0         ['re_lu_33[0][0]',
#  )                                                                   're_lu_35[0][0]',
#                                                                      're_lu_38[0][0]',
#                                                                      're_lu_39[0][0]']
#
#  conv2d_54 (Conv2D)          (None, 32, 32, 20)           4480      ['concatenate_3[0][0]']
#
#  batch_normalization_45 (Ba  (None, 32, 32, 20)           80        ['conv2d_54[0][0]']
#  tchNormalization)
#
#  re_lu_43 (ReLU)             (None, 32, 32, 20)           0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  conv2d_52 (Conv2D)          (None, 32, 32, 56)           12544     ['concatenate_3[0][0]']
#
#  conv2d_55 (Conv2D)          (None, 32, 32, 40)           7200      ['re_lu_43[0][0]']
#
#  batch_normalization_43 (Ba  (None, 32, 32, 56)           224       ['conv2d_52[0][0]']
#  tchNormalization)
#
#  batch_normalization_46 (Ba  (None, 32, 32, 40)           160       ['conv2d_55[0][0]']
#  tchNormalization)
#
#  re_lu_41 (ReLU)             (None, 32, 32, 56)           0         ['batch_normalization_43[0][0]
#                                                                     ']
#
#  re_lu_44 (ReLU)             (None, 32, 32, 40)           0         ['batch_normalization_46[0][0]
#                                                                     ']
#
#  max_pooling2d_13 (MaxPooli  (None, 32, 32, 224)          0         ['concatenate_3[0][0]']
#  ng2D)
#
#  conv2d_51 (Conv2D)          (None, 32, 32, 80)           17920     ['concatenate_3[0][0]']
#
#  conv2d_53 (Conv2D)          (None, 32, 32, 112)          56448     ['re_lu_41[0][0]']
#
#  conv2d_56 (Conv2D)          (None, 32, 32, 40)           14400     ['re_lu_44[0][0]']
#
#  conv2d_57 (Conv2D)          (None, 32, 32, 40)           8960      ['max_pooling2d_13[0][0]']
#
#  batch_normalization_42 (Ba  (None, 32, 32, 80)           320       ['conv2d_51[0][0]']
#  tchNormalization)
#
#  batch_normalization_44 (Ba  (None, 32, 32, 112)          448       ['conv2d_53[0][0]']
#  tchNormalization)
#
#  batch_normalization_47 (Ba  (None, 32, 32, 40)           160       ['conv2d_56[0][0]']
#  tchNormalization)
#
#  batch_normalization_48 (Ba  (None, 32, 32, 40)           160       ['conv2d_57[0][0]']
#  tchNormalization)
#
#  re_lu_40 (ReLU)             (None, 32, 32, 80)           0         ['batch_normalization_42[0][0]
#                                                                     ']
#
#  re_lu_42 (ReLU)             (None, 32, 32, 112)          0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  re_lu_45 (ReLU)             (None, 32, 32, 40)           0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  re_lu_46 (ReLU)             (None, 32, 32, 40)           0         ['batch_normalization_48[0][0]
#                                                                     ']
#
#  concatenate_4 (Concatenate  (None, 32, 32, 272)          0         ['re_lu_40[0][0]',
#  )                                                                   're_lu_42[0][0]',
#                                                                      're_lu_45[0][0]',
#                                                                      're_lu_46[0][0]']
#
#  conv2d_59 (Conv2D)          (None, 32, 32, 48)           13056     ['concatenate_4[0][0]']
#
#  batch_normalization_50 (Ba  (None, 32, 32, 48)           192       ['conv2d_59[0][0]']
#  tchNormalization)
#
#  re_lu_48 (ReLU)             (None, 32, 32, 48)           0         ['batch_normalization_50[0][0]
#                                                                     ']
#
#  conv2d_60 (Conv2D)          (None, 32, 32, 80)           34560     ['re_lu_48[0][0]']
#
#  batch_normalization_51 (Ba  (None, 32, 32, 80)           320       ['conv2d_60[0][0]']
#  tchNormalization)
#
#  re_lu_49 (ReLU)             (None, 32, 32, 80)           0         ['batch_normalization_51[0][0]
#                                                                     ']
#
#  conv2d_58 (Conv2D)          (None, 16, 16, 128)          313344    ['concatenate_4[0][0]']
#
#  conv2d_61 (Conv2D)          (None, 16, 16, 80)           57600     ['re_lu_49[0][0]']
#
#  batch_normalization_49 (Ba  (None, 16, 16, 128)          512       ['conv2d_58[0][0]']
#  tchNormalization)
#
#  batch_normalization_52 (Ba  (None, 16, 16, 80)           320       ['conv2d_61[0][0]']
#  tchNormalization)
#
#  re_lu_47 (ReLU)             (None, 16, 16, 128)          0         ['batch_normalization_49[0][0]
#                                                                     ']
#
#  re_lu_50 (ReLU)             (None, 16, 16, 80)           0         ['batch_normalization_52[0][0]
#                                                                     ']
#
#  max_pooling2d_14 (MaxPooli  (None, 16, 16, 272)          0         ['concatenate_4[0][0]']
#  ng2D)
#
#  concatenate_5 (Concatenate  (None, 16, 16, 480)          0         ['re_lu_47[0][0]',
#  )                                                                   're_lu_50[0][0]',
#                                                                      'max_pooling2d_14[0][0]']
#
#  conv2d_65 (Conv2D)          (None, 16, 16, 24)           11520     ['concatenate_5[0][0]']
#
#  batch_normalization_56 (Ba  (None, 16, 16, 24)           96        ['conv2d_65[0][0]']
#  tchNormalization)
#
#  re_lu_54 (ReLU)             (None, 16, 16, 24)           0         ['batch_normalization_56[0][0]
#                                                                     ']
#
#  conv2d_63 (Conv2D)          (None, 16, 16, 64)           30720     ['concatenate_5[0][0]']
#
#  conv2d_66 (Conv2D)          (None, 16, 16, 48)           10368     ['re_lu_54[0][0]']
#
#  batch_normalization_54 (Ba  (None, 16, 16, 64)           256       ['conv2d_63[0][0]']
#  tchNormalization)
#
#  batch_normalization_57 (Ba  (None, 16, 16, 48)           192       ['conv2d_66[0][0]']
#  tchNormalization)
#
#  re_lu_52 (ReLU)             (None, 16, 16, 64)           0         ['batch_normalization_54[0][0]
#                                                                     ']
#
#  re_lu_55 (ReLU)             (None, 16, 16, 48)           0         ['batch_normalization_57[0][0]
#                                                                     ']
#
#  max_pooling2d_15 (MaxPooli  (None, 16, 16, 480)          0         ['concatenate_5[0][0]']
#  ng2D)
#
#  conv2d_62 (Conv2D)          (None, 16, 16, 96)           46080     ['concatenate_5[0][0]']
#
#  conv2d_64 (Conv2D)          (None, 16, 16, 128)          73728     ['re_lu_52[0][0]']
#
#  conv2d_67 (Conv2D)          (None, 16, 16, 48)           20736     ['re_lu_55[0][0]']
#
#  conv2d_68 (Conv2D)          (None, 16, 16, 48)           23040     ['max_pooling2d_15[0][0]']
#
#  batch_normalization_53 (Ba  (None, 16, 16, 96)           384       ['conv2d_62[0][0]']
#  tchNormalization)
#
#  batch_normalization_55 (Ba  (None, 16, 16, 128)          512       ['conv2d_64[0][0]']
#  tchNormalization)
#
#  batch_normalization_58 (Ba  (None, 16, 16, 48)           192       ['conv2d_67[0][0]']
#  tchNormalization)
#
#  batch_normalization_59 (Ba  (None, 16, 16, 48)           192       ['conv2d_68[0][0]']
#  tchNormalization)
#
#  re_lu_51 (ReLU)             (None, 16, 16, 96)           0         ['batch_normalization_53[0][0]
#                                                                     ']
#
#  re_lu_53 (ReLU)             (None, 16, 16, 128)          0         ['batch_normalization_55[0][0]
#                                                                     ']
#
#  re_lu_56 (ReLU)             (None, 16, 16, 48)           0         ['batch_normalization_58[0][0]
#                                                                     ']
#
#  re_lu_57 (ReLU)             (None, 16, 16, 48)           0         ['batch_normalization_59[0][0]
#                                                                     ']
#
#  concatenate_6 (Concatenate  (None, 16, 16, 320)          0         ['re_lu_51[0][0]',
#  )                                                                   're_lu_53[0][0]',
#                                                                      're_lu_56[0][0]',
#                                                                      're_lu_57[0][0]']
#
#  global_average_pooling2d_1  (None, 320)                  0         ['concatenate_6[0][0]']
#   (GlobalAveragePooling2D)
#
#  dropout_3 (Dropout)         (None, 320)                  0         ['global_average_pooling2d_1[0
#                                                                     ][0]']
#
#  dense_5 (Dense)             (None, 2)                    642       ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 1138850 (4.34 MB)
# Trainable params: 1134402 (4.33 MB)
# Non-trainable params: 4448 (17.38 KB)
# __________________________________________________________________________________________________
# Epoch 1/20
# 2025-09-14 00:25:48.555975: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.17GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-09-14 00:25:58.200240: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 345.08MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2025-09-14 00:25:58.200326: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.00GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
#   91/1063 [=>............................] - ETA: 35s - loss: 0.4926 - accuracy: 0.7898
# 2025-09-14 00:26:13.092950: W tensorflow/tsl/framework/bfc_allocator.cc:296] Allocator (GPU_0_bfc) ran out of memory trying to allocate 621.61MiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 1063/1063 [==============================] - 89s 43ms/step - loss: 0.3621 - accuracy: 0.8499 - val_loss: 0.6584 - val_accuracy: 0.8152
# Epoch 2/20
# 1063/1063 [==============================] - 44s 37ms/step - loss: 0.2609 - accuracy: 0.8966 - val_loss: 0.2354 - val_accuracy: 0.9082
# Epoch 3/20
# 1063/1063 [==============================] - 45s 37ms/step - loss: 0.2124 - accuracy: 0.9159 - val_loss: 0.1339 - val_accuracy: 0.9455
# Epoch 4/20
# 1063/1063 [==============================] - 44s 37ms/step - loss: 0.1906 - accuracy: 0.9276 - val_loss: 2.1304 - val_accuracy: 0.6024
# Epoch 5/20
# 1063/1063 [==============================] - 45s 38ms/step - loss: 0.1664 - accuracy: 0.9386 - val_loss: 0.6458 - val_accuracy: 0.7646
# Epoch 6/20
# 1063/1063 [==============================] - 45s 37ms/step - loss: 0.1339 - accuracy: 0.9505 - val_loss: 7.5750 - val_accuracy: 0.5678
# Epoch 7/20
# 1063/1063 [==============================] - 44s 37ms/step - loss: 0.1188 - accuracy: 0.9566 - val_loss: 0.1007 - val_accuracy: 0.9721
# Epoch 8/20
# 1063/1063 [==============================] - 45s 37ms/step - loss: 0.1102 - accuracy: 0.9614 - val_loss: 9.8178 - val_accuracy: 0.5652
# Epoch 9/20
# 1063/1063 [==============================] - 44s 37ms/step - loss: 0.0962 - accuracy: 0.9642 - val_loss: 0.8646 - val_accuracy: 0.9149
# Epoch 10/20
# 1063/1063 [==============================] - 44s 37ms/step - loss: 0.0905 - accuracy: 0.9655 - val_loss: 1.9411 - val_accuracy: 0.7447
# Epoch 11/20
# 1063/1063 [==============================] - 44s 37ms/step - loss: 0.0919 - accuracy: 0.9667 - val_loss: 50.8889 - val_accuracy: 0.5146
# 94/94 [==============================] - 3s 18ms/step - loss: 0.1199 - accuracy: 0.9679
# Test accuracy: 0.9679

# %%
# EfficientNet 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pathlib

# =========================
# Paths & Dataset
# =========================
DATA_DIR = "/home/jovyan/.cache/kagglehub/datasets/obulisainaren/multi-cancer/versions/3/Multi Cancer/Multi Cancer/Breast Cancer"
IMG_SIZE = (256, 256)                # smaller than 512 to save memory
BATCH_SIZE = 8
SEED = 1337
data_dir = pathlib.Path(DATA_DIR)

train_ds = keras.utils.image_dataset_from_directory(
    data_dir, labels="inferred", label_mode="int",
    image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    validation_split=0.15, subset="training", seed=SEED
)
valtest_ds = keras.utils.image_dataset_from_directory(
    data_dir, labels="inferred", label_mode="int",
    image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    validation_split=0.15, subset="validation", seed=SEED
)

val_batches = int(0.5 * tf.data.experimental.cardinality(valtest_ds).numpy())
val_ds = valtest_ds.take(val_batches)
test_ds = valtest_ds.skip(val_batches)

class_names = train_ds.class_names
num_classes = len(class_names)
print("Classes:", class_names)

AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.shuffle(1000).prefetch(AUTOTUNE)
val_ds   = val_ds.prefetch(AUTOTUNE)
test_ds  = test_ds.prefetch(AUTOTUNE)

# =========================
# Building Blocks
# =========================
def SE(x, se_ratio=0.25):
    """Squeeze-and-Excitation."""
    filters = x.shape[-1]
    se = layers.GlobalAveragePooling2D(keepdims=True)(x)
    se = layers.Conv2D(int(filters * se_ratio), 1, activation="swish")(se)
    se = layers.Conv2D(filters, 1, activation="sigmoid")(se)
    return layers.Multiply()([x, se])

def MBConv(x, out_ch, expand=4, kernel=3, stride=1, se_ratio=0.25, drop_rate=0.0):
    """Minimal EfficientNet-style MBConv block (no fused variant)."""
    in_ch = x.shape[-1]
    residual = x

    # Expansion
    mid_ch = int(in_ch * expand)
    if expand != 1:
        x = layers.Conv2D(mid_ch, 1, padding="same", use_bias=False,
                          kernel_initializer="he_normal")(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation("swish")(x)

    # Depthwise
    x = layers.DepthwiseConv2D(kernel, strides=stride, padding="same",
                               use_bias=False, kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("swish")(x)

    # SE
    if se_ratio and se_ratio > 0:
        x = SE(x, se_ratio=se_ratio)

    # Projection
    x = layers.Conv2D(out_ch, 1, padding="same", use_bias=False,
                      kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)

    # Skip connection (if shape matches)
    if stride == 1 and in_ch == out_ch:
        if drop_rate and drop_rate > 0:
            x = layers.Dropout(drop_rate)(x)
        x = layers.Add()([x, residual])
    return x

def round_filters(filters, width_mult=1.0):
    return max(8, int(filters * width_mult))

def round_repeats(repeats, depth_mult=1.0):
    import math
    return max(1, int(math.ceil(repeats * depth_mult)))

# =========================
# Model (EfficientNet-like)
# =========================
def build_efficientnet_like(input_shape, num_classes, width_mult=1.0, depth_mult=1.0, drop_rate=0.2):
    inputs = keras.Input(shape=input_shape)

    # Data augmentation + basic rescale
    x = layers.RandomFlip("horizontal")(inputs)
    x = layers.RandomRotation(0.05)(x)
    x = layers.RandomZoom(0.1)(x)
    x = layers.Rescaling(1./255)(x)

    # Stem
    stem_ch = round_filters(32, width_mult)
    x = layers.Conv2D(stem_ch, 3, strides=2, padding="same", use_bias=False,
                      kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("swish")(x)

    # Stages: (out_channels, repeats, kernel, stride, expand)
    cfgs = [
        # out, r, k, s, t
        (16,  1, 3, 1, 1),   # MBConv1
        (24,  2, 3, 2, 4),   # MBConv6-ish (expand=4 to keep it light)
        (40,  2, 5, 2, 4),
        (80,  3, 3, 2, 4),
        (112, 3, 5, 1, 4),
        (192, 4, 5, 2, 4),
        (320, 1, 3, 1, 4),
    ]

    block_idx = 0
    total_blocks = sum(round_repeats(r, depth_mult) for (_, r, _, _, _) in cfgs)

    for out_ch, repeats, k, s, t in cfgs:
        out_ch = round_filters(out_ch, width_mult)
        reps = round_repeats(repeats, depth_mult)

        for i in range(reps):
            stride = s if i == 0 else 1
            # simple linear drop schedule
            b_drop = drop_rate * float(block_idx) / max(1, total_blocks - 1)
            x = MBConv(x, out_ch=out_ch, expand=t, kernel=k, stride=stride,
                       se_ratio=0.25, drop_rate=b_drop)
            block_idx += 1

    # Head
    head_ch = round_filters(1280, width_mult)
    x = layers.Conv2D(head_ch, 1, use_bias=False, kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("swish")(x)

    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(drop_rate)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)

    return keras.Model(inputs, outputs)

# Build the model (roughly around B0 scale)
model = build_efficientnet_like(IMG_SIZE + (3,), num_classes,
                                width_mult=1.0, depth_mult=1.0, drop_rate=0.2)

model.compile(
    optimizer=keras.optimizers.Adam(3e-4),
    loss=keras.losses.SparseCategoricalCrossentropy(),
    metrics=["accuracy"]
)

model.summary()

# =========================
# Train & Evaluate
# =========================
callbacks = [
    keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True, monitor="val_accuracy"),
    keras.callbacks.ReduceLROnPlateau(patience=2, factor=0.5, min_lr=1e-6)
]

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=30,
    callbacks=callbacks
)

test_loss, test_acc = model.evaluate(test_ds)
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# Found 10000 files belonging to 2 classes.
# Using 8500 files for training.
# Found 10000 files belonging to 2 classes.
# Using 1500 files for validation.
# Classes: ['breast_benign', 'breast_malignant']
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_5 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  random_flip_4 (RandomFlip)  (None, 256, 256, 3)          0         ['input_5[0][0]']
#
#  random_rotation_4 (RandomR  (None, 256, 256, 3)          0         ['random_flip_4[0][0]']
#  otation)
#
#  random_zoom_4 (RandomZoom)  (None, 256, 256, 3)          0         ['random_rotation_4[0][0]']
#
#  rescaling_4 (Rescaling)     (None, 256, 256, 3)          0         ['random_zoom_4[0][0]']
#
#  conv2d_69 (Conv2D)          (None, 128, 128, 32)         864       ['rescaling_4[0][0]']
#
#  batch_normalization_60 (Ba  (None, 128, 128, 32)         128       ['conv2d_69[0][0]']
#  tchNormalization)
#
#  activation (Activation)     (None, 128, 128, 32)         0         ['batch_normalization_60[0][0]
#                                                                     ']
#
#  depthwise_conv2d (Depthwis  (None, 128, 128, 32)         288       ['activation[0][0]']
#  eConv2D)
#
#  batch_normalization_61 (Ba  (None, 128, 128, 32)         128       ['depthwise_conv2d[0][0]']
#  tchNormalization)
#
#  activation_1 (Activation)   (None, 128, 128, 32)         0         ['batch_normalization_61[0][0]
#                                                                     ']
#
#  global_average_pooling2d_2  (None, 1, 1, 32)             0         ['activation_1[0][0]']
#   (GlobalAveragePooling2D)
#
#  conv2d_70 (Conv2D)          (None, 1, 1, 8)              264       ['global_average_pooling2d_2[0
#                                                                     ][0]']
#
#  conv2d_71 (Conv2D)          (None, 1, 1, 32)             288       ['conv2d_70[0][0]']
#
#  multiply (Multiply)         (None, 128, 128, 32)         0         ['activation_1[0][0]',
#                                                                      'conv2d_71[0][0]']
#
#  conv2d_72 (Conv2D)          (None, 128, 128, 16)         512       ['multiply[0][0]']
#
#  batch_normalization_62 (Ba  (None, 128, 128, 16)         64        ['conv2d_72[0][0]']
#  tchNormalization)
#
#  conv2d_73 (Conv2D)          (None, 128, 128, 64)         1024      ['batch_normalization_62[0][0]
#                                                                     ']
#
#  batch_normalization_63 (Ba  (None, 128, 128, 64)         256       ['conv2d_73[0][0]']
#  tchNormalization)
#
#  activation_2 (Activation)   (None, 128, 128, 64)         0         ['batch_normalization_63[0][0]
#                                                                     ']
#
#  depthwise_conv2d_1 (Depthw  (None, 64, 64, 64)           576       ['activation_2[0][0]']
#  iseConv2D)
#
#  batch_normalization_64 (Ba  (None, 64, 64, 64)           256       ['depthwise_conv2d_1[0][0]']
#  tchNormalization)
#
#  activation_3 (Activation)   (None, 64, 64, 64)           0         ['batch_normalization_64[0][0]
#                                                                     ']
#
#  global_average_pooling2d_3  (None, 1, 1, 64)             0         ['activation_3[0][0]']
#   (GlobalAveragePooling2D)
#
#  conv2d_74 (Conv2D)          (None, 1, 1, 16)             1040      ['global_average_pooling2d_3[0
#                                                                     ][0]']
#
#  conv2d_75 (Conv2D)          (None, 1, 1, 64)             1088      ['conv2d_74[0][0]']
#
#  multiply_1 (Multiply)       (None, 64, 64, 64)           0         ['activation_3[0][0]',
#                                                                      'conv2d_75[0][0]']
#
#  conv2d_76 (Conv2D)          (None, 64, 64, 24)           1536      ['multiply_1[0][0]']
#
#  batch_normalization_65 (Ba  (None, 64, 64, 24)           96        ['conv2d_76[0][0]']
#  tchNormalization)
#
#  conv2d_77 (Conv2D)          (None, 64, 64, 96)           2304      ['batch_normalization_65[0][0]
#                                                                     ']
#
#  batch_normalization_66 (Ba  (None, 64, 64, 96)           384       ['conv2d_77[0][0]']
#  tchNormalization)
#
#  activation_4 (Activation)   (None, 64, 64, 96)           0         ['batch_normalization_66[0][0]
#                                                                     ']
#
#  depthwise_conv2d_2 (Depthw  (None, 64, 64, 96)           864       ['activation_4[0][0]']
#  iseConv2D)
#
#  batch_normalization_67 (Ba  (None, 64, 64, 96)           384       ['depthwise_conv2d_2[0][0]']
#  tchNormalization)
#
#  activation_5 (Activation)   (None, 64, 64, 96)           0         ['batch_normalization_67[0][0]
#                                                                     ']
#
#  global_average_pooling2d_4  (None, 1, 1, 96)             0         ['activation_5[0][0]']
#   (GlobalAveragePooling2D)
#
#  conv2d_78 (Conv2D)          (None, 1, 1, 24)             2328      ['global_average_pooling2d_4[0
#                                                                     ][0]']
#
#  conv2d_79 (Conv2D)          (None, 1, 1, 96)             2400      ['conv2d_78[0][0]']
#
#  multiply_2 (Multiply)       (None, 64, 64, 96)           0         ['activation_5[0][0]',
#                                                                      'conv2d_79[0][0]']
#
#  conv2d_80 (Conv2D)          (None, 64, 64, 24)           2304      ['multiply_2[0][0]']
#
#  batch_normalization_68 (Ba  (None, 64, 64, 24)           96        ['conv2d_80[0][0]']
#  tchNormalization)
#
#  dropout_4 (Dropout)         (None, 64, 64, 24)           0         ['batch_normalization_68[0][0]
#                                                                     ']
#
#  add_6 (Add)                 (None, 64, 64, 24)           0         ['dropout_4[0][0]',
#                                                                      'batch_normalization_65[0][0]
#                                                                     ']
#
#  conv2d_81 (Conv2D)          (None, 64, 64, 96)           2304      ['add_6[0][0]']
#
#  batch_normalization_69 (Ba  (None, 64, 64, 96)           384       ['conv2d_81[0][0]']
#  tchNormalization)
#
#  activation_6 (Activation)   (None, 64, 64, 96)           0         ['batch_normalization_69[0][0]
#                                                                     ']
#
#  depthwise_conv2d_3 (Depthw  (None, 32, 32, 96)           2400      ['activation_6[0][0]']
#  iseConv2D)
#
#  batch_normalization_70 (Ba  (None, 32, 32, 96)           384       ['depthwise_conv2d_3[0][0]']
#  tchNormalization)
#
#  activation_7 (Activation)   (None, 32, 32, 96)           0         ['batch_normalization_70[0][0]
#                                                                     ']
#
#  global_average_pooling2d_5  (None, 1, 1, 96)             0         ['activation_7[0][0]']
#   (GlobalAveragePooling2D)
#
#  conv2d_82 (Conv2D)          (None, 1, 1, 24)             2328      ['global_average_pooling2d_5[0
#                                                                     ][0]']
#
#  conv2d_83 (Conv2D)          (None, 1, 1, 96)             2400      ['conv2d_82[0][0]']
#
#  multiply_3 (Multiply)       (None, 32, 32, 96)           0         ['activation_7[0][0]',
#                                                                      'conv2d_83[0][0]']
#
#  conv2d_84 (Conv2D)          (None, 32, 32, 40)           3840      ['multiply_3[0][0]']
#
#  batch_normalization_71 (Ba  (None, 32, 32, 40)           160       ['conv2d_84[0][0]']
#  tchNormalization)
#
#  conv2d_85 (Conv2D)          (None, 32, 32, 160)          6400      ['batch_normalization_71[0][0]
#                                                                     ']
#
#  batch_normalization_72 (Ba  (None, 32, 32, 160)          640       ['conv2d_85[0][0]']
#  tchNormalization)
#
#  activation_8 (Activation)   (None, 32, 32, 160)          0         ['batch_normalization_72[0][0]
#                                                                     ']
#
#  depthwise_conv2d_4 (Depthw  (None, 32, 32, 160)          4000      ['activation_8[0][0]']
#  iseConv2D)
#
#  batch_normalization_73 (Ba  (None, 32, 32, 160)          640       ['depthwise_conv2d_4[0][0]']
#  tchNormalization)
#
#  activation_9 (Activation)   (None, 32, 32, 160)          0         ['batch_normalization_73[0][0]
#                                                                     ']
#
#  global_average_pooling2d_6  (None, 1, 1, 160)            0         ['activation_9[0][0]']
#   (GlobalAveragePooling2D)
#
#  conv2d_86 (Conv2D)          (None, 1, 1, 40)             6440      ['global_average_pooling2d_6[0
#                                                                     ][0]']
#
#  conv2d_87 (Conv2D)          (None, 1, 1, 160)            6560      ['conv2d_86[0][0]']
#
#  multiply_4 (Multiply)       (None, 32, 32, 160)          0         ['activation_9[0][0]',
#                                                                      'conv2d_87[0][0]']
#
#  conv2d_88 (Conv2D)          (None, 32, 32, 40)           6400      ['multiply_4[0][0]']
#
#  batch_normalization_74 (Ba  (None, 32, 32, 40)           160       ['conv2d_88[0][0]']
#  tchNormalization)
#
#  dropout_5 (Dropout)         (None, 32, 32, 40)           0         ['batch_normalization_74[0][0]
#                                                                     ']
#
#  add_7 (Add)                 (None, 32, 32, 40)           0         ['dropout_5[0][0]',
#                                                                      'batch_normalization_71[0][0]
#                                                                     ']
#
#  conv2d_89 (Conv2D)          (None, 32, 32, 160)          6400      ['add_7[0][0]']
#
#  batch_normalization_75 (Ba  (None, 32, 32, 160)          640       ['conv2d_89[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 32, 32, 160)          0         ['batch_normalization_75[0][0]
#                                                                     ']
#
#  depthwise_conv2d_5 (Depthw  (None, 16, 16, 160)          1440      ['activation_10[0][0]']
#  iseConv2D)
#
#  batch_normalization_76 (Ba  (None, 16, 16, 160)          640       ['depthwise_conv2d_5[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 16, 16, 160)          0         ['batch_normalization_76[0][0]
#                                                                     ']
#
#  global_average_pooling2d_7  (None, 1, 1, 160)            0         ['activation_11[0][0]']
#   (GlobalAveragePooling2D)
#
#  conv2d_90 (Conv2D)          (None, 1, 1, 40)             6440      ['global_average_pooling2d_7[0
#                                                                     ][0]']
#
#  conv2d_91 (Conv2D)          (None, 1, 1, 160)            6560      ['conv2d_90[0][0]']
#
#  multiply_5 (Multiply)       (None, 16, 16, 160)          0         ['activation_11[0][0]',
#                                                                      'conv2d_91[0][0]']
#
#  conv2d_92 (Conv2D)          (None, 16, 16, 80)           12800     ['multiply_5[0][0]']
#
#  batch_normalization_77 (Ba  (None, 16, 16, 80)           320       ['conv2d_92[0][0]']
#  tchNormalization)
#
#  conv2d_93 (Conv2D)          (None, 16, 16, 320)          25600     ['batch_normalization_77[0][0]
#                                                                     ']
#
#  batch_normalization_78 (Ba  (None, 16, 16, 320)          1280      ['conv2d_93[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 16, 16, 320)          0         ['batch_normalization_78[0][0]
#                                                                     ']
#
#  depthwise_conv2d_6 (Depthw  (None, 16, 16, 320)          2880      ['activation_12[0][0]']
#  iseConv2D)
#
#  batch_normalization_79 (Ba  (None, 16, 16, 320)          1280      ['depthwise_conv2d_6[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 16, 16, 320)          0         ['batch_normalization_79[0][0]
#                                                                     ']
#
#  global_average_pooling2d_8  (None, 1, 1, 320)            0         ['activation_13[0][0]']
#   (GlobalAveragePooling2D)
#
#  conv2d_94 (Conv2D)          (None, 1, 1, 80)             25680     ['global_average_pooling2d_8[0
#                                                                     ][0]']
#
#  conv2d_95 (Conv2D)          (None, 1, 1, 320)            25920     ['conv2d_94[0][0]']
#
#  multiply_6 (Multiply)       (None, 16, 16, 320)          0         ['activation_13[0][0]',
#                                                                      'conv2d_95[0][0]']
#
#  conv2d_96 (Conv2D)          (None, 16, 16, 80)           25600     ['multiply_6[0][0]']
#
#  batch_normalization_80 (Ba  (None, 16, 16, 80)           320       ['conv2d_96[0][0]']
#  tchNormalization)
#
#  dropout_6 (Dropout)         (None, 16, 16, 80)           0         ['batch_normalization_80[0][0]
#                                                                     ']
#
#  add_8 (Add)                 (None, 16, 16, 80)           0         ['dropout_6[0][0]',
#                                                                      'batch_normalization_77[0][0]
#                                                                     ']
#
#  conv2d_97 (Conv2D)          (None, 16, 16, 320)          25600     ['add_8[0][0]']
#
#  batch_normalization_81 (Ba  (None, 16, 16, 320)          1280      ['conv2d_97[0][0]']
#  tchNormalization)
#
#  activation_14 (Activation)  (None, 16, 16, 320)          0         ['batch_normalization_81[0][0]
#                                                                     ']
#
#  depthwise_conv2d_7 (Depthw  (None, 16, 16, 320)          2880      ['activation_14[0][0]']
#  iseConv2D)
#
#  batch_normalization_82 (Ba  (None, 16, 16, 320)          1280      ['depthwise_conv2d_7[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 16, 16, 320)          0         ['batch_normalization_82[0][0]
#                                                                     ']
#
#  global_average_pooling2d_9  (None, 1, 1, 320)            0         ['activation_15[0][0]']
#   (GlobalAveragePooling2D)
#
#  conv2d_98 (Conv2D)          (None, 1, 1, 80)             25680     ['global_average_pooling2d_9[0
#                                                                     ][0]']
#
#  conv2d_99 (Conv2D)          (None, 1, 1, 320)            25920     ['conv2d_98[0][0]']
#
#  multiply_7 (Multiply)       (None, 16, 16, 320)          0         ['activation_15[0][0]',
#                                                                      'conv2d_99[0][0]']
#
#  conv2d_100 (Conv2D)         (None, 16, 16, 80)           25600     ['multiply_7[0][0]']
#
#  batch_normalization_83 (Ba  (None, 16, 16, 80)           320       ['conv2d_100[0][0]']
#  tchNormalization)
#
#  dropout_7 (Dropout)         (None, 16, 16, 80)           0         ['batch_normalization_83[0][0]
#                                                                     ']
#
#  add_9 (Add)                 (None, 16, 16, 80)           0         ['dropout_7[0][0]',
#                                                                      'add_8[0][0]']
#
#  conv2d_101 (Conv2D)         (None, 16, 16, 320)          25600     ['add_9[0][0]']
#
#  batch_normalization_84 (Ba  (None, 16, 16, 320)          1280      ['conv2d_101[0][0]']
#  tchNormalization)
#
#  activation_16 (Activation)  (None, 16, 16, 320)          0         ['batch_normalization_84[0][0]
#                                                                     ']
#
#  depthwise_conv2d_8 (Depthw  (None, 16, 16, 320)          8000      ['activation_16[0][0]']
#  iseConv2D)
#
#  batch_normalization_85 (Ba  (None, 16, 16, 320)          1280      ['depthwise_conv2d_8[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 16, 16, 320)          0         ['batch_normalization_85[0][0]
#                                                                     ']
#
#  global_average_pooling2d_1  (None, 1, 1, 320)            0         ['activation_17[0][0]']
#  0 (GlobalAveragePooling2D)
#
#  conv2d_102 (Conv2D)         (None, 1, 1, 80)             25680     ['global_average_pooling2d_10[
#                                                                     0][0]']
#
#  conv2d_103 (Conv2D)         (None, 1, 1, 320)            25920     ['conv2d_102[0][0]']
#
#  multiply_8 (Multiply)       (None, 16, 16, 320)          0         ['activation_17[0][0]',
#                                                                      'conv2d_103[0][0]']
#
#  conv2d_104 (Conv2D)         (None, 16, 16, 112)          35840     ['multiply_8[0][0]']
#
#  batch_normalization_86 (Ba  (None, 16, 16, 112)          448       ['conv2d_104[0][0]']
#  tchNormalization)
#
#  conv2d_105 (Conv2D)         (None, 16, 16, 448)          50176     ['batch_normalization_86[0][0]
#                                                                     ']
#
#  batch_normalization_87 (Ba  (None, 16, 16, 448)          1792      ['conv2d_105[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 16, 16, 448)          0         ['batch_normalization_87[0][0]
#                                                                     ']
#
#  depthwise_conv2d_9 (Depthw  (None, 16, 16, 448)          11200     ['activation_18[0][0]']
#  iseConv2D)
#
#  batch_normalization_88 (Ba  (None, 16, 16, 448)          1792      ['depthwise_conv2d_9[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 16, 16, 448)          0         ['batch_normalization_88[0][0]
#                                                                     ']
#
#  global_average_pooling2d_1  (None, 1, 1, 448)            0         ['activation_19[0][0]']
#  1 (GlobalAveragePooling2D)
#
#  conv2d_106 (Conv2D)         (None, 1, 1, 112)            50288     ['global_average_pooling2d_11[
#                                                                     0][0]']
#
#  conv2d_107 (Conv2D)         (None, 1, 1, 448)            50624     ['conv2d_106[0][0]']
#
#  multiply_9 (Multiply)       (None, 16, 16, 448)          0         ['activation_19[0][0]',
#                                                                      'conv2d_107[0][0]']
#
#  conv2d_108 (Conv2D)         (None, 16, 16, 112)          50176     ['multiply_9[0][0]']
#
#  batch_normalization_89 (Ba  (None, 16, 16, 112)          448       ['conv2d_108[0][0]']
#  tchNormalization)
#
#  dropout_8 (Dropout)         (None, 16, 16, 112)          0         ['batch_normalization_89[0][0]
#                                                                     ']
#
#  add_10 (Add)                (None, 16, 16, 112)          0         ['dropout_8[0][0]',
#                                                                      'batch_normalization_86[0][0]
#                                                                     ']
#
#  conv2d_109 (Conv2D)         (None, 16, 16, 448)          50176     ['add_10[0][0]']
#
#  batch_normalization_90 (Ba  (None, 16, 16, 448)          1792      ['conv2d_109[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 16, 16, 448)          0         ['batch_normalization_90[0][0]
#                                                                     ']
#
#  depthwise_conv2d_10 (Depth  (None, 16, 16, 448)          11200     ['activation_20[0][0]']
#  wiseConv2D)
#
#  batch_normalization_91 (Ba  (None, 16, 16, 448)          1792      ['depthwise_conv2d_10[0][0]']
#  tchNormalization)
#
#  activation_21 (Activation)  (None, 16, 16, 448)          0         ['batch_normalization_91[0][0]
#                                                                     ']
#
#  global_average_pooling2d_1  (None, 1, 1, 448)            0         ['activation_21[0][0]']
#  2 (GlobalAveragePooling2D)
#
#  conv2d_110 (Conv2D)         (None, 1, 1, 112)            50288     ['global_average_pooling2d_12[
#                                                                     0][0]']
#
#  conv2d_111 (Conv2D)         (None, 1, 1, 448)            50624     ['conv2d_110[0][0]']
#
#  multiply_10 (Multiply)      (None, 16, 16, 448)          0         ['activation_21[0][0]',
#                                                                      'conv2d_111[0][0]']
#
#  conv2d_112 (Conv2D)         (None, 16, 16, 112)          50176     ['multiply_10[0][0]']
#
#  batch_normalization_92 (Ba  (None, 16, 16, 112)          448       ['conv2d_112[0][0]']
#  tchNormalization)
#
#  dropout_9 (Dropout)         (None, 16, 16, 112)          0         ['batch_normalization_92[0][0]
#                                                                     ']
#
#  add_11 (Add)                (None, 16, 16, 112)          0         ['dropout_9[0][0]',
#                                                                      'add_10[0][0]']
#
#  conv2d_113 (Conv2D)         (None, 16, 16, 448)          50176     ['add_11[0][0]']
#
#  batch_normalization_93 (Ba  (None, 16, 16, 448)          1792      ['conv2d_113[0][0]']
#  tchNormalization)
#
#  activation_22 (Activation)  (None, 16, 16, 448)          0         ['batch_normalization_93[0][0]
#                                                                     ']
#
#  depthwise_conv2d_11 (Depth  (None, 8, 8, 448)            11200     ['activation_22[0][0]']
#  wiseConv2D)
#
#  batch_normalization_94 (Ba  (None, 8, 8, 448)            1792      ['depthwise_conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_23 (Activation)  (None, 8, 8, 448)            0         ['batch_normalization_94[0][0]
#                                                                     ']
#
#  global_average_pooling2d_1  (None, 1, 1, 448)            0         ['activation_23[0][0]']
#  3 (GlobalAveragePooling2D)
#
#  conv2d_114 (Conv2D)         (None, 1, 1, 112)            50288     ['global_average_pooling2d_13[
#                                                                     0][0]']
#
#  conv2d_115 (Conv2D)         (None, 1, 1, 448)            50624     ['conv2d_114[0][0]']
#
#  multiply_11 (Multiply)      (None, 8, 8, 448)            0         ['activation_23[0][0]',
#                                                                      'conv2d_115[0][0]']
#
#  conv2d_116 (Conv2D)         (None, 8, 8, 192)            86016     ['multiply_11[0][0]']
#
#  batch_normalization_95 (Ba  (None, 8, 8, 192)            768       ['conv2d_116[0][0]']
#  tchNormalization)
#
#  conv2d_117 (Conv2D)         (None, 8, 8, 768)            147456    ['batch_normalization_95[0][0]
#                                                                     ']
#
#  batch_normalization_96 (Ba  (None, 8, 8, 768)            3072      ['conv2d_117[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 8, 8, 768)            0         ['batch_normalization_96[0][0]
#                                                                     ']
#
#  depthwise_conv2d_12 (Depth  (None, 8, 8, 768)            19200     ['activation_24[0][0]']
#  wiseConv2D)
#
#  batch_normalization_97 (Ba  (None, 8, 8, 768)            3072      ['depthwise_conv2d_12[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 8, 8, 768)            0         ['batch_normalization_97[0][0]
#                                                                     ']
#
#  global_average_pooling2d_1  (None, 1, 1, 768)            0         ['activation_25[0][0]']
#  4 (GlobalAveragePooling2D)
#
#  conv2d_118 (Conv2D)         (None, 1, 1, 192)            147648    ['global_average_pooling2d_14[
#                                                                     0][0]']
#
#  conv2d_119 (Conv2D)         (None, 1, 1, 768)            148224    ['conv2d_118[0][0]']
#
#  multiply_12 (Multiply)      (None, 8, 8, 768)            0         ['activation_25[0][0]',
# ...
#  activation_26 (Activation)  (None, 8, 8, 768)            0         ['batch_normalization_99[0][0]
#                                                                     ']
#
#  depthwise_conv2d_13 (Depth  (None, 8, 8, 768)            19200     ['activation_26[0][0]']
#  wiseConv2D)
#
#  batch_normalization_100 (B  (None, 8, 8, 768)            3072      ['depthwise_conv2d_13[0][0]']
#  atchNormalization)
#
#  activation_27 (Activation)  (None, 8, 8, 768)            0         ['batch_normalization_100[0][0
#                                                                     ]']
#
#  global_average_pooling2d_1  (None, 1, 1, 768)            0         ['activation_27[0][0]']
#  5 (GlobalAveragePooling2D)
#
#  conv2d_122 (Conv2D)         (None, 1, 1, 192)            147648    ['global_average_pooling2d_15[
#                                                                     0][0]']
#
#  conv2d_123 (Conv2D)         (None, 1, 1, 768)            148224    ['conv2d_122[0][0]']
#
#  multiply_13 (Multiply)      (None, 8, 8, 768)            0         ['activation_27[0][0]',
#                                                                      'conv2d_123[0][0]']
#
#  conv2d_124 (Conv2D)         (None, 8, 8, 192)            147456    ['multiply_13[0][0]']
#
#  batch_normalization_101 (B  (None, 8, 8, 192)            768       ['conv2d_124[0][0]']
#  atchNormalization)
#
#  dropout_11 (Dropout)        (None, 8, 8, 192)            0         ['batch_normalization_101[0][0
#                                                                     ]']
#
#  add_13 (Add)                (None, 8, 8, 192)            0         ['dropout_11[0][0]',
#                                                                      'add_12[0][0]']
#
#  conv2d_125 (Conv2D)         (None, 8, 8, 768)            147456    ['add_13[0][0]']
#
#  batch_normalization_102 (B  (None, 8, 8, 768)            3072      ['conv2d_125[0][0]']
#  atchNormalization)
#
#  activation_28 (Activation)  (None, 8, 8, 768)            0         ['batch_normalization_102[0][0
#                                                                     ]']
#
#  depthwise_conv2d_14 (Depth  (None, 8, 8, 768)            19200     ['activation_28[0][0]']
#  wiseConv2D)
#
#  batch_normalization_103 (B  (None, 8, 8, 768)            3072      ['depthwise_conv2d_14[0][0]']
#  atchNormalization)
#
#  activation_29 (Activation)  (None, 8, 8, 768)            0         ['batch_normalization_103[0][0
#                                                                     ]']
#
#  global_average_pooling2d_1  (None, 1, 1, 768)            0         ['activation_29[0][0]']
#  6 (GlobalAveragePooling2D)
#
#  conv2d_126 (Conv2D)         (None, 1, 1, 192)            147648    ['global_average_pooling2d_16[
#                                                                     0][0]']
#
#  conv2d_127 (Conv2D)         (None, 1, 1, 768)            148224    ['conv2d_126[0][0]']
#
#  multiply_14 (Multiply)      (None, 8, 8, 768)            0         ['activation_29[0][0]',
#                                                                      'conv2d_127[0][0]']
#
#  conv2d_128 (Conv2D)         (None, 8, 8, 192)            147456    ['multiply_14[0][0]']
#
#  batch_normalization_104 (B  (None, 8, 8, 192)            768       ['conv2d_128[0][0]']
#  atchNormalization)
#
#  dropout_12 (Dropout)        (None, 8, 8, 192)            0         ['batch_normalization_104[0][0
#                                                                     ]']
#
#  add_14 (Add)                (None, 8, 8, 192)            0         ['dropout_12[0][0]',
#                                                                      'add_13[0][0]']
#
#  conv2d_129 (Conv2D)         (None, 8, 8, 768)            147456    ['add_14[0][0]']
#
#  batch_normalization_105 (B  (None, 8, 8, 768)            3072      ['conv2d_129[0][0]']
#  atchNormalization)
#
#  activation_30 (Activation)  (None, 8, 8, 768)            0         ['batch_normalization_105[0][0
#                                                                     ]']
#
#  depthwise_conv2d_15 (Depth  (None, 8, 8, 768)            6912      ['activation_30[0][0]']
#  wiseConv2D)
#
#  batch_normalization_106 (B  (None, 8, 8, 768)            3072      ['depthwise_conv2d_15[0][0]']
#  atchNormalization)
#
#  activation_31 (Activation)  (None, 8, 8, 768)            0         ['batch_normalization_106[0][0
#                                                                     ]']
#
#  global_average_pooling2d_1  (None, 1, 1, 768)            0         ['activation_31[0][0]']
#  7 (GlobalAveragePooling2D)
#
#  conv2d_130 (Conv2D)         (None, 1, 1, 192)            147648    ['global_average_pooling2d_17[
#                                                                     0][0]']
#
#  conv2d_131 (Conv2D)         (None, 1, 1, 768)            148224    ['conv2d_130[0][0]']
#
#  multiply_15 (Multiply)      (None, 8, 8, 768)            0         ['activation_31[0][0]',
#                                                                      'conv2d_131[0][0]']
#
#  conv2d_132 (Conv2D)         (None, 8, 8, 320)            245760    ['multiply_15[0][0]']
#
#  batch_normalization_107 (B  (None, 8, 8, 320)            1280      ['conv2d_132[0][0]']
#  atchNormalization)
#
#  conv2d_133 (Conv2D)         (None, 8, 8, 1280)           409600    ['batch_normalization_107[0][0
#                                                                     ]']
#
#  batch_normalization_108 (B  (None, 8, 8, 1280)           5120      ['conv2d_133[0][0]']
#  atchNormalization)
#
#  activation_32 (Activation)  (None, 8, 8, 1280)           0         ['batch_normalization_108[0][0
#                                                                     ]']
#
#  global_average_pooling2d_1  (None, 1280)                 0         ['activation_32[0][0]']
#  8 (GlobalAveragePooling2D)
#
#  dropout_13 (Dropout)        (None, 1280)                 0         ['global_average_pooling2d_18[
#                                                                     0][0]']
#
#  dense_6 (Dense)             (None, 2)                    2562      ['dropout_13[0][0]']
#
# ==================================================================================================
# Total params: 4098362 (15.63 MB)
# Trainable params: 4068250 (15.52 MB)
# Non-trainable params: 30112 (117.62 KB)
# __________________________________________________________________________________________________
# Epoch 1/30
# 2025-09-14 00:35:03.991361: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inmodel_4/dropout_4/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 1063/1063 [==============================] - 130s 67ms/step - loss: 0.3516 - accuracy: 0.8576 - val_loss: 0.6648 - val_accuracy: 0.8085 - lr: 3.0000e-04
# Epoch 2/30
# 1063/1063 [==============================] - 73s 64ms/step - loss: 0.2461 - accuracy: 0.9059 - val_loss: 0.4864 - val_accuracy: 0.8790 - lr: 3.0000e-04
# Epoch 3/30
# 1063/1063 [==============================] - 73s 64ms/step - loss: 0.2093 - accuracy: 0.9236 - val_loss: 0.2720 - val_accuracy: 0.9043 - lr: 3.0000e-04
# Epoch 4/30
# 1063/1063 [==============================] - 73s 64ms/step - loss: 0.1824 - accuracy: 0.9338 - val_loss: 0.3652 - val_accuracy: 0.9455 - lr: 3.0000e-04
# Epoch 5/30
# 1063/1063 [==============================] - 73s 64ms/step - loss: 0.1562 - accuracy: 0.9422 - val_loss: 0.4426 - val_accuracy: 0.8710 - lr: 3.0000e-04
# Epoch 6/30
# 1063/1063 [==============================] - 74s 64ms/step - loss: 0.1004 - accuracy: 0.9634 - val_loss: 0.1014 - val_accuracy: 0.9681 - lr: 1.5000e-04
# Epoch 7/30
# 1063/1063 [==============================] - 72s 63ms/step - loss: 0.1078 - accuracy: 0.9615 - val_loss: 0.0569 - val_accuracy: 0.9787 - lr: 1.5000e-04
# Epoch 8/30
# 1063/1063 [==============================] - 73s 64ms/step - loss: 0.0878 - accuracy: 0.9692 - val_loss: 0.1856 - val_accuracy: 0.9335 - lr: 1.5000e-04
# Epoch 9/30
# 1063/1063 [==============================] - 72s 63ms/step - loss: 0.0961 - accuracy: 0.9661 - val_loss: 0.0662 - val_accuracy: 0.9747 - lr: 1.5000e-04
# Epoch 10/30
# 1063/1063 [==============================] - 73s 64ms/step - loss: 0.0705 - accuracy: 0.9771 - val_loss: 0.0726 - val_accuracy: 0.9774 - lr: 7.5000e-05
# Epoch 11/30
# 1063/1063 [==============================] - 73s 64ms/step - loss: 0.0590 - accuracy: 0.9788 - val_loss: 0.0544 - val_accuracy: 0.9814 - lr: 7.5000e-05
# Epoch 12/30
# 1063/1063 [==============================] - 73s 64ms/step - loss: 0.0594 - accuracy: 0.9804 - val_loss: 0.0913 - val_accuracy: 0.9641 - lr: 7.5000e-05
# Epoch 13/30
# 1063/1063 [==============================] - 73s 64ms/step - loss: 0.0581 - accuracy: 0.9787 - val_loss: 0.0534 - val_accuracy: 0.9854 - lr: 7.5000e-05
# Epoch 14/30
# 1063/1063 [==============================] - 73s 64ms/step - loss: 0.0516 - accuracy: 0.9829 - val_loss: 0.0478 - val_accuracy: 0.9867 - lr: 7.5000e-05
# Epoch 15/30
# 1063/1063 [==============================] - 73s 64ms/step - loss: 0.0569 - accuracy: 0.9814 - val_loss: 0.0423 - val_accuracy: 0.9854 - lr: 7.5000e-05
# Epoch 16/30
# 1063/1063 [==============================] - 74s 65ms/step - loss: 0.0489 - accuracy: 0.9831 - val_loss: 0.0774 - val_accuracy: 0.9707 - lr: 7.5000e-05
# Epoch 17/30
# 1063/1063 [==============================] - 74s 65ms/step - loss: 0.0476 - accuracy: 0.9836 - val_loss: 0.0356 - val_accuracy: 0.9867 - lr: 7.5000e-05
# Epoch 18/30
# 1063/1063 [==============================] - 73s 64ms/step - loss: 0.0477 - accuracy: 0.9848 - val_loss: 0.0344 - val_accuracy: 0.9854 - lr: 7.5000e-05
# Epoch 19/30
# 1063/1063 [==============================] - 73s 64ms/step - loss: 0.0429 - accuracy: 0.9865 - val_loss: 0.0420 - val_accuracy: 0.9867 - lr: 7.5000e-05
# 94/94 [==============================] - 2s 13ms/step - loss: 0.0800 - accuracy: 0.9733
# Test accuracy: 0.9733

# %%
# =========================================
# Common setup (TensorFlow / Keras)
# =========================================
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pathlib

# ---- Paths & data ----
DATA_DIR = "/home/jovyan/.cache/kagglehub/datasets/obulisainaren/multi-cancer/versions/3/Multi Cancer/Multi Cancer/Breast Cancer"
IMG_SIZE = (256, 256)   # keep same as second snippet
BATCH_SIZE = 8
SEED = 1337

data_dir = pathlib.Path(DATA_DIR)

# ===== Dataset split: train (70%), val (15%), test (15%) =====
train_ds = keras.utils.image_dataset_from_directory(
    data_dir, labels="inferred", label_mode="int",
    image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    validation_split=0.15, subset="training", seed=SEED, shuffle=True
)

valtest_ds = keras.utils.image_dataset_from_directory(
    data_dir, labels="inferred", label_mode="int",
    image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    validation_split=0.15, subset="validation", seed=SEED, shuffle=False
)

# Split val/test 50/50 from the validation subset
val_batches = int(0.5 * tf.data.experimental.cardinality(valtest_ds).numpy())
val_ds = valtest_ds.take(val_batches)
test_ds = valtest_ds.skip(val_batches)

class_names = train_ds.class_names
num_classes = len(class_names)
print("Classes:", class_names)

# ===== Prefetch for performance (same as second snippet) =====
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.shuffle(1000).prefetch(AUTOTUNE)
val_ds   = val_ds.prefetch(AUTOTUNE)
test_ds  = test_ds.prefetch(AUTOTUNE)

# ===== Data augmentation (same as second snippet) =====
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.05),
    layers.RandomZoom(0.1),
])

# ===== Normalization (same as second snippet) =====
# NOTE: We use simple Rescaling(1./255) for ALL models, including transfer learning.
# This matches the second snippet; it's fine for your experiments.
def normalize_block(x):
    return layers.Rescaling(1./255)(x)

# =========================================
# Classifier head (shared for TL models)
# =========================================
def classifier_head(x, num_classes, dropout=0.3):
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(dropout)(x)
    return layers.Dense(num_classes, activation="softmax")(x)

# =========================================
# 1) Baseline CNN (from scratch)
#   - keep architecture flexible, but preprocessing matches second snippet
# =========================================
def build_baseline_cnn(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)

    # Three conv blocks, two convs per block (as in your first snippet's baseline)
    for filters in [32, 64, 128]:
        x = layers.Conv2D(filters, 3, padding="same", activation="relu")(x)
        x = layers.Conv2D(filters, 3, padding="same", activation="relu")(x)
        x = layers.MaxPooling2D()(x)
        x = layers.Dropout(0.25)(x)

    x = layers.Flatten()(x)
    x = layers.Dense(256, activation="relu")(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)
    return keras.Model(inputs, outputs, name="baseline_cnn")

# =========================================
# 2) ResNet50 (prebuilt)
# =========================================
from tensorflow.keras.applications import ResNet50
def build_resnet50(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = ResNet50(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="resnet50")

# =========================================
# 3) VGG16 (prebuilt)
# =========================================
from tensorflow.keras.applications import VGG16
def build_vgg16(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = VGG16(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="vgg16")

# =========================================
# 4) InceptionV3 (prebuilt)
# =========================================
from tensorflow.keras.applications import InceptionV3
def build_inceptionv3(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = InceptionV3(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="inceptionv3")

# =========================================
# 5) EfficientNetB0 (prebuilt)
# =========================================
from tensorflow.keras.applications import EfficientNetB0
def build_efficientnetb0(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = EfficientNetB0(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="efficientnetb0")

# =========================================
# Pick a model to train (same interface)
# =========================================
MODEL_NAME = "cnn"   # one of: "cnn", "resnet", "vgg", "inception", "efficientnet"
WEIGHTS = "imagenet"          # "imagenet" or None
FINE_TUNE_BASE = False        # set True to unfreeze backbone later

input_shape = (*IMG_SIZE, 3)

if MODEL_NAME == "cnn":
    model = build_baseline_cnn(input_shape, num_classes)
elif MODEL_NAME == "resnet":
    model = build_resnet50(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
elif MODEL_NAME == "vgg":
    model = build_vgg16(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
elif MODEL_NAME == "inception":
    model = build_inceptionv3(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
elif MODEL_NAME == "efficientnet":
    model = build_efficientnetb0(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
else:
    raise ValueError("Unknown MODEL_NAME")

# =========================================
# Compile & Train
# =========================================
model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss=keras.losses.SparseCategoricalCrossentropy(),
    metrics=["accuracy"]
)

callbacks = [
    keras.callbacks.EarlyStopping(patience=4, restore_best_weights=True, monitor="val_accuracy"),
]

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=20,
    callbacks=callbacks
)

# ===== Evaluate on the held-out TEST set (matches second snippet practice) =====
test_loss, test_acc = model.evaluate(test_ds, verbose=0)
print(f"{model.name}  |  Test acc: {test_acc:.4f}  |  Test loss: {test_loss:.4f}")
