# %%
import os, random, pandas as pd, tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.utils import shuffle

# ===============================
# Constants & Reproducibility
# ===============================
SEED = 1337
IMG_SIZE = (224, 224)
BATCH_SIZE = 8
AUTOTUNE = tf.data.AUTOTUNE
random.seed(SEED); tf.random.set_seed(SEED)

# ===============================
# CSV manifest (fixed split)
# ===============================
# If CSV has absolute paths, leave BASE_DIR=None. If relative, set BASE_DIR.
CSV_PATH = "/home/jovyan/Independent/split_manifest.csv"
BASE_DIR = None  # e.g., "/home/jovyan/.../Breast Cancer" if your CSV paths are relative

manifest = pd.read_csv(CSV_PATH)

# Resolve to absolute paths if needed
if BASE_DIR is not None:
    manifest["path"] = manifest["path"].apply(
        lambda p: p if os.path.isabs(p) else os.path.join(BASE_DIR, p)
    )

# Stable label mapping (replaces class_names)
labels_sorted = sorted(manifest["label"].unique())
label_to_int  = {l:i for i,l in enumerate(labels_sorted)}
int_to_label  = {v:k for k,v in label_to_int.items()}
num_classes   = len(labels_sorted)
print("Classes:", labels_sorted)

# Split dataframes
df_train = manifest[manifest["split"]=="train"].copy()
df_val   = manifest[manifest["split"]=="val"].copy()
df_test  = manifest[manifest["split"]=="test"].copy()

print("Counts by split:\n", manifest.groupby(["split","label"]).size().unstack(fill_value=0))

# ===============================
# tf.data from CSV (non-leaking)
# ===============================
def _decode(path):
    img = tf.io.read_file(path)
    img = tf.io.decode_image(img, channels=3, expand_animations=False)
    img = tf.image.resize(img, IMG_SIZE, antialias=True)
    img = tf.cast(img, tf.float32)  # 0..255; we'll rescale in the model
    return img

def make_ds(df, split, batch_size=BATCH_SIZE, seed=SEED):
    if split == "train":
        df = shuffle(df, random_state=seed)
    paths  = df["path"].tolist()
    labels = [label_to_int[l] for l in df["label"]]
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))
    def _load(p, y):
        return _decode(p), tf.cast(y, tf.int32)
    ds = ds.map(_load, num_parallel_calls=AUTOTUNE)
    if split == "train":
        ds = ds.shuffle(buffer_size=len(paths), seed=seed, reshuffle_each_iteration=True)
    return ds.batch(batch_size).prefetch(AUTOTUNE)

train_ds = make_ds(df_train, "train")
val_ds   = make_ds(df_val,   "val")
test_ds  = make_ds(df_test,  "test")

# ===============================
# Augment & Normalize blocks
# ===============================
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.05),
    layers.RandomZoom(0.1),
])

def normalize_block(x):
    # Scales from 0..255 (our decode) to 0..1 for all models
    return layers.Rescaling(1./255)(x)

# ===============================
# Classifier head (shared)
# ===============================
def classifier_head(x, num_classes, dropout=0.3):
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(dropout)(x)
    return layers.Dense(num_classes, activation="softmax")(x)

# ===============================
# 1) Baseline CNN (from scratch)
# ===============================
def build_baseline_cnn(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)

    # Three conv blocks, two convs per block (as in your first snippet's baseline)
    for filters in [32, 64, 128]:
        x = layers.Conv2D(filters, 3, padding="same", activation="relu")(x)
        x = layers.Conv2D(filters, 3, padding="same", activation="relu")(x)
        x = layers.MaxPooling2D()(x)
        x = layers.Dropout(0.25)(x)

    x = layers.Flatten()(x)
    x = layers.Dense(256, activation="relu")(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)
    return keras.Model(inputs, outputs, name="baseline_cnn")
# ===============================
# 2) ResNet50 (transfer learning)
# ===============================
from tensorflow.keras.applications import ResNet50
def build_resnet50(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = ResNet50(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="resnet50")

# ===============================
# 3) VGG16
# ===============================
from tensorflow.keras.applications import VGG16
def build_vgg16(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = VGG16(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="vgg16")

# ===============================
# 4) InceptionV3
# ===============================
from tensorflow.keras.applications import InceptionV3
def build_inceptionv3(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = InceptionV3(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="inceptionv3")

# ===============================
# 5) EfficientNetB0
# ===============================
from tensorflow.keras.applications import EfficientNetB0
def build_efficientnetb0(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = EfficientNetB0(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="efficientnetb0")

# ===============================
# Pick a model to train
# ===============================
MODEL_NAME = "cnn"   # "cnn" | "resnet" | "vgg" | "inception" | "efficientnet"
WEIGHTS = "imagenet"    # "imagenet" or None
FINE_TUNE_BASE = False  # set True to unfreeze backbone later
input_shape = (*IMG_SIZE, 3)

if MODEL_NAME == "cnn":
    model = build_baseline_cnn(input_shape, num_classes)
elif MODEL_NAME == "resnet":
    model = build_resnet50(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
elif MODEL_NAME == "vgg":
    model = build_vgg16(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
elif MODEL_NAME == "inception":
    model = build_inceptionv3(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
elif MODEL_NAME == "efficientnet":
    model = build_efficientnetb0(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
else:
    raise ValueError("Unknown MODEL_NAME")

# =========================================
# Compile & Train
# =========================================
model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss=keras.losses.SparseCategoricalCrossentropy(),
    metrics=["accuracy"]
)

callbacks = [
    keras.callbacks.EarlyStopping(patience=4, restore_best_weights=True, monitor="val_accuracy"),
]

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=20,
    callbacks=callbacks
)

# ===== Evaluate on the held-out TEST set (matches second snippet practice) =====
test_loss, test_acc = model.evaluate(test_ds, verbose=0)
print(f"{model.name}  |  Test acc: {test_acc:.4f}  |  Test loss: {test_loss:.4f}")
# Out:
# 2025-10-08 04:12:44.166191: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-08 04:12:45.255131: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Classes: ['brain_glioma', 'brain_menin', 'brain_tumor']
# Counts by split:
#  label  brain_glioma  brain_menin  brain_tumor
# split
# test            750          750          750
# train          3499         3499         3499
# val             750          750          750
# 2025-10-08 04:12:49.000043: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10491 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:3e:00.0, compute capability: 6.1
# 2025-10-08 04:12:49.000710: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 10491 MB memory:  -> device: 1, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:60:00.0, compute capability: 6.1
# 2025-10-08 04:12:49.001249: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 10491 MB memory:  -> device: 2, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:61:00.0, compute capability: 6.1
# 2025-10-08 04:12:49.001732: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 10491 MB memory:  -> device: 3, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:b1:00.0, compute capability: 6.1
# Epoch 1/20
# 2025-10-08 04:12:51.655574: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inbaseline_cnn/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2025-10-08 04:13:01.936252: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 2008 of 10497
# 2025-10-08 04:13:11.930664: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 4533 of 10497
# 2025-10-08 04:13:21.937635: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 7171 of 10497
# 2025-10-08 04:13:31.768329: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] Shuffle buffer filled.
# 2025-10-08 04:13:32.117421: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2025-10-08 04:13:32.682045: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5db692eeb260 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-10-08 04:13:32.682094: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce GTX 1080 Ti, Compute Capability 6.1
# 2025-10-08 04:13:32.682108: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (1): NVIDIA GeForce GTX 1080 Ti, Compute Capability 6.1
# 2025-10-08 04:13:32.682118: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (2): NVIDIA GeForce GTX 1080 Ti, Compute Capability 6.1
# 2025-10-08 04:13:32.682128: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (3): NVIDIA GeForce GTX 1080 Ti, Compute Capability 6.1
# 2025-10-08 04:13:32.689978: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-10-08 04:13:32.861429: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1313/1313 [==============================] - 104s 45ms/step - loss: 0.7719 - accuracy: 0.6473 - val_loss: 0.7520 - val_accuracy: 0.6689
# Epoch 2/20
# 1313/1313 [==============================] - 58s 41ms/step - loss: 0.6080 - accuracy: 0.7436 - val_loss: 0.5946 - val_accuracy: 0.7258
# Epoch 3/20
# 1313/1313 [==============================] - 58s 41ms/step - loss: 0.5469 - accuracy: 0.7805 - val_loss: 0.4405 - val_accuracy: 0.8391
# Epoch 4/20
# 1313/1313 [==============================] - 58s 41ms/step - loss: 0.5151 - accuracy: 0.7950 - val_loss: 0.4353 - val_accuracy: 0.8196
# Epoch 5/20
# 1313/1313 [==============================] - 58s 41ms/step - loss: 0.4796 - accuracy: 0.8106 - val_loss: 0.3907 - val_accuracy: 0.8516
# Epoch 6/20
# 1313/1313 [==============================] - 58s 41ms/step - loss: 0.4654 - accuracy: 0.8189 - val_loss: 0.3671 - val_accuracy: 0.8622
# Epoch 7/20
# 1313/1313 [==============================] - 58s 41ms/step - loss: 0.4437 - accuracy: 0.8268 - val_loss: 0.3505 - val_accuracy: 0.8711
# Epoch 8/20
# 1313/1313 [==============================] - 58s 41ms/step - loss: 0.4122 - accuracy: 0.8418 - val_loss: 0.3114 - val_accuracy: 0.8831
# Epoch 9/20
# 1313/1313 [==============================] - 58s 41ms/step - loss: 0.4075 - accuracy: 0.8453 - val_loss: 0.3224 - val_accuracy: 0.8849
# Epoch 10/20
# 1313/1313 [==============================] - 58s 41ms/step - loss: 0.3786 - accuracy: 0.8506 - val_loss: 0.2909 - val_accuracy: 0.8991
# Epoch 11/20
# 1313/1313 [==============================] - 58s 41ms/step - loss: 0.3682 - accuracy: 0.8586 - val_loss: 0.2977 - val_accuracy: 0.8987
# Epoch 12/20
# 1313/1313 [==============================] - 58s 41ms/step - loss: 0.3514 - accuracy: 0.8670 - val_loss: 0.3715 - val_accuracy: 0.8591
# Epoch 13/20
# 1313/1313 [==============================] - 58s 41ms/step - loss: 0.3375 - accuracy: 0.8738 - val_loss: 0.2559 - val_accuracy: 0.9076
# Epoch 14/20
# 1313/1313 [==============================] - 58s 41ms/step - loss: 0.3059 - accuracy: 0.8837 - val_loss: 0.2391 - val_accuracy: 0.9133
# Epoch 15/20
# 1313/1313 [==============================] - 58s 41ms/step - loss: 0.3119 - accuracy: 0.8838 - val_loss: 0.3007 - val_accuracy: 0.8924
# Epoch 16/20
# 1313/1313 [==============================] - 58s 41ms/step - loss: 0.2984 - accuracy: 0.8869 - val_loss: 0.2456 - val_accuracy: 0.9160
# Epoch 17/20
# 1313/1313 [==============================] - 58s 41ms/step - loss: 0.2799 - accuracy: 0.8947 - val_loss: 0.2089 - val_accuracy: 0.9231
# Epoch 18/20
# 1313/1313 [==============================] - 58s 41ms/step - loss: 0.2746 - accuracy: 0.8971 - val_loss: 0.1825 - val_accuracy: 0.9329
# Epoch 19/20
# 1313/1313 [==============================] - 58s 41ms/step - loss: 0.2711 - accuracy: 0.8994 - val_loss: 0.2164 - val_accuracy: 0.9302
# Epoch 20/20
# 1313/1313 [==============================] - 58s 41ms/step - loss: 0.2572 - accuracy: 0.9026 - val_loss: 0.2007 - val_accuracy: 0.9271
# baseline_cnn  |  Test acc: 0.9209  |  Test loss: 0.2155

# %%
import os, random, pandas as pd, tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.utils import shuffle

# ===============================
# Constants & Reproducibility
# ===============================
SEED = 1337
IMG_SIZE = (224, 224)
BATCH_SIZE = 8
AUTOTUNE = tf.data.AUTOTUNE
random.seed(SEED); tf.random.set_seed(SEED)

# ===============================
# CSV manifest (fixed split)
# ===============================
# If CSV has absolute paths, leave BASE_DIR=None. If relative, set BASE_DIR.
CSV_PATH = "/home/jovyan/Independent/split_manifest.csv"
BASE_DIR = None  # e.g., "/home/jovyan/.../Breast Cancer" if your CSV paths are relative

manifest = pd.read_csv(CSV_PATH)

# Resolve to absolute paths if needed
if BASE_DIR is not None:
    manifest["path"] = manifest["path"].apply(
        lambda p: p if os.path.isabs(p) else os.path.join(BASE_DIR, p)
    )

# Stable label mapping (replaces class_names)
labels_sorted = sorted(manifest["label"].unique())
label_to_int  = {l:i for i,l in enumerate(labels_sorted)}
int_to_label  = {v:k for k,v in label_to_int.items()}
num_classes   = len(labels_sorted)
print("Classes:", labels_sorted)

# Split dataframes
df_train = manifest[manifest["split"]=="train"].copy()
df_val   = manifest[manifest["split"]=="val"].copy()
df_test  = manifest[manifest["split"]=="test"].copy()

print("Counts by split:\n", manifest.groupby(["split","label"]).size().unstack(fill_value=0))

# ===============================
# tf.data from CSV (non-leaking)
# ===============================
def _decode(path):
    img = tf.io.read_file(path)
    img = tf.io.decode_image(img, channels=3, expand_animations=False)
    img = tf.image.resize(img, IMG_SIZE, antialias=True)
    img = tf.cast(img, tf.float32)  # 0..255; we'll rescale in the model
    return img

def make_ds(df, split, batch_size=BATCH_SIZE, seed=SEED):
    if split == "train":
        df = shuffle(df, random_state=seed)
    paths  = df["path"].tolist()
    labels = [label_to_int[l] for l in df["label"]]
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))
    def _load(p, y):
        return _decode(p), tf.cast(y, tf.int32)
    ds = ds.map(_load, num_parallel_calls=AUTOTUNE)
    if split == "train":
        ds = ds.shuffle(buffer_size=len(paths), seed=seed, reshuffle_each_iteration=True)
    return ds.batch(batch_size).prefetch(AUTOTUNE)

train_ds = make_ds(df_train, "train")
val_ds   = make_ds(df_val,   "val")
test_ds  = make_ds(df_test,  "test")

# ===============================
# Augment & Normalize blocks
# ===============================
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.05),
    layers.RandomZoom(0.1),
])

def normalize_block(x):
    # Scales from 0..255 (our decode) to 0..1 for all models
    return layers.Rescaling(1./255)(x)

# ===============================
# Classifier head (shared)
# ===============================
def classifier_head(x, num_classes, dropout=0.3):
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(dropout)(x)
    return layers.Dense(num_classes, activation="softmax")(x)

# ===============================
# 1) Baseline CNN (from scratch)
# ===============================
def build_baseline_cnn(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    for filters in [32, 64, 128]:
        x = layers.Conv2D(filters, 3, padding="same", activation="relu")(x)
        x = layers.Conv2D(filters, 3, padding="same", activation="relu")(x)
        x = layers.MaxPooling2D()(x)
        x = layers.Dropout(0.25)(x)
    x = layers.Flatten()(x)
    x = layers.Dense(256, activation="relu")(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)
    return keras.Model(inputs, outputs, name="baseline_cnn")

# ===============================
# 2) ResNet50 (transfer learning)
# ===============================
from tensorflow.keras.applications import ResNet50
def build_resnet50(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = ResNet50(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="resnet50")

# ===============================
# 3) VGG16
# ===============================
from tensorflow.keras.applications import VGG16
def build_vgg16(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = VGG16(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="vgg16")

# ===============================
# 4) InceptionV3
# ===============================
from tensorflow.keras.applications import InceptionV3
def build_inceptionv3(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = InceptionV3(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="inceptionv3")

# ===============================
# 5) EfficientNetB0
# ===============================
from tensorflow.keras.applications import EfficientNetB0
def build_efficientnetb0(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = EfficientNetB0(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="efficientnetb0")

# ===============================
# Pick a model to train
# ===============================
MODEL_NAME = "resnet"   # "cnn" | "resnet" | "vgg" | "inception" | "efficientnet"
WEIGHTS = "imagenet"    # "imagenet" or None
FINE_TUNE_BASE = False  # set True to unfreeze backbone later
input_shape = (*IMG_SIZE, 3)

if MODEL_NAME == "cnn":
    model = build_baseline_cnn(input_shape, num_classes)
elif MODEL_NAME == "resnet":
    model = build_resnet50(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
elif MODEL_NAME == "vgg":
    model = build_vgg16(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
elif MODEL_NAME == "inception":
    model = build_inceptionv3(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
elif MODEL_NAME == "efficientnet":
    model = build_efficientnetb0(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
else:
    raise ValueError("Unknown MODEL_NAME")

# =========================================
# Compile & Train
# =========================================
model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss=keras.losses.SparseCategoricalCrossentropy(),
    metrics=["accuracy"]
)

callbacks = [
    keras.callbacks.EarlyStopping(patience=4, restore_best_weights=True, monitor="val_accuracy"),
]

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=20,
    callbacks=callbacks
)

# ===== Evaluate on the held-out TEST set (matches second snippet practice) =====
test_loss, test_acc = model.evaluate(test_ds, verbose=0)
print(f"{model.name}  |  Test acc: {test_acc:.4f}  |  Test loss: {test_loss:.4f}")
# Out:
# Classes: ['brain_glioma', 'brain_menin', 'brain_tumor']
# Counts by split:
#  label  brain_glioma  brain_menin  brain_tumor
# split
# test            750          750          750
# train          3499         3499         3499
# val             750          750          750
# Epoch 1/20
# 1313/1313 [==============================] - 37s 23ms/step - loss: 1.0588 - accuracy: 0.4505 - val_loss: 0.9209 - val_accuracy: 0.5560
# Epoch 2/20
# 1313/1313 [==============================] - 32s 22ms/step - loss: 0.9424 - accuracy: 0.5520 - val_loss: 0.8348 - val_accuracy: 0.6636
# Epoch 3/20
# 1313/1313 [==============================] - 33s 22ms/step - loss: 0.9089 - accuracy: 0.5710 - val_loss: 0.7950 - val_accuracy: 0.6524
# Epoch 4/20
# 1313/1313 [==============================] - 33s 23ms/step - loss: 0.8796 - accuracy: 0.5962 - val_loss: 0.8269 - val_accuracy: 0.6636
# Epoch 5/20
# 1313/1313 [==============================] - 33s 22ms/step - loss: 0.8577 - accuracy: 0.6089 - val_loss: 0.7818 - val_accuracy: 0.6729
# Epoch 6/20
# 1313/1313 [==============================] - 32s 22ms/step - loss: 0.8600 - accuracy: 0.6056 - val_loss: 0.7620 - val_accuracy: 0.6791
# Epoch 7/20
# 1313/1313 [==============================] - 32s 22ms/step - loss: 0.8485 - accuracy: 0.6066 - val_loss: 0.7909 - val_accuracy: 0.6711
# Epoch 8/20
# 1313/1313 [==============================] - 33s 22ms/step - loss: 0.8421 - accuracy: 0.6185 - val_loss: 0.7311 - val_accuracy: 0.6764
# Epoch 9/20
# 1313/1313 [==============================] - 32s 22ms/step - loss: 0.8328 - accuracy: 0.6195 - val_loss: 0.7364 - val_accuracy: 0.6991
# Epoch 10/20
# 1313/1313 [==============================] - 33s 22ms/step - loss: 0.8299 - accuracy: 0.6218 - val_loss: 0.7699 - val_accuracy: 0.6698
# Epoch 11/20
# 1313/1313 [==============================] - 32s 22ms/step - loss: 0.8195 - accuracy: 0.6328 - val_loss: 0.7039 - val_accuracy: 0.7004
# Epoch 12/20
# 1313/1313 [==============================] - 32s 22ms/step - loss: 0.8190 - accuracy: 0.6311 - val_loss: 0.7431 - val_accuracy: 0.6853
# Epoch 13/20
# 1313/1313 [==============================] - 33s 22ms/step - loss: 0.8128 - accuracy: 0.6298 - val_loss: 0.7286 - val_accuracy: 0.7044
# Epoch 14/20
# 1313/1313 [==============================] - 33s 22ms/step - loss: 0.8047 - accuracy: 0.6448 - val_loss: 0.7111 - val_accuracy: 0.7133
# Epoch 15/20
# 1313/1313 [==============================] - 32s 22ms/step - loss: 0.8114 - accuracy: 0.6357 - val_loss: 0.6954 - val_accuracy: 0.7000
# Epoch 16/20
# 1313/1313 [==============================] - 32s 22ms/step - loss: 0.8085 - accuracy: 0.6331 - val_loss: 0.7039 - val_accuracy: 0.7040
# Epoch 17/20
# 1313/1313 [==============================] - 32s 22ms/step - loss: 0.8062 - accuracy: 0.6347 - val_loss: 0.6973 - val_accuracy: 0.7049
# Epoch 18/20
# 1313/1313 [==============================] - 33s 23ms/step - loss: 0.8082 - accuracy: 0.6322 - val_loss: 0.7122 - val_accuracy: 0.7093
# resnet50  |  Test acc: 0.7058  |  Test loss: 0.7210

# %%
import os, random, pandas as pd, tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.utils import shuffle

# ===============================
# Constants & Reproducibility
# ===============================
SEED = 1337
IMG_SIZE = (224, 224)
BATCH_SIZE = 8
AUTOTUNE = tf.data.AUTOTUNE
random.seed(SEED); tf.random.set_seed(SEED)

# ===============================
# CSV manifest (fixed split)
# ===============================
# If CSV has absolute paths, leave BASE_DIR=None. If relative, set BASE_DIR.
CSV_PATH = "/home/jovyan/Independent/split_manifest.csv"
BASE_DIR = None  # e.g., "/home/jovyan/.../Breast Cancer" if your CSV paths are relative

manifest = pd.read_csv(CSV_PATH)

# Resolve to absolute paths if needed
if BASE_DIR is not None:
    manifest["path"] = manifest["path"].apply(
        lambda p: p if os.path.isabs(p) else os.path.join(BASE_DIR, p)
    )

# Stable label mapping (replaces class_names)
labels_sorted = sorted(manifest["label"].unique())
label_to_int  = {l:i for i,l in enumerate(labels_sorted)}
int_to_label  = {v:k for k,v in label_to_int.items()}
num_classes   = len(labels_sorted)
print("Classes:", labels_sorted)

# Split dataframes
df_train = manifest[manifest["split"]=="train"].copy()
df_val   = manifest[manifest["split"]=="val"].copy()
df_test  = manifest[manifest["split"]=="test"].copy()

print("Counts by split:\n", manifest.groupby(["split","label"]).size().unstack(fill_value=0))

# ===============================
# tf.data from CSV (non-leaking)
# ===============================
def _decode(path):
    img = tf.io.read_file(path)
    img = tf.io.decode_image(img, channels=3, expand_animations=False)
    img = tf.image.resize(img, IMG_SIZE, antialias=True)
    img = tf.cast(img, tf.float32)  # 0..255; we'll rescale in the model
    return img

def make_ds(df, split, batch_size=BATCH_SIZE, seed=SEED):
    if split == "train":
        df = shuffle(df, random_state=seed)
    paths  = df["path"].tolist()
    labels = [label_to_int[l] for l in df["label"]]
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))
    def _load(p, y):
        return _decode(p), tf.cast(y, tf.int32)
    ds = ds.map(_load, num_parallel_calls=AUTOTUNE)
    if split == "train":
        ds = ds.shuffle(buffer_size=len(paths), seed=seed, reshuffle_each_iteration=True)
    return ds.batch(batch_size).prefetch(AUTOTUNE)

train_ds = make_ds(df_train, "train")
val_ds   = make_ds(df_val,   "val")
test_ds  = make_ds(df_test,  "test")

# ===============================
# Augment & Normalize blocks
# ===============================
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.05),
    layers.RandomZoom(0.1),
])

def normalize_block(x):
    # Scales from 0..255 (our decode) to 0..1 for all models
    return layers.Rescaling(1./255)(x)

# ===============================
# Classifier head (shared)
# ===============================
def classifier_head(x, num_classes, dropout=0.3):
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(dropout)(x)
    return layers.Dense(num_classes, activation="softmax")(x)

# ===============================
# 1) Baseline CNN (from scratch)
# ===============================
def build_baseline_cnn(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)

    # Three conv blocks, two convs per block (as in your first snippet's baseline)
    for filters in [32, 64, 128]:
        x = layers.Conv2D(filters, 3, padding="same", activation="relu")(x)
        x = layers.Conv2D(filters, 3, padding="same", activation="relu")(x)
        x = layers.MaxPooling2D()(x)
        x = layers.Dropout(0.25)(x)

    x = layers.Flatten()(x)
    x = layers.Dense(256, activation="relu")(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)
    return keras.Model(inputs, outputs, name="baseline_cnn")
# ===============================
# 2) ResNet50 (transfer learning)
# ===============================
from tensorflow.keras.applications import ResNet50
def build_resnet50(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = ResNet50(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="resnet50")

# ===============================
# 3) VGG16
# ===============================
from tensorflow.keras.applications import VGG16
def build_vgg16(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = VGG16(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="vgg16")

# ===============================
# 4) InceptionV3
# ===============================
from tensorflow.keras.applications import InceptionV3
def build_inceptionv3(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = InceptionV3(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="inceptionv3")

# ===============================
# 5) EfficientNetB0
# ===============================
from tensorflow.keras.applications import EfficientNetB0
def build_efficientnetb0(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = EfficientNetB0(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="efficientnetb0")

# ===============================
# Pick a model to train
# ===============================
MODEL_NAME = "vgg"   # "cnn" | "resnet" | "vgg" | "inception" | "efficientnet"
WEIGHTS = "imagenet"    # "imagenet" or None
FINE_TUNE_BASE = False  # set True to unfreeze backbone later
input_shape = (*IMG_SIZE, 3)

if MODEL_NAME == "cnn":
    model = build_baseline_cnn(input_shape, num_classes)
elif MODEL_NAME == "resnet":
    model = build_resnet50(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
elif MODEL_NAME == "vgg":
    model = build_vgg16(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
elif MODEL_NAME == "inception":
    model = build_inceptionv3(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
elif MODEL_NAME == "efficientnet":
    model = build_efficientnetb0(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
else:
    raise ValueError("Unknown MODEL_NAME")

# =========================================
# Compile & Train
# =========================================
model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss=keras.losses.SparseCategoricalCrossentropy(),
    metrics=["accuracy"]
)

callbacks = [
    keras.callbacks.EarlyStopping(patience=4, restore_best_weights=True, monitor="val_accuracy"),
]

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=20,
    callbacks=callbacks
)

# ===== Evaluate on the held-out TEST set (matches second snippet practice) =====
test_loss, test_acc = model.evaluate(test_ds, verbose=0)
print(f"{model.name}  |  Test acc: {test_acc:.4f}  |  Test loss: {test_loss:.4f}")
# Out:
# 2025-10-08 19:43:00.048160: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-10-08 19:43:00.094250: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-10-08 19:43:00.910011: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Classes: ['brain_glioma', 'brain_menin', 'brain_tumor']
# Counts by split:
#  label  brain_glioma  brain_menin  brain_tumor
# split
# test            750          750          750
# train          3499         3499         3499
# val             750          750          750
# 2025-10-08 19:43:04.946026: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9556 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:3d:00.0, compute capability: 7.5
# 2025-10-08 19:43:04.947592: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 9556 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:61:00.0, compute capability: 7.5
# 2025-10-08 19:43:04.948986: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 9556 MB memory:  -> device: 2, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:b1:00.0, compute capability: 7.5
# 2025-10-08 19:43:04.950346: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 9556 MB memory:  -> device: 3, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:b2:00.0, compute capability: 7.5
# Epoch 1/20
# 2025-10-08 19:43:20.079106: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 5537 of 10497
# 2025-10-08 19:43:27.506700: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] Shuffle buffer filled.
# 2025-10-08 19:43:28.111151: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2025-10-08 19:43:29.090217: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7d835b7bbb90 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-10-08 19:43:29.090256: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2025-10-08 19:43:29.090263: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (1): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2025-10-08 19:43:29.090269: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (2): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2025-10-08 19:43:29.090275: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (3): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2025-10-08 19:43:29.095355: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-10-08 19:43:29.209446: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1313/1313 [==============================] - 58s 29ms/step - loss: 0.7390 - accuracy: 0.7013 - val_loss: 0.5448 - val_accuracy: 0.8196
# Epoch 2/20
# 1313/1313 [==============================] - 39s 28ms/step - loss: 0.5314 - accuracy: 0.8025 - val_loss: 0.4408 - val_accuracy: 0.8542
# Epoch 3/20
# 1313/1313 [==============================] - 40s 28ms/step - loss: 0.4701 - accuracy: 0.8208 - val_loss: 0.3770 - val_accuracy: 0.8764
# Epoch 4/20
# 1313/1313 [==============================] - 40s 28ms/step - loss: 0.4397 - accuracy: 0.8314 - val_loss: 0.3457 - val_accuracy: 0.8880
# Epoch 5/20
# 1313/1313 [==============================] - 40s 28ms/step - loss: 0.4221 - accuracy: 0.8376 - val_loss: 0.3221 - val_accuracy: 0.8982
# Epoch 6/20
# 1313/1313 [==============================] - 40s 28ms/step - loss: 0.4089 - accuracy: 0.8444 - val_loss: 0.3295 - val_accuracy: 0.8893
# Epoch 7/20
# 1313/1313 [==============================] - 40s 28ms/step - loss: 0.3995 - accuracy: 0.8504 - val_loss: 0.3069 - val_accuracy: 0.8938
# Epoch 8/20
# 1313/1313 [==============================] - 39s 28ms/step - loss: 0.3876 - accuracy: 0.8487 - val_loss: 0.2980 - val_accuracy: 0.8933
# Epoch 9/20
# 1313/1313 [==============================] - 40s 28ms/step - loss: 0.3851 - accuracy: 0.8550 - val_loss: 0.2996 - val_accuracy: 0.8898
# vgg16  |  Test acc: 0.9084  |  Test loss: 0.3246

# %%
#GoogLeNet
import os, random, pandas as pd, tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.utils import shuffle

# ===============================
# Constants & Reproducibility
# ===============================
SEED = 1337
IMG_SIZE = (224, 224)
BATCH_SIZE = 8
AUTOTUNE = tf.data.AUTOTUNE
random.seed(SEED); tf.random.set_seed(SEED)

# ===============================
# CSV manifest (fixed split)
# ===============================
# If CSV has absolute paths, leave BASE_DIR=None. If relative, set BASE_DIR.
CSV_PATH = "/home/jovyan/Independent/split_manifest.csv"
BASE_DIR = None  # e.g., "/home/jovyan/.../Breast Cancer" if your CSV paths are relative

manifest = pd.read_csv(CSV_PATH)

# Resolve to absolute paths if needed
if BASE_DIR is not None:
    manifest["path"] = manifest["path"].apply(
        lambda p: p if os.path.isabs(p) else os.path.join(BASE_DIR, p)
    )

# Stable label mapping (replaces class_names)
labels_sorted = sorted(manifest["label"].unique())
label_to_int  = {l:i for i,l in enumerate(labels_sorted)}
int_to_label  = {v:k for k,v in label_to_int.items()}
num_classes   = len(labels_sorted)
print("Classes:", labels_sorted)

# Split dataframes
df_train = manifest[manifest["split"]=="train"].copy()
df_val   = manifest[manifest["split"]=="val"].copy()
df_test  = manifest[manifest["split"]=="test"].copy()

print("Counts by split:\n", manifest.groupby(["split","label"]).size().unstack(fill_value=0))

# ===============================
# tf.data from CSV (non-leaking)
# ===============================
def _decode(path):
    img = tf.io.read_file(path)
    img = tf.io.decode_image(img, channels=3, expand_animations=False)
    img = tf.image.resize(img, IMG_SIZE, antialias=True)
    img = tf.cast(img, tf.float32)  # 0..255; we'll rescale in the model
    return img

def make_ds(df, split, batch_size=BATCH_SIZE, seed=SEED):
    if split == "train":
        df = shuffle(df, random_state=seed)
    paths  = df["path"].tolist()
    labels = [label_to_int[l] for l in df["label"]]
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))
    def _load(p, y):
        return _decode(p), tf.cast(y, tf.int32)
    ds = ds.map(_load, num_parallel_calls=AUTOTUNE)
    if split == "train":
        ds = ds.shuffle(buffer_size=len(paths), seed=seed, reshuffle_each_iteration=True)
    return ds.batch(batch_size).prefetch(AUTOTUNE)

train_ds = make_ds(df_train, "train")
val_ds   = make_ds(df_val,   "val")
test_ds  = make_ds(df_test,  "test")

# ===============================
# Augment & Normalize blocks
# ===============================
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.05),
    layers.RandomZoom(0.1),
])

def normalize_block(x):
    # Scales from 0..255 (our decode) to 0..1 for all models
    return layers.Rescaling(1./255)(x)

# ===============================
# Classifier head (shared)
# ===============================
def classifier_head(x, num_classes, dropout=0.3):
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(dropout)(x)
    return layers.Dense(num_classes, activation="softmax")(x)

# ===============================
# 1) Baseline CNN (from scratch)
# ===============================
def build_baseline_cnn(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)

    # Three conv blocks, two convs per block (as in your first snippet's baseline)
    for filters in [32, 64, 128]:
        x = layers.Conv2D(filters, 3, padding="same", activation="relu")(x)
        x = layers.Conv2D(filters, 3, padding="same", activation="relu")(x)
        x = layers.MaxPooling2D()(x)
        x = layers.Dropout(0.25)(x)

    x = layers.Flatten()(x)
    x = layers.Dense(256, activation="relu")(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)
    return keras.Model(inputs, outputs, name="baseline_cnn")
# ===============================
# 2) ResNet50 (transfer learning)
# ===============================
from tensorflow.keras.applications import ResNet50
def build_resnet50(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = ResNet50(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="resnet50")

# ===============================
# 3) VGG16
# ===============================
from tensorflow.keras.applications import VGG16
def build_vgg16(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = VGG16(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="vgg16")

# ===============================
# 4) InceptionV3
# ===============================
from tensorflow.keras.applications import InceptionV3
def build_inceptionv3(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = InceptionV3(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="inceptionv3")

# ===============================
# 5) EfficientNetB0
# ===============================
from tensorflow.keras.applications import EfficientNetB0
def build_efficientnetb0(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = EfficientNetB0(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="efficientnetb0")

# ===============================
# Pick a model to train
# ===============================
MODEL_NAME = "inception"   # "cnn" | "resnet" | "vgg" | "inception" | "efficientnet"
WEIGHTS = "imagenet"    # "imagenet" or None
FINE_TUNE_BASE = False  # set True to unfreeze backbone later
input_shape = (*IMG_SIZE, 3)

if MODEL_NAME == "cnn":
    model = build_baseline_cnn(input_shape, num_classes)
elif MODEL_NAME == "resnet":
    model = build_resnet50(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
elif MODEL_NAME == "vgg":
    model = build_vgg16(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
elif MODEL_NAME == "inception":
    model = build_inceptionv3(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
elif MODEL_NAME == "efficientnet":
    model = build_efficientnetb0(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
else:
    raise ValueError("Unknown MODEL_NAME")

# =========================================
# Compile & Train
# =========================================
model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss=keras.losses.SparseCategoricalCrossentropy(),
    metrics=["accuracy"]
)

callbacks = [
    keras.callbacks.EarlyStopping(patience=4, restore_best_weights=True, monitor="val_accuracy"),
]

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=20,
    callbacks=callbacks
)

# ===== Evaluate on the held-out TEST set (matches second snippet practice) =====
test_loss, test_acc = model.evaluate(test_ds, verbose=0)
print(f"{model.name}  |  Test acc: {test_acc:.4f}  |  Test loss: {test_loss:.4f}")
# Out:
# Classes: ['brain_glioma', 'brain_menin', 'brain_tumor']
# Counts by split:
#  label  brain_glioma  brain_menin  brain_tumor
# split
# test            750          750          750
# train          3499         3499         3499
# val             750          750          750
# Epoch 1/20
# 1313/1313 [==============================] - 35s 22ms/step - loss: 0.4170 - accuracy: 0.8312 - val_loss: 0.4143 - val_accuracy: 0.8280
# Epoch 2/20
# 1313/1313 [==============================] - 29s 20ms/step - loss: 0.3193 - accuracy: 0.8801 - val_loss: 0.4952 - val_accuracy: 0.8116
# Epoch 3/20
# 1313/1313 [==============================] - 29s 20ms/step - loss: 0.2959 - accuracy: 0.8858 - val_loss: 0.1897 - val_accuracy: 0.9249
# Epoch 4/20
# 1313/1313 [==============================] - 29s 20ms/step - loss: 0.3002 - accuracy: 0.8849 - val_loss: 0.2024 - val_accuracy: 0.9204
# Epoch 5/20
# 1313/1313 [==============================] - 29s 20ms/step - loss: 0.2787 - accuracy: 0.8945 - val_loss: 0.1910 - val_accuracy: 0.9240
# Epoch 6/20
# 1313/1313 [==============================] - 29s 20ms/step - loss: 0.2893 - accuracy: 0.8843 - val_loss: 0.2951 - val_accuracy: 0.8840
# Epoch 7/20
# 1313/1313 [==============================] - 29s 20ms/step - loss: 0.2688 - accuracy: 0.8931 - val_loss: 0.1680 - val_accuracy: 0.9342
# Epoch 8/20
# 1313/1313 [==============================] - 29s 20ms/step - loss: 0.2775 - accuracy: 0.8927 - val_loss: 0.3396 - val_accuracy: 0.8756
# Epoch 9/20
# 1313/1313 [==============================] - 29s 20ms/step - loss: 0.2663 - accuracy: 0.8995 - val_loss: 0.1942 - val_accuracy: 0.9236
# Epoch 10/20
# 1313/1313 [==============================] - 29s 20ms/step - loss: 0.2733 - accuracy: 0.8990 - val_loss: 0.3468 - val_accuracy: 0.8698
# Epoch 11/20
# 1313/1313 [==============================] - 29s 20ms/step - loss: 0.2756 - accuracy: 0.8999 - val_loss: 0.1504 - val_accuracy: 0.9444
# Epoch 12/20
# 1313/1313 [==============================] - 29s 20ms/step - loss: 0.2726 - accuracy: 0.9002 - val_loss: 0.1787 - val_accuracy: 0.9267
# Epoch 13/20
# 1313/1313 [==============================] - 29s 20ms/step - loss: 0.2757 - accuracy: 0.8972 - val_loss: 0.1745 - val_accuracy: 0.9271
# Epoch 14/20
# 1313/1313 [==============================] - 29s 20ms/step - loss: 0.2735 - accuracy: 0.9024 - val_loss: 0.1972 - val_accuracy: 0.9218
# Epoch 15/20
# 1313/1313 [==============================] - 29s 20ms/step - loss: 0.2684 - accuracy: 0.9011 - val_loss: 0.1827 - val_accuracy: 0.9284
# inceptionv3  |  Test acc: 0.9338  |  Test loss: 0.1669

# %%
#Effnecitnet 
import os, random, pandas as pd, tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.utils import shuffle

# ===============================
# Constants & Reproducibility
# ===============================
SEED = 1337
IMG_SIZE = (224, 224)
BATCH_SIZE = 8
AUTOTUNE = tf.data.AUTOTUNE
random.seed(SEED); tf.random.set_seed(SEED)

# ===============================
# CSV manifest (fixed split)
# ===============================
# If CSV has absolute paths, leave BASE_DIR=None. If relative, set BASE_DIR.
CSV_PATH = "/home/jovyan/Independent/split_manifest.csv"
BASE_DIR = None  # e.g., "/home/jovyan/.../Breast Cancer" if your CSV paths are relative

manifest = pd.read_csv(CSV_PATH)

# Resolve to absolute paths if needed
if BASE_DIR is not None:
    manifest["path"] = manifest["path"].apply(
        lambda p: p if os.path.isabs(p) else os.path.join(BASE_DIR, p)
    )

# Stable label mapping (replaces class_names)
labels_sorted = sorted(manifest["label"].unique())
label_to_int  = {l:i for i,l in enumerate(labels_sorted)}
int_to_label  = {v:k for k,v in label_to_int.items()}
num_classes   = len(labels_sorted)
print("Classes:", labels_sorted)

# Split dataframes
df_train = manifest[manifest["split"]=="train"].copy()
df_val   = manifest[manifest["split"]=="val"].copy()
df_test  = manifest[manifest["split"]=="test"].copy()

print("Counts by split:\n", manifest.groupby(["split","label"]).size().unstack(fill_value=0))

# ===============================
# tf.data from CSV (non-leaking)
# ===============================
def _decode(path):
    img = tf.io.read_file(path)
    img = tf.io.decode_image(img, channels=3, expand_animations=False)
    img = tf.image.resize(img, IMG_SIZE, antialias=True)
    img = tf.cast(img, tf.float32)  # 0..255; we'll rescale in the model
    return img

def make_ds(df, split, batch_size=BATCH_SIZE, seed=SEED):
    if split == "train":
        df = shuffle(df, random_state=seed)
    paths  = df["path"].tolist()
    labels = [label_to_int[l] for l in df["label"]]
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))
    def _load(p, y):
        return _decode(p), tf.cast(y, tf.int32)
    ds = ds.map(_load, num_parallel_calls=AUTOTUNE)
    if split == "train":
        ds = ds.shuffle(buffer_size=len(paths), seed=seed, reshuffle_each_iteration=True)
    return ds.batch(batch_size).prefetch(AUTOTUNE)

train_ds = make_ds(df_train, "train")
val_ds   = make_ds(df_val,   "val")
test_ds  = make_ds(df_test,  "test")

# ===============================
# Augment & Normalize blocks
# ===============================
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.05),
    layers.RandomZoom(0.1),
])

def normalize_block(x):
    # Scales from 0..255 (our decode) to 0..1 for all models
    return layers.Rescaling(1./255)(x)

# ===============================
# Classifier head (shared)
# ===============================
def classifier_head(x, num_classes, dropout=0.3):
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(dropout)(x)
    return layers.Dense(num_classes, activation="softmax")(x)

# ===============================
# 1) Baseline CNN (from scratch)
# ===============================
def build_baseline_cnn(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)

    # Three conv blocks, two convs per block (as in your first snippet's baseline)
    for filters in [32, 64, 128]:
        x = layers.Conv2D(filters, 3, padding="same", activation="relu")(x)
        x = layers.Conv2D(filters, 3, padding="same", activation="relu")(x)
        x = layers.MaxPooling2D()(x)
        x = layers.Dropout(0.25)(x)

    x = layers.Flatten()(x)
    x = layers.Dense(256, activation="relu")(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)
    return keras.Model(inputs, outputs, name="baseline_cnn")
# ===============================
# 2) ResNet50 (transfer learning)
# ===============================
from tensorflow.keras.applications import ResNet50
def build_resnet50(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = ResNet50(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="resnet50")

# ===============================
# 3) VGG16
# ===============================
from tensorflow.keras.applications import VGG16
def build_vgg16(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = VGG16(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="vgg16")

# ===============================
# 4) InceptionV3
# ===============================
from tensorflow.keras.applications import InceptionV3
def build_inceptionv3(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = InceptionV3(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="inceptionv3")

# ===============================
# 5) EfficientNetB0
# ===============================
from tensorflow.keras.applications import EfficientNetB0
def build_efficientnetb0(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = EfficientNetB0(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="efficientnetb0")

# ===============================
# Pick a model to train
# ===============================
MODEL_NAME = "efficientnet"   # "cnn" | "resnet" | "vgg" | "inception" | "efficientnet"
WEIGHTS = "imagenet"    # "imagenet" or None
FINE_TUNE_BASE = False  # set True to unfreeze backbone later
input_shape = (*IMG_SIZE, 3)

if MODEL_NAME == "cnn":
    model = build_baseline_cnn(input_shape, num_classes)
elif MODEL_NAME == "resnet":
    model = build_resnet50(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
elif MODEL_NAME == "vgg":
    model = build_vgg16(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
elif MODEL_NAME == "inception":
    model = build_inceptionv3(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
elif MODEL_NAME == "efficientnet":
    model = build_efficientnetb0(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
else:
    raise ValueError("Unknown MODEL_NAME")

# =========================================
# Compile & Train
# =========================================
model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss=keras.losses.SparseCategoricalCrossentropy(),
    metrics=["accuracy"]
)

callbacks = [
    keras.callbacks.EarlyStopping(patience=4, restore_best_weights=True, monitor="val_accuracy"),
]

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=20,
    callbacks=callbacks
)

# ===== Evaluate on the held-out TEST set (matches second snippet practice) =====
test_loss, test_acc = model.evaluate(test_ds, verbose=0)
print(f"{model.name}  |  Test acc: {test_acc:.4f}  |  Test loss: {test_loss:.4f}")
# Out:
# Classes: ['brain_glioma', 'brain_menin', 'brain_tumor']
# Counts by split:
#  label  brain_glioma  brain_menin  brain_tumor
# split
# test            750          750          750
# train          3499         3499         3499
# val             750          750          750
# Epoch 1/20
# 2025-10-08 20:10:04.200278: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inefficientnetb0/block2b_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 1313/1313 [==============================] - 31s 17ms/step - loss: 1.1311 - accuracy: 0.3299 - val_loss: 1.1220 - val_accuracy: 0.3333
# Epoch 2/20
# 1313/1313 [==============================] - 24s 16ms/step - loss: 1.1249 - accuracy: 0.3340 - val_loss: 1.1014 - val_accuracy: 0.3333
# Epoch 3/20
# 1313/1313 [==============================] - 24s 16ms/step - loss: 1.1291 - accuracy: 0.3340 - val_loss: 1.1139 - val_accuracy: 0.3333
# Epoch 4/20
# 1313/1313 [==============================] - 24s 16ms/step - loss: 1.1241 - accuracy: 0.3398 - val_loss: 1.1082 - val_accuracy: 0.3333
# Epoch 5/20
# 1313/1313 [==============================] - 24s 16ms/step - loss: 1.1246 - accuracy: 0.3302 - val_loss: 1.1050 - val_accuracy: 0.4084
# Epoch 6/20
# 1313/1313 [==============================] - 24s 16ms/step - loss: 1.1282 - accuracy: 0.3353 - val_loss: 1.1031 - val_accuracy: 0.3333
# Epoch 7/20
# 1313/1313 [==============================] - 24s 16ms/step - loss: 1.1260 - accuracy: 0.3364 - val_loss: 1.1029 - val_accuracy: 0.3333
# Epoch 8/20
# 1313/1313 [==============================] - 24s 16ms/step - loss: 1.1250 - accuracy: 0.3371 - val_loss: 1.1134 - val_accuracy: 0.3333
# Epoch 9/20
# 1313/1313 [==============================] - 24s 16ms/step - loss: 1.1232 - accuracy: 0.3414 - val_loss: 1.1119 - val_accuracy: 0.4991
# Epoch 10/20
# 1313/1313 [==============================] - 24s 16ms/step - loss: 1.1258 - accuracy: 0.3370 - val_loss: 1.1005 - val_accuracy: 0.3364
# Epoch 11/20
# 1313/1313 [==============================] - 24s 16ms/step - loss: 1.1241 - accuracy: 0.3315 - val_loss: 1.1265 - val_accuracy: 0.3333
# Epoch 12/20
# 1313/1313 [==============================] - 24s 16ms/step - loss: 1.1256 - accuracy: 0.3278 - val_loss: 1.1010 - val_accuracy: 0.3333
# Epoch 13/20
# 1313/1313 [==============================] - 24s 16ms/step - loss: 1.1239 - accuracy: 0.3399 - val_loss: 1.1074 - val_accuracy: 0.3333
# efficientnetb0  |  Test acc: 0.4827  |  Test loss: 1.1120
