# %%
# Copied Code from Kaggle to import all of the data
import kagglehub

# Download latest version
dataset_path = kagglehub.dataset_download("obulisainaren/multi-cancer")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/obulisainaren/multi-cancer?dataset_version_number=3...
# 100%|██████████| 8.62G/8.62G [01:28<00:00, 105MB/s]
# Extracting files...
# Path to dataset files: /home/jovyan/.cache/kagglehub/datasets/obulisainaren/multi-cancer/versions/3

# %%
import os
import pandas as pd
import PIL
from PIL import Image
import numpy as np

dataset_path = "/home/jovyan/.cache/kagglehub/datasets/obulisainaren/multi-cancer/versions/3/Multi Cancer/Multi Cancer/Brain Cancer"

# loop through each class folder
classes = os.listdir(dataset_path)

# Store image paths + labels
data = []

for class_name in classes:
    class_folder = os.path.join(dataset_path, class_name)
    if os.path.isdir(class_folder):  # make sure it's a folder
        for img_file in os.listdir(class_folder):
            img_path = os.path.join(class_folder, img_file)
            data.append({"image_path": img_path, "label": class_name})

# Create dataframe
df = pd.DataFrame(data)

# Check sample
print(df.head())
print("Total images:", len(df))
print(df['label'].value_counts())
# Out:
#                                           image_path         label
# 0  /home/jovyan/.cache/kagglehub/datasets/obulisa...  brain_glioma
# 1  /home/jovyan/.cache/kagglehub/datasets/obulisa...  brain_glioma
# 2  /home/jovyan/.cache/kagglehub/datasets/obulisa...  brain_glioma
# 3  /home/jovyan/.cache/kagglehub/datasets/obulisa...  brain_glioma
# 4  /home/jovyan/.cache/kagglehub/datasets/obulisa...  brain_glioma
# Total images: 15000
# label
# brain_glioma    5000
# brain_menin     5000
# brain_tumor     5000
# Name: count, dtype: int64

# %%
ROOT_DIR = "/home/jovyan/.cache/kagglehub/datasets/obulisainaren/multi-cancer/versions/3/Multi Cancer/Multi Cancer/Brain Cancer"
number_of_img = {}
# Shows me the number of images in the Brain Cancer Directory 
for dir in os.listdir(ROOT_DIR): 
    number_of_img[dir] = len(os.listdir(os.path.join(ROOT_DIR, dir)))

number_of_img.items()
# Out:
# dict_items([('brain_glioma', 5000), ('brain_menin', 5000), ('brain_tumor', 5000)])

# %%
# Need to get the sizes of the images and make sure they are all the same size 
image_sizes = {}
ROOT_DIR = "/home/jovyan/.cache/kagglehub/datasets/obulisainaren/multi-cancer/versions/3/Multi Cancer/Multi Cancer/Brain Cancer/brain_glioma"

for filename in os.listdir(ROOT_DIR):
    if filename.lower().endswith((".jpg")):
        img_path = os.path.join(ROOT_DIR, filename)
        try: 
            with Image.open(img_path) as img: 
                image_sizes[filename] = img.size # width and height 
        except Exception as e: 
            print(f"Could not open {filename}: {e}")

for k, v in list(image_sizes.items())[:100]:
    print(k, v)
# Out:
# brain_glioma_0001.jpg (512, 512)
# brain_glioma_0002.jpg (512, 512)
# brain_glioma_0003.jpg (512, 512)
# brain_glioma_0004.jpg (512, 512)
# brain_glioma_0005.jpg (512, 512)
# brain_glioma_0006.jpg (512, 512)
# brain_glioma_0007.jpg (512, 512)
# brain_glioma_0008.jpg (512, 512)
# brain_glioma_0009.jpg (512, 512)
# brain_glioma_0010.jpg (512, 512)
# brain_glioma_0011.jpg (512, 512)
# brain_glioma_0012.jpg (512, 512)
# brain_glioma_0013.jpg (512, 512)
# brain_glioma_0014.jpg (512, 512)
# brain_glioma_0015.jpg (512, 512)
# brain_glioma_0016.jpg (512, 512)
# brain_glioma_0017.jpg (512, 512)
# brain_glioma_0018.jpg (512, 512)
# brain_glioma_0019.jpg (512, 512)
# brain_glioma_0020.jpg (512, 512)
# brain_glioma_0021.jpg (512, 512)
# brain_glioma_0022.jpg (512, 512)
# brain_glioma_0023.jpg (512, 512)
# brain_glioma_0024.jpg (512, 512)
# brain_glioma_0025.jpg (512, 512)
# brain_glioma_0026.jpg (512, 512)
# brain_glioma_0027.jpg (512, 512)
# brain_glioma_0028.jpg (512, 512)
# brain_glioma_0029.jpg (512, 512)
# brain_glioma_0030.jpg (512, 512)
# brain_glioma_0031.jpg (512, 512)
# brain_glioma_0032.jpg (512, 512)
# brain_glioma_0033.jpg (512, 512)
# brain_glioma_0034.jpg (512, 512)
# brain_glioma_0035.jpg (512, 512)
# brain_glioma_0036.jpg (512, 512)
# brain_glioma_0037.jpg (512, 512)
# brain_glioma_0038.jpg (512, 512)
# brain_glioma_0039.jpg (512, 512)
# brain_glioma_0040.jpg (512, 512)
# brain_glioma_0041.jpg (512, 512)
# brain_glioma_0042.jpg (512, 512)
# brain_glioma_0043.jpg (512, 512)
# brain_glioma_0044.jpg (512, 512)
# brain_glioma_0045.jpg (512, 512)
# brain_glioma_0046.jpg (512, 512)
# brain_glioma_0047.jpg (512, 512)
# brain_glioma_0048.jpg (512, 512)
# brain_glioma_0049.jpg (512, 512)
# brain_glioma_0050.jpg (512, 512)
# brain_glioma_0051.jpg (512, 512)
# brain_glioma_0052.jpg (512, 512)
# brain_glioma_0053.jpg (512, 512)
# brain_glioma_0054.jpg (512, 512)
# brain_glioma_0055.jpg (512, 512)
# brain_glioma_0056.jpg (512, 512)
# brain_glioma_0057.jpg (512, 512)
# brain_glioma_0058.jpg (512, 512)
# brain_glioma_0059.jpg (512, 512)
# brain_glioma_0060.jpg (512, 512)
# brain_glioma_0061.jpg (512, 512)
# brain_glioma_0062.jpg (512, 512)
# brain_glioma_0063.jpg (512, 512)
# brain_glioma_0064.jpg (512, 512)
# brain_glioma_0065.jpg (512, 512)
# brain_glioma_0066.jpg (512, 512)
# brain_glioma_0067.jpg (512, 512)
# brain_glioma_0068.jpg (512, 512)
# brain_glioma_0069.jpg (512, 512)
# brain_glioma_0070.jpg (512, 512)
# brain_glioma_0071.jpg (512, 512)
# brain_glioma_0072.jpg (512, 512)
# brain_glioma_0073.jpg (512, 512)
# brain_glioma_0074.jpg (512, 512)
# brain_glioma_0075.jpg (512, 512)
# brain_glioma_0076.jpg (512, 512)
# brain_glioma_0077.jpg (512, 512)
# brain_glioma_0078.jpg (512, 512)
# brain_glioma_0079.jpg (512, 512)
# brain_glioma_0080.jpg (512, 512)
# brain_glioma_0081.jpg (512, 512)
# brain_glioma_0082.jpg (512, 512)
# brain_glioma_0083.jpg (512, 512)
# brain_glioma_0084.jpg (512, 512)
# brain_glioma_0085.jpg (512, 512)
# brain_glioma_0086.jpg (512, 512)
# brain_glioma_0087.jpg (512, 512)
# brain_glioma_0088.jpg (512, 512)
# brain_glioma_0089.jpg (512, 512)
# brain_glioma_0090.jpg (512, 512)
# brain_glioma_0091.jpg (512, 512)
# brain_glioma_0092.jpg (512, 512)
# brain_glioma_0093.jpg (512, 512)
# brain_glioma_0094.jpg (512, 512)
# brain_glioma_0095.jpg (512, 512)
# brain_glioma_0096.jpg (512, 512)
# brain_glioma_0097.jpg (512, 512)
# brain_glioma_0098.jpg (512, 512)
# brain_glioma_0099.jpg (512, 512)
# brain_glioma_0100.jpg (512, 512)

# %%
from collections import Counter

size_counts = Counter(image_sizes.values())
print(size_counts)
# Out:
# Counter({(512, 512): 5000})

# %%
# CNN 
# !pip install tensorflow_datasets
# Out:
# Collecting tensorflow_datasets
#   Obtaining dependency information for tensorflow_datasets from https://files.pythonhosted.org/packages/16/e0/657192dbc03636532ccbd5c90669d31a65187365b99ba685db36bb31dd67/tensorflow_datasets-4.9.9-py3-none-any.whl.metadata
#   Downloading tensorflow_datasets-4.9.9-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: absl-py in /opt/conda/lib/python3.11/site-packages (from tensorflow_datasets) (2.0.0)
# Collecting array_record>=0.5.0 (from tensorflow_datasets)
#   Obtaining dependency information for array_record>=0.5.0 from https://files.pythonhosted.org/packages/b6/cc/0c24c7325ecad65c114f03b765069b9ce45664148c4d39fa6e370d0e95c0/array_record-0.8.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata
#   Downloading array_record-0.8.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: dm-tree in /opt/conda/lib/python3.11/site-packages (from tensorflow_datasets) (0.1.8)
# Collecting etils[edc,enp,epath,epy,etree]>=1.9.1 (from tensorflow_datasets)
#   Obtaining dependency information for etils[edc,enp,epath,epy,etree]>=1.9.1 from https://files.pythonhosted.org/packages/e7/98/87b5946356095738cb90a6df7b35ff69ac5750f6e783d5fbcc5cb3b6cbd7/etils-1.13.0-py3-none-any.whl.metadata
#   Downloading etils-1.13.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting immutabledict (from tensorflow_datasets)
#   Obtaining dependency information for immutabledict from https://files.pythonhosted.org/packages/59/56/25ca7b848164b7d93dbd5fc97dd7751700c93e324fe854afbeb562ee2f98/immutabledict-4.2.1-py3-none-any.whl.metadata
#   Downloading immutabledict-4.2.1-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (from tensorflow_datasets) (1.24.3)
# Collecting promise (from tensorflow_datasets)
#   Downloading promise-2.3.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: protobuf>=3.20 in /opt/conda/lib/python3.11/site-packages (from tensorflow_datasets) (4.23.3)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.11/site-packages (from tensorflow_datasets) (5.9.5)
# Requirement already satisfied: pyarrow in /opt/conda/lib/python3.11/site-packages (from tensorflow_datasets) (13.0.0)
# Requirement already satisfied: requests>=2.19.0 in /opt/conda/lib/python3.11/site-packages (from tensorflow_datasets) (2.31.0)
# Collecting simple_parsing (from tensorflow_datasets)
#   Obtaining dependency information for simple_parsing from https://files.pythonhosted.org/packages/4f/9c/e9ea38750027a6de3e3c5e68a19fda0e7b0cd3db8045f30d0f6bc113b911/simple_parsing-0.1.7-py3-none-any.whl.metadata
#   Downloading simple_parsing-0.1.7-py3-none-any.whl.metadata (7.3 kB)
# Collecting tensorflow-metadata (from tensorflow_datasets)
#   Obtaining dependency information for tensorflow-metadata from https://files.pythonhosted.org/packages/ec/bf/443fc7c325e59b9016f710bc7f6b0574e73eca7b789a6a6a2054ca77e887/tensorflow_metadata-1.17.2-py3-none-any.whl.metadata
#   Downloading tensorflow_metadata-1.17.2-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: termcolor in /opt/conda/lib/python3.11/site-packages (from tensorflow_datasets) (2.3.0)
# Collecting toml (from tensorflow_datasets)
#   Obtaining dependency information for toml from https://files.pythonhosted.org/packages/44/6f/7120676b6d73228c96e17f1f794d8ab046fc910d781c8d151120c3f1569e/toml-0.10.2-py2.py3-none-any.whl.metadata
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.11/site-packages (from tensorflow_datasets) (4.66.1)
# Requirement already satisfied: wrapt in /opt/conda/lib/python3.11/site-packages (from tensorflow_datasets) (1.15.0)
# Collecting einops (from etils[edc,enp,epath,epy,etree]>=1.9.1->tensorflow_datasets)
#   Obtaining dependency information for einops from https://files.pythonhosted.org/packages/87/62/9773de14fe6c45c23649e98b83231fffd7b9892b6cf863251dc2afa73643/einops-0.8.1-py3-none-any.whl.metadata
#   Downloading einops-0.8.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.11/site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1->tensorflow_datasets) (2023.9.0)
# Requirement already satisfied: importlib_resources in /opt/conda/lib/python3.11/site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1->tensorflow_datasets) (6.0.1)
# Requirement already satisfied: typing_extensions in /opt/conda/lib/python3.11/site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1->tensorflow_datasets) (4.5.0)
# Requirement already satisfied: zipp in /opt/conda/lib/python3.11/site-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1->tensorflow_datasets) (3.16.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests>=2.19.0->tensorflow_datasets) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests>=2.19.0->tensorflow_datasets) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests>=2.19.0->tensorflow_datasets) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests>=2.19.0->tensorflow_datasets) (2023.7.22)
# Requirement already satisfied: six in /opt/conda/lib/python3.11/site-packages (from promise->tensorflow_datasets) (1.16.0)
# Collecting docstring-parser<1.0,>=0.15 (from simple_parsing->tensorflow_datasets)
#   Obtaining dependency information for docstring-parser<1.0,>=0.15 from https://files.pythonhosted.org/packages/55/e2/2537ebcff11c1ee1ff17d8d0b6f4db75873e3b0fb32c2d4a2ee31ecb310a/docstring_parser-0.17.0-py3-none-any.whl.metadata
#   Downloading docstring_parser-0.17.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting googleapis-common-protos<2,>=1.56.4 (from tensorflow-metadata->tensorflow_datasets)
#   Obtaining dependency information for googleapis-common-protos<2,>=1.56.4 from https://files.pythonhosted.org/packages/86/f1/62a193f0227cf15a920390abe675f386dec35f7ae3ffe6da582d3ade42c7/googleapis_common_protos-1.70.0-py3-none-any.whl.metadata
#   Downloading googleapis_common_protos-1.70.0-py3-none-any.whl.metadata (9.3 kB)
# Collecting protobuf>=3.20 (from tensorflow_datasets)
#   Obtaining dependency information for protobuf>=3.20 from https://files.pythonhosted.org/packages/40/01/2e730bd1c25392fc32e3268e02446f0d77cb51a2c3a8486b1798e34d5805/protobuf-6.32.0-cp39-abi3-manylinux2014_x86_64.whl.metadata
#   Downloading protobuf-6.32.0-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Downloading tensorflow_datasets-4.9.9-py3-none-any.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 34.4 MB/s eta 0:00:00:00:01
# Downloading array_record-0.8.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 27.6 MB/s eta 0:00:00:00:01
# Downloading immutabledict-4.2.1-py3-none-any.whl (4.7 kB)
# Downloading simple_parsing-0.1.7-py3-none-any.whl (112 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.8/112.8 kB 983.4 kB/s eta 0:00:0000:01
# Downloading tensorflow_metadata-1.17.2-py3-none-any.whl (31 kB)
# Downloading protobuf-6.32.0-cp39-abi3-manylinux2014_x86_64.whl (322 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.0/322.0 kB 3.8 MB/s eta 0:00:00:00:01
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading docstring_parser-0.17.0-py3-none-any.whl (36 kB)
# Downloading googleapis_common_protos-1.70.0-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.5/294.5 kB 2.7 MB/s eta 0:00:00ta 0:00:01
# Downloading einops-0.8.1-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 kB 1.6 MB/s eta 0:00:00eta 0:00:01
# Downloading etils-1.13.0-py3-none-any.whl (170 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.6/170.6 kB 1.1 MB/s eta 0:00:00ta 0:00:01
# Building wheels for collected packages: promise
#   Building wheel for promise (setup.py) ... done
#   Created wheel for promise: filename=promise-2.3-py3-none-any.whl size=21484 sha256=f0cd5ceccc26f1e9a884d6a51a63aa0942b8db2f1e8bb3072f909f78d64f5dd5
#   Stored in directory: /home/jovyan/.cache/pip/wheels/90/74/b1/9b54c896b8d9409e9268329d4d45ede8a8040abe91c8879932
# Successfully built promise
# Installing collected packages: toml, protobuf, promise, immutabledict, etils, einops, docstring-parser, simple_parsing, googleapis-common-protos, tensorflow-metadata, array_record, tensorflow_datasets
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.23.3
#     Uninstalling protobuf-4.23.3:
#       Successfully uninstalled protobuf-4.23.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.13.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 6.32.0 which is incompatible.
# Successfully installed array_record-0.8.1 docstring-parser-0.17.0 einops-0.8.1 etils-1.13.0 googleapis-common-protos-1.70.0 immutabledict-4.2.1 promise-2.3 protobuf-6.32.0 simple_parsing-0.1.7 tensorflow-metadata-1.17.2 tensorflow_datasets-4.9.9 toml-0.10.2

# %%
import os, random, pandas as pd, tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.utils import shuffle

# ===============================
# Constants & Reproducibility
# ===============================
SEED = 1337
IMG_SIZE = (256, 256)
BATCH_SIZE = 8
AUTOTUNE = tf.data.AUTOTUNE
random.seed(SEED); tf.random.set_seed(SEED)

# ===============================
# CSV manifest (fixed split)
# ===============================
CSV_PATH = "/home/jovyan/Independent/split_manifest.csv"
BASE_DIR = None  # set a base folder only if your CSV has relative paths

manifest = pd.read_csv(CSV_PATH)

if BASE_DIR is not None:
    manifest["path"] = manifest["path"].apply(
        lambda p: p if os.path.isabs(p) else os.path.join(BASE_DIR, p)
    )

# Stable label mapping
labels_sorted = sorted(manifest["label"].unique())
label_to_int  = {l:i for i,l in enumerate(labels_sorted)}
int_to_label  = {v:k for k,v in label_to_int.items()}
num_classes   = len(labels_sorted)
print("Classes:", labels_sorted)

# Split dataframes
df_train = manifest[manifest["split"]=="train"].copy()
df_val   = manifest[manifest["split"]=="val"].copy()
df_test  = manifest[manifest["split"]=="test"].copy()

print("Counts by split:\n", manifest.groupby(["split","label"]).size().unstack(fill_value=0))

# ===============================
# tf.data from CSV (non-leaking)
# ===============================
def _decode(path):
    img = tf.io.read_file(path)
    # JPGs: decode_jpeg is a bit faster than generic decode_image
    img = tf.io.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, IMG_SIZE, antialias=True)
    img = tf.cast(img, tf.float32)  # 0..255; we'll rescale in the model
    return img

def make_ds(df, split, batch_size=BATCH_SIZE, seed=SEED):
    if split == "train":
        df = shuffle(df, random_state=seed)
    paths  = df["path"].tolist()
    labels = [label_to_int[l] for l in df["label"]]
    ds = tf.data.Dataset.from_tensor_slices((paths, labels))
    def _load(p, y):
        return _decode(p), tf.cast(y, tf.int32)
    ds = ds.map(_load, num_parallel_calls=AUTOTUNE)
    if split == "train":
        ds = ds.shuffle(buffer_size=len(paths), seed=seed, reshuffle_each_iteration=True)
    return ds.batch(batch_size).prefetch(AUTOTUNE)

train_ds = make_ds(df_train, "train")
val_ds   = make_ds(df_val,   "val")
test_ds  = make_ds(df_test,  "test")

# ===============================
# Data augmentation (train-only via model)
# ===============================
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.05),
    layers.RandomZoom(0.1),
], name="augment")

# ===============================
# Custom CNN (a bit stronger baseline)
# ===============================
def conv_block(x, filters, dropout=0.0):
    x = layers.Conv2D(filters, 3, padding="same", use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Conv2D(filters, 3, padding="same", use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.MaxPooling2D()(x)
    if dropout > 0:
        x = layers.Dropout(dropout)(x)
    return x

def build_custom_cnn(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = layers.Rescaling(1./255)(x)  # keep preprocessing inside the model

    x = conv_block(x, 32,  dropout=0.10)
    x = conv_block(x, 64,  dropout=0.15)
    x = conv_block(x, 128, dropout=0.20)

    x = layers.Conv2D(256, 3, padding="same", use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.GlobalAveragePooling2D()(x)

    x = layers.Dense(256, activation="relu")(x)
    x = layers.Dropout(0.5)(x)

    outputs = layers.Dense(num_classes, activation="softmax")(x)
    return keras.Model(inputs, outputs, name="custom_cnn")

model = build_custom_cnn(IMG_SIZE + (3,), num_classes)

# ===============================
# Compile
# ===============================
model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss=keras.losses.SparseCategoricalCrossentropy(),
    metrics=["accuracy"]
)

model.summary()

# ===============================
# Train
# ===============================
callbacks = [
    keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True, monitor="val_accuracy"),
    keras.callbacks.ModelCheckpoint("best_custom_cnn.keras", monitor="val_accuracy", save_best_only=True),
    keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=2, min_lr=1e-6),
]

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=30,
    callbacks=callbacks
)

# ===============================
# Evaluate on test set
# ===============================
test_loss, test_acc = model.evaluate(test_ds, verbose=0)
print(f"Test accuracy: {test_acc:.4f}  |  loss: {test_loss:.4f}")

# %%
# ResNet
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pathlib

# ===== Paths & setup =====
DATA_DIR = "/home/jovyan/.cache/kagglehub/datasets/obulisainaren/multi-cancer/versions/3/Multi Cancer/Multi Cancer/Brain Cancer"   
IMG_SIZE = (256, 256)  
BATCH_SIZE = 8   # adjust if OOM
SEED = 1337

data_dir = pathlib.Path(DATA_DIR)

# ===== Dataset split =====
train_ds = keras.utils.image_dataset_from_directory(
    data_dir, labels="inferred", label_mode="int",
    image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    validation_split=0.15, subset="training", seed=SEED
)

valtest_ds = keras.utils.image_dataset_from_directory(
    data_dir, labels="inferred", label_mode="int",
    image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    validation_split=0.15, subset="validation", seed=SEED
)

# Split val/test
val_batches = int(0.5 * tf.data.experimental.cardinality(valtest_ds).numpy())
val_ds = valtest_ds.take(val_batches)
test_ds = valtest_ds.skip(val_batches)

class_names = train_ds.class_names
num_classes = len(class_names)
print("Classes:", class_names)

# ===== Prefetch =====
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.shuffle(1000).prefetch(AUTOTUNE)
val_ds   = val_ds.prefetch(AUTOTUNE)
test_ds  = test_ds.prefetch(AUTOTUNE)

# ===== Data augmentation =====
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.05),
    layers.RandomZoom(0.1),
])

# ===== Residual block =====
def residual_block(x, filters, downsample=False):
    shortcut = x

    # First conv
    x = layers.Conv2D(filters, 3, padding="same", strides=(2 if downsample else 1),
                      kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)

    # Second conv
    x = layers.Conv2D(filters, 3, padding="same", kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)

    # Match shortcut shape if downsampling
    if downsample:
        shortcut = layers.Conv2D(filters, 1, strides=2, padding="same",
                                 kernel_initializer="he_normal")(shortcut)
        shortcut = layers.BatchNormalization()(shortcut)

    # Add skip connection
    x = layers.Add()([x, shortcut])
    x = layers.ReLU()(x)
    return x

# ===== Baseline ResNet model =====
def build_resnet(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = layers.Rescaling(1./255)(x)

    # Stem
    x = layers.Conv2D(32, 7, strides=2, padding="same", kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    x = layers.ReLU()(x)
    x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

    # Residual blocks
    x = residual_block(x, 32)
    x = residual_block(x, 32)
    x = residual_block(x, 64, downsample=True)
    x = residual_block(x, 64)
    x = residual_block(x, 128, downsample=True)
    x = residual_block(x, 128)

    # Classifier head
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)

    model = keras.Model(inputs, outputs)
    return model

model = build_resnet(IMG_SIZE + (3,), num_classes)

model.compile(
    optimizer="adam",
    loss=keras.losses.SparseCategoricalCrossentropy(),
    metrics=["accuracy"]
)

model.summary()

# ===== Train =====
callbacks = [
    keras.callbacks.EarlyStopping(patience=4, restore_best_weights=True, monitor="val_accuracy"),
]

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=20,
    callbacks=callbacks
)

# ===== Evaluate =====
test_loss, test_acc = model.evaluate(test_ds)
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# 2025-09-12 21:28:12.782573: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-09-12 21:28:12.965920: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-09-12 21:28:14.011175: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Found 15000 files belonging to 3 classes.
# Using 12750 files for training.
# Found 15000 files belonging to 3 classes.
# Using 2250 files for validation.
# Classes: ['brain_glioma', 'brain_menin', 'brain_tumor']
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  sequential (Sequential)     (None, 256, 256, 3)          0         ['input_1[0][0]']
#
#  rescaling (Rescaling)       (None, 256, 256, 3)          0         ['sequential[0][0]']
#
#  conv2d (Conv2D)             (None, 128, 128, 32)         4736      ['rescaling[0][0]']
#
#  batch_normalization (Batch  (None, 128, 128, 32)         128       ['conv2d[0][0]']
#  Normalization)
#
#  re_lu (ReLU)                (None, 128, 128, 32)         0         ['batch_normalization[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 64, 64, 32)           0         ['re_lu[0][0]']
#  D)
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 32)           9248      ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (Bat  (None, 64, 64, 32)           128       ['conv2d_1[0][0]']
#  chNormalization)
#
#  re_lu_1 (ReLU)              (None, 64, 64, 32)           0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 32)           9248      ['re_lu_1[0][0]']
#
#  batch_normalization_2 (Bat  (None, 64, 64, 32)           128       ['conv2d_2[0][0]']
#  chNormalization)
#
#  add (Add)                   (None, 64, 64, 32)           0         ['batch_normalization_2[0][0]'
#                                                                     , 'max_pooling2d[0][0]']
#
#  re_lu_2 (ReLU)              (None, 64, 64, 32)           0         ['add[0][0]']
#
#  conv2d_3 (Conv2D)           (None, 64, 64, 32)           9248      ['re_lu_2[0][0]']
#
#  batch_normalization_3 (Bat  (None, 64, 64, 32)           128       ['conv2d_3[0][0]']
#  chNormalization)
#
#  re_lu_3 (ReLU)              (None, 64, 64, 32)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 32)           9248      ['re_lu_3[0][0]']
#
#  batch_normalization_4 (Bat  (None, 64, 64, 32)           128       ['conv2d_4[0][0]']
#  chNormalization)
#
#  add_1 (Add)                 (None, 64, 64, 32)           0         ['batch_normalization_4[0][0]'
#                                                                     , 're_lu_2[0][0]']
#
#  re_lu_4 (ReLU)              (None, 64, 64, 32)           0         ['add_1[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 32, 32, 64)           18496     ['re_lu_4[0][0]']
#
#  batch_normalization_5 (Bat  (None, 32, 32, 64)           256       ['conv2d_5[0][0]']
#  chNormalization)
#
#  re_lu_5 (ReLU)              (None, 32, 32, 64)           0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 32, 32, 64)           36928     ['re_lu_5[0][0]']
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 64)           2112      ['re_lu_4[0][0]']
#
#  batch_normalization_6 (Bat  (None, 32, 32, 64)           256       ['conv2d_6[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 32, 32, 64)           256       ['conv2d_7[0][0]']
#  chNormalization)
#
#  add_2 (Add)                 (None, 32, 32, 64)           0         ['batch_normalization_6[0][0]'
#                                                                     , 'batch_normalization_7[0][0]
#                                                                     ']
#
#  re_lu_6 (ReLU)              (None, 32, 32, 64)           0         ['add_2[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 32, 32, 64)           36928     ['re_lu_6[0][0]']
#
#  batch_normalization_8 (Bat  (None, 32, 32, 64)           256       ['conv2d_8[0][0]']
#  chNormalization)
#
#  re_lu_7 (ReLU)              (None, 32, 32, 64)           0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 64)           36928     ['re_lu_7[0][0]']
#
#  batch_normalization_9 (Bat  (None, 32, 32, 64)           256       ['conv2d_9[0][0]']
#  chNormalization)
#
#  add_3 (Add)                 (None, 32, 32, 64)           0         ['batch_normalization_9[0][0]'
#                                                                     , 're_lu_6[0][0]']
#
#  re_lu_8 (ReLU)              (None, 32, 32, 64)           0         ['add_3[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 128)          73856     ['re_lu_8[0][0]']
#
#  batch_normalization_10 (Ba  (None, 16, 16, 128)          512       ['conv2d_10[0][0]']
#  tchNormalization)
#
#  re_lu_9 (ReLU)              (None, 16, 16, 128)          0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  conv2d_11 (Conv2D)          (None, 16, 16, 128)          147584    ['re_lu_9[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 16, 16, 128)          8320      ['re_lu_8[0][0]']
#
#  batch_normalization_11 (Ba  (None, 16, 16, 128)          512       ['conv2d_11[0][0]']
#  tchNormalization)
#
#  batch_normalization_12 (Ba  (None, 16, 16, 128)          512       ['conv2d_12[0][0]']
#  tchNormalization)
#
#  add_4 (Add)                 (None, 16, 16, 128)          0         ['batch_normalization_11[0][0]
#                                                                     ',
#                                                                      'batch_normalization_12[0][0]
#                                                                     ']
#
#  re_lu_10 (ReLU)             (None, 16, 16, 128)          0         ['add_4[0][0]']
#
#  conv2d_13 (Conv2D)          (None, 16, 16, 128)          147584    ['re_lu_10[0][0]']
#
#  batch_normalization_13 (Ba  (None, 16, 16, 128)          512       ['conv2d_13[0][0]']
#  tchNormalization)
#
#  re_lu_11 (ReLU)             (None, 16, 16, 128)          0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  conv2d_14 (Conv2D)          (None, 16, 16, 128)          147584    ['re_lu_11[0][0]']
#
#  batch_normalization_14 (Ba  (None, 16, 16, 128)          512       ['conv2d_14[0][0]']
#  tchNormalization)
#
#  add_5 (Add)                 (None, 16, 16, 128)          0         ['batch_normalization_14[0][0]
#                                                                     ',
#                                                                      're_lu_10[0][0]']
#
#  re_lu_12 (ReLU)             (None, 16, 16, 128)          0         ['add_5[0][0]']
#
#  global_average_pooling2d (  (None, 128)                  0         ['re_lu_12[0][0]']
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 128)                  0         ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense (Dense)               (None, 3)                    387       ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 702915 (2.68 MB)
# Trainable params: 700675 (2.67 MB)
# Non-trainable params: 2240 (8.75 KB)
# __________________________________________________________________________________________________
# Epoch 1/20
# 2025-09-12 21:28:31.341615: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 369 of 1000
# 2025-09-12 21:28:41.325682: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 852 of 1000
#    1/1594 [..............................] - ETA: 11:56:54 - loss: 2.1403 - accuracy: 0.3750
# 2025-09-12 21:28:43.859408: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] Shuffle buffer filled.
# 1594/1594 [==============================] - 157s 81ms/step - loss: 0.6156 - accuracy: 0.7500 - val_loss: 0.6567 - val_accuracy: 0.7261
# Epoch 2/20
# 1594/1594 [==============================] - 128s 79ms/step - loss: 0.3964 - accuracy: 0.8494 - val_loss: 0.7659 - val_accuracy: 0.6791
# Epoch 3/20
# 1594/1594 [==============================] - 128s 79ms/step - loss: 0.3058 - accuracy: 0.8856 - val_loss: 3.3846 - val_accuracy: 0.5984
# Epoch 4/20
# 1594/1594 [==============================] - 128s 79ms/step - loss: 0.2599 - accuracy: 0.9041 - val_loss: 0.2040 - val_accuracy: 0.9211
# Epoch 5/20
# 1594/1594 [==============================] - 128s 79ms/step - loss: 0.2032 - accuracy: 0.9282 - val_loss: 11.4641 - val_accuracy: 0.3599
# Epoch 6/20
# 1594/1594 [==============================] - 128s 79ms/step - loss: 0.1817 - accuracy: 0.9325 - val_loss: 0.9922 - val_accuracy: 0.7252
# Epoch 7/20
# 1594/1594 [==============================] - 128s 79ms/step - loss: 0.1518 - accuracy: 0.9469 - val_loss: 0.2766 - val_accuracy: 0.8697
# Epoch 8/20
# 1594/1594 [==============================] - 128s 79ms/step - loss: 0.1363 - accuracy: 0.9538 - val_loss: 0.4050 - val_accuracy: 0.8280
# 141/141 [==============================] - 4s 26ms/step - loss: 0.1979 - accuracy: 0.9278
# Test accuracy: 0.9278

# %%
# VGGNet 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pathlib

# ===== Paths & setup =====
DATA_DIR = "/home/jovyan/.cache/kagglehub/datasets/obulisainaren/multi-cancer/versions/3/Multi Cancer/Multi Cancer/Brain Cancer"  
IMG_SIZE = (256, 256)  
BATCH_SIZE = 8        # lower if you hit OOM
SEED = 1337

data_dir = pathlib.Path(DATA_DIR)

# ===== Dataset split: train (70%), val (15%), test (15%) =====
train_ds = keras.utils.image_dataset_from_directory(
    data_dir, labels="inferred", label_mode="int",
    image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    validation_split=0.15, subset="training", seed=SEED
)
valtest_ds = keras.utils.image_dataset_from_directory(
    data_dir, labels="inferred", label_mode="int",
    image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    validation_split=0.15, subset="validation", seed=SEED
)

# Split val/test
val_batches = int(0.5 * tf.data.experimental.cardinality(valtest_ds).numpy())
val_ds = valtest_ds.take(val_batches)
test_ds = valtest_ds.skip(val_batches)

class_names = train_ds.class_names
num_classes = len(class_names)
print("Classes:", class_names)

# ===== Prefetch for performance =====
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.shuffle(1000).prefetch(AUTOTUNE)
val_ds   = val_ds.prefetch(AUTOTUNE)
test_ds  = test_ds.prefetch(AUTOTUNE)

# ===== Data augmentation =====
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.05),
    layers.RandomZoom(0.1),
])

# ===== VGG-style block helper =====
def vgg_block(x, filters, convs=2):
    for _ in range(convs):
        x = layers.Conv2D(filters, 3, padding="same", activation="relu",
                          kernel_initializer="he_normal")(x)
    x = layers.MaxPooling2D(pool_size=2)(x)
    return x

# ===== Baseline VGG-style model (roughly VGG11/VGG13 sized) =====
def build_vgg(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = layers.Rescaling(1./255)(x)

    # VGG-style feature extractor
    x = vgg_block(x, 32, convs=1)   # Block 1
    x = vgg_block(x, 64, convs=1)   # Block 2
    x = vgg_block(x, 128, convs=2)  # Block 3
    x = vgg_block(x, 256, convs=2)  # Block 4

    # Classifier head
    x = layers.Flatten()(x)
    x = layers.Dense(256, activation="relu")(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)

    model = keras.Model(inputs, outputs)
    return model

model = build_vgg(IMG_SIZE + (3,), num_classes)

model.compile(
    optimizer="adam",
    loss=keras.losses.SparseCategoricalCrossentropy(),
    metrics=["accuracy"]
)

model.summary()

# ===== Train =====
callbacks = [
    keras.callbacks.EarlyStopping(patience=4, restore_best_weights=True, monitor="val_accuracy"),
]

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=20,
    callbacks=callbacks
)

# ===== Evaluate =====
test_loss, test_acc = model.evaluate(test_ds)
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# Found 15000 files belonging to 3 classes.
# Using 12750 files for training.
# Found 15000 files belonging to 3 classes.
# Using 2250 files for validation.
# Classes: ['brain_glioma', 'brain_menin', 'brain_tumor']
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  sequential_1 (Sequential)   (None, 256, 256, 3)       0
#
#  rescaling_1 (Rescaling)     (None, 256, 256, 3)       0
#
#  conv2d_15 (Conv2D)          (None, 256, 256, 32)      896
#
#  max_pooling2d_1 (MaxPoolin  (None, 128, 128, 32)      0
#  g2D)
#
#  conv2d_16 (Conv2D)          (None, 128, 128, 64)      18496
#
#  max_pooling2d_2 (MaxPoolin  (None, 64, 64, 64)        0
#  g2D)
#
#  conv2d_17 (Conv2D)          (None, 64, 64, 128)       73856
#
#  conv2d_18 (Conv2D)          (None, 64, 64, 128)       147584
#
#  max_pooling2d_3 (MaxPoolin  (None, 32, 32, 128)       0
#  g2D)
#
#  conv2d_19 (Conv2D)          (None, 32, 32, 256)       295168
#
#  conv2d_20 (Conv2D)          (None, 32, 32, 256)       590080
#
#  max_pooling2d_4 (MaxPoolin  (None, 16, 16, 256)       0
#  g2D)
#
#  flatten (Flatten)           (None, 65536)             0
#
#  dense_1 (Dense)             (None, 256)               16777472
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 3)                 771
#
# =================================================================
# Total params: 17904323 (68.30 MB)
# Trainable params: 17904323 (68.30 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 1594/1594 [==============================] - 313s 194ms/step - loss: 0.7347 - accuracy: 0.6949 - val_loss: 0.5072 - val_accuracy: 0.8005
# Epoch 2/20
# 1594/1594 [==============================] - 311s 194ms/step - loss: 0.5127 - accuracy: 0.7937 - val_loss: 0.3942 - val_accuracy: 0.8493
# Epoch 3/20
# 1594/1594 [==============================] - 312s 195ms/step - loss: 0.4137 - accuracy: 0.8372 - val_loss: 0.2770 - val_accuracy: 0.8963
# Epoch 4/20
# 1594/1594 [==============================] - 311s 194ms/step - loss: 0.3491 - accuracy: 0.8654 - val_loss: 0.2316 - val_accuracy: 0.9176
# Epoch 5/20
# 1594/1594 [==============================] - 312s 194ms/step - loss: 0.2986 - accuracy: 0.8863 - val_loss: 0.2115 - val_accuracy: 0.9211
# Epoch 6/20
# 1594/1594 [==============================] - 313s 195ms/step - loss: 0.2660 - accuracy: 0.9024 - val_loss: 0.2123 - val_accuracy: 0.9087
# Epoch 7/20
# 1594/1594 [==============================] - 313s 195ms/step - loss: 0.2289 - accuracy: 0.9100 - val_loss: 0.2041 - val_accuracy: 0.9300
# Epoch 8/20
# 1594/1594 [==============================] - 312s 195ms/step - loss: 0.2083 - accuracy: 0.9235 - val_loss: 0.1884 - val_accuracy: 0.9229
# Epoch 9/20
# 1594/1594 [==============================] - 313s 195ms/step - loss: 0.1858 - accuracy: 0.9328 - val_loss: 0.1106 - val_accuracy: 0.9601
# Epoch 10/20
# 1594/1594 [==============================] - 314s 196ms/step - loss: 0.1767 - accuracy: 0.9351 - val_loss: 0.1329 - val_accuracy: 0.9548
# Epoch 11/20
# 1594/1594 [==============================] - 315s 196ms/step - loss: 0.1741 - accuracy: 0.9357 - val_loss: 0.1434 - val_accuracy: 0.9459
# Epoch 12/20
# 1594/1594 [==============================] - 314s 196ms/step - loss: 0.1593 - accuracy: 0.9442 - val_loss: 0.1318 - val_accuracy: 0.9566
# Epoch 13/20
# 1594/1594 [==============================] - 314s 196ms/step - loss: 0.1633 - accuracy: 0.9419 - val_loss: 0.1058 - val_accuracy: 0.9601
# 141/141 [==============================] - 8s 57ms/step - loss: 0.1251 - accuracy: 0.9519
# Test accuracy: 0.9519

# %%
# GoogLeNet 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pathlib

# ===== Paths & setup =====
DATA_DIR = "/home/jovyan/.cache/kagglehub/datasets/obulisainaren/multi-cancer/versions/3/Multi Cancer/Multi Cancer/Brain Cancer"
IMG_SIZE = (256, 256)  
BATCH_SIZE = 8        
SEED = 1337

data_dir = pathlib.Path(DATA_DIR)

# ===== Dataset split: train (70%), val (15%), test (15%) =====
train_ds = keras.utils.image_dataset_from_directory(
    data_dir, labels="inferred", label_mode="int",
    image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    validation_split=0.15, subset="training", seed=SEED
)
valtest_ds = keras.utils.image_dataset_from_directory(
    data_dir, labels="inferred", label_mode="int",
    image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    validation_split=0.15, subset="validation", seed=SEED
)

# Split val/test
val_batches = int(0.5 * tf.data.experimental.cardinality(valtest_ds).numpy())
val_ds = valtest_ds.take(val_batches)
test_ds = valtest_ds.skip(val_batches)

class_names = train_ds.class_names
num_classes = len(class_names)
print("Classes:", class_names)

# ===== Prefetch for performance =====
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.shuffle(1000).prefetch(AUTOTUNE)
val_ds   = val_ds.prefetch(AUTOTUNE)
test_ds  = test_ds.prefetch(AUTOTUNE)

# ===== Data augmentation =====
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.05),
    layers.RandomZoom(0.1),
])

# ===== Conv -> BN -> ReLU helper =====
def CBR(x, filters, k, s=1, p="same"):
    x = layers.Conv2D(filters, k, strides=s, padding=p,
                      use_bias=False, kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    return layers.ReLU()(x)

# ===== Inception (v1-style) block =====
def inception_block(x, f1, f3r, f3, f5r, f5, fpool):
    """
    Branches:
      - 1x1
      - 1x1 -> 3x3
      - 1x1 -> 5x5 (implemented as two 3x3 for efficiency)
      - 3x3 pool -> 1x1
    """
    b1 = CBR(x, f1, 1)

    b2 = CBR(x, f3r, 1)
    b2 = CBR(b2, f3, 3)

    b3 = CBR(x, f5r, 1)
    b3 = CBR(b3, f5, 3)
    b3 = CBR(b3, f5, 3)

    b4 = layers.MaxPooling2D(3, strides=1, padding="same")(x)
    b4 = CBR(b4, fpool, 1)

    return layers.Concatenate()([b1, b2, b3, b4])

# ===== Inception Reduction block (downsampling) =====
def inception_reduction(x, f3, f5r, f5):
    """
    Branches that reduce spatial dims:
      - 3x3 stride-2
      - 1x1 -> 3x3 -> 3x3 stride-2
      - 3x3 maxpool stride-2
    """
    b1 = CBR(x, f3, 3, s=2, p="same")

    b2 = CBR(x, f5r, 1)
    b2 = CBR(b2, f5, 3)
    b2 = CBR(b2, f5, 3, s=2)

    b3 = layers.MaxPooling2D(3, strides=2, padding="same")(x)

    return layers.Concatenate()([b1, b2, b3])

# ===== Baseline Inception-style model =====
def build_inception_baseline(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = layers.Rescaling(1./255)(x)

    # Stem
    x = CBR(x, 32, 7, s=2)                # 512 -> 256
    x = layers.MaxPooling2D(3, strides=2, padding="same")(x)  # 256 -> 128
    x = CBR(x, 64, 3)

    # Inception stacks
    x = inception_block(x, f1=32, f3r=32, f3=48, f5r=8,  f5=16, fpool=16)
    x = inception_block(x, f1=48, f3r=40, f3=64, f5r=12, f5=24, fpool=24)

    # Reduction
    x = inception_reduction(x, f3=96, f5r=32, f5=48)  # 128 -> 64

    # More Inception blocks
    x = inception_block(x, f1=64, f3r=48, f3=96, f5r=16, f5=32, fpool=32)
    x = inception_block(x, f1=80, f3r=56, f3=112, f5r=20, f5=40, fpool=40)

    # Second reduction
    x = inception_reduction(x, f3=128, f5r=48, f5=80)  # 64 -> 32

    # Head
    x = inception_block(x, f1=96, f3r=64, f3=128, f5r=24, f5=48, fpool=48)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)

    return keras.Model(inputs, outputs)

model = build_inception_baseline(IMG_SIZE + (3,), num_classes)
model.compile(optimizer="adam",
              loss=keras.losses.SparseCategoricalCrossentropy(),
              metrics=["accuracy"])

model.summary()

# ===== Train =====
callbacks = [
    keras.callbacks.EarlyStopping(patience=4, restore_best_weights=True, monitor="val_accuracy"),
]

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=20,
    callbacks=callbacks
)

# ===== Evaluate =====
test_loss, test_acc = model.evaluate(test_ds)
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# Found 15000 files belonging to 3 classes.
# Using 12750 files for training.
# Found 15000 files belonging to 3 classes.
# Using 2250 files for validation.
# Classes: ['brain_glioma', 'brain_menin', 'brain_tumor']
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  sequential_1 (Sequential)   (None, 256, 256, 3)          0         ['input_3[0][0]']
#
#  rescaling_2 (Rescaling)     (None, 256, 256, 3)          0         ['sequential_1[0][0]']
#
#  conv2d_110 (Conv2D)         (None, 128, 128, 32)         4704      ['rescaling_2[0][0]']
#
#  batch_normalization_94 (Ba  (None, 128, 128, 32)         128       ['conv2d_110[0][0]']
#  tchNormalization)
#
#  re_lu_45 (ReLU)             (None, 128, 128, 32)         0         ['batch_normalization_94[0][0]
#                                                                     ']
#
#  max_pooling2d_8 (MaxPoolin  (None, 64, 64, 32)           0         ['re_lu_45[0][0]']
#  g2D)
#
#  conv2d_111 (Conv2D)         (None, 64, 64, 64)           18432     ['max_pooling2d_8[0][0]']
#
#  batch_normalization_95 (Ba  (None, 64, 64, 64)           256       ['conv2d_111[0][0]']
#  tchNormalization)
#
#  re_lu_46 (ReLU)             (None, 64, 64, 64)           0         ['batch_normalization_95[0][0]
#                                                                     ']
#
#  conv2d_115 (Conv2D)         (None, 64, 64, 8)            512       ['re_lu_46[0][0]']
#
#  batch_normalization_99 (Ba  (None, 64, 64, 8)            32        ['conv2d_115[0][0]']
#  tchNormalization)
#
#  re_lu_50 (ReLU)             (None, 64, 64, 8)            0         ['batch_normalization_99[0][0]
#                                                                     ']
#
#  conv2d_113 (Conv2D)         (None, 64, 64, 32)           2048      ['re_lu_46[0][0]']
#
#  conv2d_116 (Conv2D)         (None, 64, 64, 16)           1152      ['re_lu_50[0][0]']
#
#  batch_normalization_97 (Ba  (None, 64, 64, 32)           128       ['conv2d_113[0][0]']
#  tchNormalization)
#
#  batch_normalization_100 (B  (None, 64, 64, 16)           64        ['conv2d_116[0][0]']
#  atchNormalization)
#
#  re_lu_48 (ReLU)             (None, 64, 64, 32)           0         ['batch_normalization_97[0][0]
#                                                                     ']
#
#  re_lu_51 (ReLU)             (None, 64, 64, 16)           0         ['batch_normalization_100[0][0
#                                                                     ]']
#
#  max_pooling2d_9 (MaxPoolin  (None, 64, 64, 64)           0         ['re_lu_46[0][0]']
#  g2D)
#
#  conv2d_112 (Conv2D)         (None, 64, 64, 32)           2048      ['re_lu_46[0][0]']
#
#  conv2d_114 (Conv2D)         (None, 64, 64, 48)           13824     ['re_lu_48[0][0]']
#
#  conv2d_117 (Conv2D)         (None, 64, 64, 16)           2304      ['re_lu_51[0][0]']
#
#  conv2d_118 (Conv2D)         (None, 64, 64, 16)           1024      ['max_pooling2d_9[0][0]']
#
#  batch_normalization_96 (Ba  (None, 64, 64, 32)           128       ['conv2d_112[0][0]']
#  tchNormalization)
#
#  batch_normalization_98 (Ba  (None, 64, 64, 48)           192       ['conv2d_114[0][0]']
#  tchNormalization)
#
#  batch_normalization_101 (B  (None, 64, 64, 16)           64        ['conv2d_117[0][0]']
#  atchNormalization)
#
#  batch_normalization_102 (B  (None, 64, 64, 16)           64        ['conv2d_118[0][0]']
#  atchNormalization)
#
#  re_lu_47 (ReLU)             (None, 64, 64, 32)           0         ['batch_normalization_96[0][0]
#                                                                     ']
#
#  re_lu_49 (ReLU)             (None, 64, 64, 48)           0         ['batch_normalization_98[0][0]
#                                                                     ']
#
#  re_lu_52 (ReLU)             (None, 64, 64, 16)           0         ['batch_normalization_101[0][0
#                                                                     ]']
#
#  re_lu_53 (ReLU)             (None, 64, 64, 16)           0         ['batch_normalization_102[0][0
#                                                                     ]']
#
#  concatenate_7 (Concatenate  (None, 64, 64, 112)          0         ['re_lu_47[0][0]',
#  )                                                                   're_lu_49[0][0]',
#                                                                      're_lu_52[0][0]',
#                                                                      're_lu_53[0][0]']
#
#  conv2d_122 (Conv2D)         (None, 64, 64, 12)           1344      ['concatenate_7[0][0]']
#
#  batch_normalization_106 (B  (None, 64, 64, 12)           48        ['conv2d_122[0][0]']
#  atchNormalization)
#
#  re_lu_57 (ReLU)             (None, 64, 64, 12)           0         ['batch_normalization_106[0][0
#                                                                     ]']
#
#  conv2d_120 (Conv2D)         (None, 64, 64, 40)           4480      ['concatenate_7[0][0]']
#
#  conv2d_123 (Conv2D)         (None, 64, 64, 24)           2592      ['re_lu_57[0][0]']
#
#  batch_normalization_104 (B  (None, 64, 64, 40)           160       ['conv2d_120[0][0]']
#  atchNormalization)
#
#  batch_normalization_107 (B  (None, 64, 64, 24)           96        ['conv2d_123[0][0]']
#  atchNormalization)
#
#  re_lu_55 (ReLU)             (None, 64, 64, 40)           0         ['batch_normalization_104[0][0
#                                                                     ]']
#
#  re_lu_58 (ReLU)             (None, 64, 64, 24)           0         ['batch_normalization_107[0][0
#                                                                     ]']
#
#  max_pooling2d_10 (MaxPooli  (None, 64, 64, 112)          0         ['concatenate_7[0][0]']
#  ng2D)
#
#  conv2d_119 (Conv2D)         (None, 64, 64, 48)           5376      ['concatenate_7[0][0]']
#
#  conv2d_121 (Conv2D)         (None, 64, 64, 64)           23040     ['re_lu_55[0][0]']
#
#  conv2d_124 (Conv2D)         (None, 64, 64, 24)           5184      ['re_lu_58[0][0]']
#
#  conv2d_125 (Conv2D)         (None, 64, 64, 24)           2688      ['max_pooling2d_10[0][0]']
#
#  batch_normalization_103 (B  (None, 64, 64, 48)           192       ['conv2d_119[0][0]']
#  atchNormalization)
#
#  batch_normalization_105 (B  (None, 64, 64, 64)           256       ['conv2d_121[0][0]']
#  atchNormalization)
#
#  batch_normalization_108 (B  (None, 64, 64, 24)           96        ['conv2d_124[0][0]']
#  atchNormalization)
#
#  batch_normalization_109 (B  (None, 64, 64, 24)           96        ['conv2d_125[0][0]']
#  atchNormalization)
#
#  re_lu_54 (ReLU)             (None, 64, 64, 48)           0         ['batch_normalization_103[0][0
#                                                                     ]']
#
#  re_lu_56 (ReLU)             (None, 64, 64, 64)           0         ['batch_normalization_105[0][0
#                                                                     ]']
#
#  re_lu_59 (ReLU)             (None, 64, 64, 24)           0         ['batch_normalization_108[0][0
#                                                                     ]']
#
#  re_lu_60 (ReLU)             (None, 64, 64, 24)           0         ['batch_normalization_109[0][0
#                                                                     ]']
#
#  concatenate_8 (Concatenate  (None, 64, 64, 160)          0         ['re_lu_54[0][0]',
#  )                                                                   're_lu_56[0][0]',
#                                                                      're_lu_59[0][0]',
#                                                                      're_lu_60[0][0]']
#
#  conv2d_127 (Conv2D)         (None, 64, 64, 32)           5120      ['concatenate_8[0][0]']
#
#  batch_normalization_111 (B  (None, 64, 64, 32)           128       ['conv2d_127[0][0]']
#  atchNormalization)
#
#  re_lu_62 (ReLU)             (None, 64, 64, 32)           0         ['batch_normalization_111[0][0
#                                                                     ]']
#
#  conv2d_128 (Conv2D)         (None, 64, 64, 48)           13824     ['re_lu_62[0][0]']
#
#  batch_normalization_112 (B  (None, 64, 64, 48)           192       ['conv2d_128[0][0]']
#  atchNormalization)
#
#  re_lu_63 (ReLU)             (None, 64, 64, 48)           0         ['batch_normalization_112[0][0
#                                                                     ]']
#
#  conv2d_126 (Conv2D)         (None, 32, 32, 96)           138240    ['concatenate_8[0][0]']
#
#  conv2d_129 (Conv2D)         (None, 32, 32, 48)           20736     ['re_lu_63[0][0]']
#
#  batch_normalization_110 (B  (None, 32, 32, 96)           384       ['conv2d_126[0][0]']
#  atchNormalization)
#
#  batch_normalization_113 (B  (None, 32, 32, 48)           192       ['conv2d_129[0][0]']
#  atchNormalization)
#
#  re_lu_61 (ReLU)             (None, 32, 32, 96)           0         ['batch_normalization_110[0][0
#                                                                     ]']
#
#  re_lu_64 (ReLU)             (None, 32, 32, 48)           0         ['batch_normalization_113[0][0
#                                                                     ]']
#
#  max_pooling2d_11 (MaxPooli  (None, 32, 32, 160)          0         ['concatenate_8[0][0]']
#  ng2D)
#
#  concatenate_9 (Concatenate  (None, 32, 32, 304)          0         ['re_lu_61[0][0]',
#  )                                                                   're_lu_64[0][0]',
#                                                                      'max_pooling2d_11[0][0]']
#
#  conv2d_133 (Conv2D)         (None, 32, 32, 16)           4864      ['concatenate_9[0][0]']
#
#  batch_normalization_117 (B  (None, 32, 32, 16)           64        ['conv2d_133[0][0]']
#  atchNormalization)
#
#  re_lu_68 (ReLU)             (None, 32, 32, 16)           0         ['batch_normalization_117[0][0
#                                                                     ]']
#
#  conv2d_131 (Conv2D)         (None, 32, 32, 48)           14592     ['concatenate_9[0][0]']
#
#  conv2d_134 (Conv2D)         (None, 32, 32, 32)           4608      ['re_lu_68[0][0]']
#
#  batch_normalization_115 (B  (None, 32, 32, 48)           192       ['conv2d_131[0][0]']
#  atchNormalization)
#
#  batch_normalization_118 (B  (None, 32, 32, 32)           128       ['conv2d_134[0][0]']
#  atchNormalization)
#
#  re_lu_66 (ReLU)             (None, 32, 32, 48)           0         ['batch_normalization_115[0][0
#                                                                     ]']
#
#  re_lu_69 (ReLU)             (None, 32, 32, 32)           0         ['batch_normalization_118[0][0
#                                                                     ]']
#
#  max_pooling2d_12 (MaxPooli  (None, 32, 32, 304)          0         ['concatenate_9[0][0]']
#  ng2D)
#
#  conv2d_130 (Conv2D)         (None, 32, 32, 64)           19456     ['concatenate_9[0][0]']
#
#  conv2d_132 (Conv2D)         (None, 32, 32, 96)           41472     ['re_lu_66[0][0]']
#
#  conv2d_135 (Conv2D)         (None, 32, 32, 32)           9216      ['re_lu_69[0][0]']
#
#  conv2d_136 (Conv2D)         (None, 32, 32, 32)           9728      ['max_pooling2d_12[0][0]']
#
#  batch_normalization_114 (B  (None, 32, 32, 64)           256       ['conv2d_130[0][0]']
#  atchNormalization)
#
#  batch_normalization_116 (B  (None, 32, 32, 96)           384       ['conv2d_132[0][0]']
#  atchNormalization)
#
#  batch_normalization_119 (B  (None, 32, 32, 32)           128       ['conv2d_135[0][0]']
#  atchNormalization)
#
#  batch_normalization_120 (B  (None, 32, 32, 32)           128       ['conv2d_136[0][0]']
#  atchNormalization)
#
#  re_lu_65 (ReLU)             (None, 32, 32, 64)           0         ['batch_normalization_114[0][0
#                                                                     ]']
#
#  re_lu_67 (ReLU)             (None, 32, 32, 96)           0         ['batch_normalization_116[0][0
#                                                                     ]']
#
#  re_lu_70 (ReLU)             (None, 32, 32, 32)           0         ['batch_normalization_119[0][0
#                                                                     ]']
#
#  re_lu_71 (ReLU)             (None, 32, 32, 32)           0         ['batch_normalization_120[0][0
#                                                                     ]']
#
#  concatenate_10 (Concatenat  (None, 32, 32, 224)          0         ['re_lu_65[0][0]',
#  e)                                                                  're_lu_67[0][0]',
#                                                                      're_lu_70[0][0]',
#                                                                      're_lu_71[0][0]']
#
#  conv2d_140 (Conv2D)         (None, 32, 32, 20)           4480      ['concatenate_10[0][0]']
#
#  batch_normalization_124 (B  (None, 32, 32, 20)           80        ['conv2d_140[0][0]']
#  atchNormalization)
#
#  re_lu_75 (ReLU)             (None, 32, 32, 20)           0         ['batch_normalization_124[0][0
#                                                                     ]']
#
#  conv2d_138 (Conv2D)         (None, 32, 32, 56)           12544     ['concatenate_10[0][0]']
#
#  conv2d_141 (Conv2D)         (None, 32, 32, 40)           7200      ['re_lu_75[0][0]']
#
#  batch_normalization_122 (B  (None, 32, 32, 56)           224       ['conv2d_138[0][0]']
#  atchNormalization)
#
#  batch_normalization_125 (B  (None, 32, 32, 40)           160       ['conv2d_141[0][0]']
#  atchNormalization)
#
#  re_lu_73 (ReLU)             (None, 32, 32, 56)           0         ['batch_normalization_122[0][0
#                                                                     ]']
#
#  re_lu_76 (ReLU)             (None, 32, 32, 40)           0         ['batch_normalization_125[0][0
#                                                                     ]']
#
#  max_pooling2d_13 (MaxPooli  (None, 32, 32, 224)          0         ['concatenate_10[0][0]']
#  ng2D)
#
#  conv2d_137 (Conv2D)         (None, 32, 32, 80)           17920     ['concatenate_10[0][0]']
#
#  conv2d_139 (Conv2D)         (None, 32, 32, 112)          56448     ['re_lu_73[0][0]']
#
#  conv2d_142 (Conv2D)         (None, 32, 32, 40)           14400     ['re_lu_76[0][0]']
#
#  conv2d_143 (Conv2D)         (None, 32, 32, 40)           8960      ['max_pooling2d_13[0][0]']
#
#  batch_normalization_121 (B  (None, 32, 32, 80)           320       ['conv2d_137[0][0]']
#  atchNormalization)
#
#  batch_normalization_123 (B  (None, 32, 32, 112)          448       ['conv2d_139[0][0]']
#  atchNormalization)
#
#  batch_normalization_126 (B  (None, 32, 32, 40)           160       ['conv2d_142[0][0]']
#  atchNormalization)
#
#  batch_normalization_127 (B  (None, 32, 32, 40)           160       ['conv2d_143[0][0]']
#  atchNormalization)
#
#  re_lu_72 (ReLU)             (None, 32, 32, 80)           0         ['batch_normalization_121[0][0
#                                                                     ]']
#
#  re_lu_74 (ReLU)             (None, 32, 32, 112)          0         ['batch_normalization_123[0][0
#                                                                     ]']
#
#  re_lu_77 (ReLU)             (None, 32, 32, 40)           0         ['batch_normalization_126[0][0
#                                                                     ]']
#
#  re_lu_78 (ReLU)             (None, 32, 32, 40)           0         ['batch_normalization_127[0][0
#                                                                     ]']
#
#  concatenate_11 (Concatenat  (None, 32, 32, 272)          0         ['re_lu_72[0][0]',
#  e)                                                                  're_lu_74[0][0]',
#                                                                      're_lu_77[0][0]',
#                                                                      're_lu_78[0][0]']
#
#  conv2d_145 (Conv2D)         (None, 32, 32, 48)           13056     ['concatenate_11[0][0]']
#
#  batch_normalization_129 (B  (None, 32, 32, 48)           192       ['conv2d_145[0][0]']
#  atchNormalization)
#
#  re_lu_80 (ReLU)             (None, 32, 32, 48)           0         ['batch_normalization_129[0][0
#                                                                     ]']
#
#  conv2d_146 (Conv2D)         (None, 32, 32, 80)           34560     ['re_lu_80[0][0]']
#
#  batch_normalization_130 (B  (None, 32, 32, 80)           320       ['conv2d_146[0][0]']
#  atchNormalization)
#
#  re_lu_81 (ReLU)             (None, 32, 32, 80)           0         ['batch_normalization_130[0][0
#                                                                     ]']
#
#  conv2d_144 (Conv2D)         (None, 16, 16, 128)          313344    ['concatenate_11[0][0]']
#
#  conv2d_147 (Conv2D)         (None, 16, 16, 80)           57600     ['re_lu_81[0][0]']
#
#  batch_normalization_128 (B  (None, 16, 16, 128)          512       ['conv2d_144[0][0]']
#  atchNormalization)
#
#  batch_normalization_131 (B  (None, 16, 16, 80)           320       ['conv2d_147[0][0]']
#  atchNormalization)
#
#  re_lu_79 (ReLU)             (None, 16, 16, 128)          0         ['batch_normalization_128[0][0
#                                                                     ]']
#
#  re_lu_82 (ReLU)             (None, 16, 16, 80)           0         ['batch_normalization_131[0][0
#                                                                     ]']
#
#  max_pooling2d_14 (MaxPooli  (None, 16, 16, 272)          0         ['concatenate_11[0][0]']
#  ng2D)
#
#  concatenate_12 (Concatenat  (None, 16, 16, 480)          0         ['re_lu_79[0][0]',
#  e)                                                                  're_lu_82[0][0]',
#                                                                      'max_pooling2d_14[0][0]']
#
#  conv2d_151 (Conv2D)         (None, 16, 16, 24)           11520     ['concatenate_12[0][0]']
#
#  batch_normalization_135 (B  (None, 16, 16, 24)           96        ['conv2d_151[0][0]']
#  atchNormalization)
#
#  re_lu_86 (ReLU)             (None, 16, 16, 24)           0         ['batch_normalization_135[0][0
#                                                                     ]']
#
#  conv2d_149 (Conv2D)         (None, 16, 16, 64)           30720     ['concatenate_12[0][0]']
#
#  conv2d_152 (Conv2D)         (None, 16, 16, 48)           10368     ['re_lu_86[0][0]']
#
#  batch_normalization_133 (B  (None, 16, 16, 64)           256       ['conv2d_149[0][0]']
#  atchNormalization)
#
#  batch_normalization_136 (B  (None, 16, 16, 48)           192       ['conv2d_152[0][0]']
#  atchNormalization)
#
#  re_lu_84 (ReLU)             (None, 16, 16, 64)           0         ['batch_normalization_133[0][0
#                                                                     ]']
#
#  re_lu_87 (ReLU)             (None, 16, 16, 48)           0         ['batch_normalization_136[0][0
#                                                                     ]']
#
#  max_pooling2d_15 (MaxPooli  (None, 16, 16, 480)          0         ['concatenate_12[0][0]']
#  ng2D)
#
#  conv2d_148 (Conv2D)         (None, 16, 16, 96)           46080     ['concatenate_12[0][0]']
#
#  conv2d_150 (Conv2D)         (None, 16, 16, 128)          73728     ['re_lu_84[0][0]']
#
#  conv2d_153 (Conv2D)         (None, 16, 16, 48)           20736     ['re_lu_87[0][0]']
#
#  conv2d_154 (Conv2D)         (None, 16, 16, 48)           23040     ['max_pooling2d_15[0][0]']
#
#  batch_normalization_132 (B  (None, 16, 16, 96)           384       ['conv2d_148[0][0]']
#  atchNormalization)
#
#  batch_normalization_134 (B  (None, 16, 16, 128)          512       ['conv2d_150[0][0]']
#  atchNormalization)
#
#  batch_normalization_137 (B  (None, 16, 16, 48)           192       ['conv2d_153[0][0]']
#  atchNormalization)
#
#  batch_normalization_138 (B  (None, 16, 16, 48)           192       ['conv2d_154[0][0]']
#  atchNormalization)
#
#  re_lu_83 (ReLU)             (None, 16, 16, 96)           0         ['batch_normalization_132[0][0
#                                                                     ]']
#
#  re_lu_85 (ReLU)             (None, 16, 16, 128)          0         ['batch_normalization_134[0][0
#                                                                     ]']
#
#  re_lu_88 (ReLU)             (None, 16, 16, 48)           0         ['batch_normalization_137[0][0
#                                                                     ]']
#
#  re_lu_89 (ReLU)             (None, 16, 16, 48)           0         ['batch_normalization_138[0][0
#                                                                     ]']
#
#  concatenate_13 (Concatenat  (None, 16, 16, 320)          0         ['re_lu_83[0][0]',
#  e)                                                                  're_lu_85[0][0]',
#                                                                      're_lu_88[0][0]',
#                                                                      're_lu_89[0][0]']
#
#  global_average_pooling2d_1  (None, 320)                  0         ['concatenate_13[0][0]']
#  8 (GlobalAveragePooling2D)
#
#  dropout_11 (Dropout)        (None, 320)                  0         ['global_average_pooling2d_18[
#                                                                     0][0]']
#
#  dense_2 (Dense)             (None, 3)                    963       ['dropout_11[0][0]']
#
# ==================================================================================================
# Total params: 1139171 (4.35 MB)
# Trainable params: 1134723 (4.33 MB)
# Non-trainable params: 4448 (17.38 KB)
# __________________________________________________________________________________________________
# Epoch 1/20
# 797/797 [==============================] - 284s 337ms/step - loss: 0.3855 - accuracy: 0.8508 - val_loss: 3.0935 - val_accuracy: 0.4893
# Epoch 2/20
# 797/797 [==============================] - 274s 339ms/step - loss: 0.2345 - accuracy: 0.9132 - val_loss: 0.5417 - val_accuracy: 0.7955
# Epoch 3/20
# 797/797 [==============================] - 270s 335ms/step - loss: 0.1826 - accuracy: 0.9313 - val_loss: 0.4185 - val_accuracy: 0.8196
# Epoch 4/20
# 797/797 [==============================] - 276s 341ms/step - loss: 0.1457 - accuracy: 0.9478 - val_loss: 0.6699 - val_accuracy: 0.7625
# Epoch 5/20
# 797/797 [==============================] - 276s 341ms/step - loss: 0.1239 - accuracy: 0.9558 - val_loss: 1.2079 - val_accuracy: 0.7509
# Epoch 6/20
# 797/797 [==============================] - 275s 341ms/step - loss: 0.1054 - accuracy: 0.9630 - val_loss: 0.8480 - val_accuracy: 0.7188
# Epoch 7/20
# 797/797 [==============================] - 276s 341ms/step - loss: 0.0846 - accuracy: 0.9707 - val_loss: 0.8800 - val_accuracy: 0.7598
# 71/71 [==============================] - 6s 82ms/step - loss: 0.4495 - accuracy: 0.8053
# Test accuracy: 0.8053

# %%
# EfficientNet 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pathlib

# =========================
# Paths & Dataset
# =========================
DATA_DIR = "/home/jovyan/.cache/kagglehub/datasets/obulisainaren/multi-cancer/versions/3/Multi Cancer/Multi Cancer/Brain Cancer"
IMG_SIZE = (256, 256)                # smaller than 512 to save memory
BATCH_SIZE = 8
SEED = 1337
data_dir = pathlib.Path(DATA_DIR)

train_ds = keras.utils.image_dataset_from_directory(
    data_dir, labels="inferred", label_mode="int",
    image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    validation_split=0.15, subset="training", seed=SEED
)
valtest_ds = keras.utils.image_dataset_from_directory(
    data_dir, labels="inferred", label_mode="int",
    image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    validation_split=0.15, subset="validation", seed=SEED
)

val_batches = int(0.5 * tf.data.experimental.cardinality(valtest_ds).numpy())
val_ds = valtest_ds.take(val_batches)
test_ds = valtest_ds.skip(val_batches)

class_names = train_ds.class_names
num_classes = len(class_names)
print("Classes:", class_names)

AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.shuffle(1000).prefetch(AUTOTUNE)
val_ds   = val_ds.prefetch(AUTOTUNE)
test_ds  = test_ds.prefetch(AUTOTUNE)

# =========================
# Building Blocks
# =========================
def SE(x, se_ratio=0.25):
    """Squeeze-and-Excitation."""
    filters = x.shape[-1]
    se = layers.GlobalAveragePooling2D(keepdims=True)(x)
    se = layers.Conv2D(int(filters * se_ratio), 1, activation="swish")(se)
    se = layers.Conv2D(filters, 1, activation="sigmoid")(se)
    return layers.Multiply()([x, se])

def MBConv(x, out_ch, expand=4, kernel=3, stride=1, se_ratio=0.25, drop_rate=0.0):
    """Minimal EfficientNet-style MBConv block (no fused variant)."""
    in_ch = x.shape[-1]
    residual = x

    # Expansion
    mid_ch = int(in_ch * expand)
    if expand != 1:
        x = layers.Conv2D(mid_ch, 1, padding="same", use_bias=False,
                          kernel_initializer="he_normal")(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation("swish")(x)

    # Depthwise
    x = layers.DepthwiseConv2D(kernel, strides=stride, padding="same",
                               use_bias=False, kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("swish")(x)

    # SE
    if se_ratio and se_ratio > 0:
        x = SE(x, se_ratio=se_ratio)

    # Projection
    x = layers.Conv2D(out_ch, 1, padding="same", use_bias=False,
                      kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)

    # Skip connection (if shape matches)
    if stride == 1 and in_ch == out_ch:
        if drop_rate and drop_rate > 0:
            x = layers.Dropout(drop_rate)(x)
        x = layers.Add()([x, residual])
    return x

def round_filters(filters, width_mult=1.0):
    return max(8, int(filters * width_mult))

def round_repeats(repeats, depth_mult=1.0):
    import math
    return max(1, int(math.ceil(repeats * depth_mult)))

# =========================
# Model (EfficientNet-like)
# =========================
def build_efficientnet_like(input_shape, num_classes, width_mult=1.0, depth_mult=1.0, drop_rate=0.2):
    inputs = keras.Input(shape=input_shape)

    # Data augmentation + basic rescale
    x = layers.RandomFlip("horizontal")(inputs)
    x = layers.RandomRotation(0.05)(x)
    x = layers.RandomZoom(0.1)(x)
    x = layers.Rescaling(1./255)(x)

    # Stem
    stem_ch = round_filters(32, width_mult)
    x = layers.Conv2D(stem_ch, 3, strides=2, padding="same", use_bias=False,
                      kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("swish")(x)

    # Stages: (out_channels, repeats, kernel, stride, expand)
    cfgs = [
        # out, r, k, s, t
        (16,  1, 3, 1, 1),   # MBConv1
        (24,  2, 3, 2, 4),   # MBConv6-ish (expand=4 to keep it light)
        (40,  2, 5, 2, 4),
        (80,  3, 3, 2, 4),
        (112, 3, 5, 1, 4),
        (192, 4, 5, 2, 4),
        (320, 1, 3, 1, 4),
    ]

    block_idx = 0
    total_blocks = sum(round_repeats(r, depth_mult) for (_, r, _, _, _) in cfgs)

    for out_ch, repeats, k, s, t in cfgs:
        out_ch = round_filters(out_ch, width_mult)
        reps = round_repeats(repeats, depth_mult)

        for i in range(reps):
            stride = s if i == 0 else 1
            # simple linear drop schedule
            b_drop = drop_rate * float(block_idx) / max(1, total_blocks - 1)
            x = MBConv(x, out_ch=out_ch, expand=t, kernel=k, stride=stride,
                       se_ratio=0.25, drop_rate=b_drop)
            block_idx += 1

    # Head
    head_ch = round_filters(1280, width_mult)
    x = layers.Conv2D(head_ch, 1, use_bias=False, kernel_initializer="he_normal")(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("swish")(x)

    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(drop_rate)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)

    return keras.Model(inputs, outputs)

# Build the model (roughly around B0 scale)
model = build_efficientnet_like(IMG_SIZE + (3,), num_classes,
                                width_mult=1.0, depth_mult=1.0, drop_rate=0.2)

model.compile(
    optimizer=keras.optimizers.Adam(3e-4),
    loss=keras.losses.SparseCategoricalCrossentropy(),
    metrics=["accuracy"]
)

model.summary()

# =========================
# Train & Evaluate
# =========================
callbacks = [
    keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True, monitor="val_accuracy"),
    keras.callbacks.ReduceLROnPlateau(patience=2, factor=0.5, min_lr=1e-6)
]

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=30,
    callbacks=callbacks
)

test_loss, test_acc = model.evaluate(test_ds)
print(f"Test accuracy: {test_acc:.4f}")
# Out:
# Found 15000 files belonging to 3 classes.
# Using 12750 files for training.
# Found 15000 files belonging to 3 classes.
# Using 2250 files for validation.
# Classes: ['brain_glioma', 'brain_menin', 'brain_tumor']
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  random_flip_1 (RandomFlip)  (None, 256, 256, 3)          0         ['input_2[0][0]']
#
#  random_rotation_1 (RandomR  (None, 256, 256, 3)          0         ['random_flip_1[0][0]']
#  otation)
#
#  random_zoom_1 (RandomZoom)  (None, 256, 256, 3)          0         ['random_rotation_1[0][0]']
#
#  rescaling_1 (Rescaling)     (None, 256, 256, 3)          0         ['random_zoom_1[0][0]']
#
#  conv2d_45 (Conv2D)          (None, 128, 128, 32)         864       ['rescaling_1[0][0]']
#
#  batch_normalization_45 (Ba  (None, 128, 128, 32)         128       ['conv2d_45[0][0]']
#  tchNormalization)
#
#  activation (Activation)     (None, 128, 128, 32)         0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  depthwise_conv2d (Depthwis  (None, 128, 128, 32)         288       ['activation[0][0]']
#  eConv2D)
#
#  batch_normalization_46 (Ba  (None, 128, 128, 32)         128       ['depthwise_conv2d[0][0]']
#  tchNormalization)
#
#  activation_1 (Activation)   (None, 128, 128, 32)         0         ['batch_normalization_46[0][0]
#                                                                     ']
#
#  global_average_pooling2d_1  (None, 1, 1, 32)             0         ['activation_1[0][0]']
#   (GlobalAveragePooling2D)
#
#  conv2d_46 (Conv2D)          (None, 1, 1, 8)              264       ['global_average_pooling2d_1[0
#                                                                     ][0]']
#
#  conv2d_47 (Conv2D)          (None, 1, 1, 32)             288       ['conv2d_46[0][0]']
#
#  multiply (Multiply)         (None, 128, 128, 32)         0         ['activation_1[0][0]',
#                                                                      'conv2d_47[0][0]']
#
#  conv2d_48 (Conv2D)          (None, 128, 128, 16)         512       ['multiply[0][0]']
#
#  batch_normalization_47 (Ba  (None, 128, 128, 16)         64        ['conv2d_48[0][0]']
#  tchNormalization)
#
#  conv2d_49 (Conv2D)          (None, 128, 128, 64)         1024      ['batch_normalization_47[0][0]
#                                                                     ']
#
#  batch_normalization_48 (Ba  (None, 128, 128, 64)         256       ['conv2d_49[0][0]']
#  tchNormalization)
#
#  activation_2 (Activation)   (None, 128, 128, 64)         0         ['batch_normalization_48[0][0]
#                                                                     ']
#
#  depthwise_conv2d_1 (Depthw  (None, 64, 64, 64)           576       ['activation_2[0][0]']
#  iseConv2D)
#
#  batch_normalization_49 (Ba  (None, 64, 64, 64)           256       ['depthwise_conv2d_1[0][0]']
#  tchNormalization)
#
#  activation_3 (Activation)   (None, 64, 64, 64)           0         ['batch_normalization_49[0][0]
#                                                                     ']
#
#  global_average_pooling2d_2  (None, 1, 1, 64)             0         ['activation_3[0][0]']
#   (GlobalAveragePooling2D)
#
#  conv2d_50 (Conv2D)          (None, 1, 1, 16)             1040      ['global_average_pooling2d_2[0
#                                                                     ][0]']
#
#  conv2d_51 (Conv2D)          (None, 1, 1, 64)             1088      ['conv2d_50[0][0]']
#
#  multiply_1 (Multiply)       (None, 64, 64, 64)           0         ['activation_3[0][0]',
#                                                                      'conv2d_51[0][0]']
#
#  conv2d_52 (Conv2D)          (None, 64, 64, 24)           1536      ['multiply_1[0][0]']
#
#  batch_normalization_50 (Ba  (None, 64, 64, 24)           96        ['conv2d_52[0][0]']
#  tchNormalization)
#
#  conv2d_53 (Conv2D)          (None, 64, 64, 96)           2304      ['batch_normalization_50[0][0]
#                                                                     ']
#
#  batch_normalization_51 (Ba  (None, 64, 64, 96)           384       ['conv2d_53[0][0]']
#  tchNormalization)
#
#  activation_4 (Activation)   (None, 64, 64, 96)           0         ['batch_normalization_51[0][0]
#                                                                     ']
#
#  depthwise_conv2d_2 (Depthw  (None, 64, 64, 96)           864       ['activation_4[0][0]']
#  iseConv2D)
#
#  batch_normalization_52 (Ba  (None, 64, 64, 96)           384       ['depthwise_conv2d_2[0][0]']
#  tchNormalization)
#
#  activation_5 (Activation)   (None, 64, 64, 96)           0         ['batch_normalization_52[0][0]
#                                                                     ']
#
#  global_average_pooling2d_3  (None, 1, 1, 96)             0         ['activation_5[0][0]']
#   (GlobalAveragePooling2D)
#
#  conv2d_54 (Conv2D)          (None, 1, 1, 24)             2328      ['global_average_pooling2d_3[0
#                                                                     ][0]']
#
#  conv2d_55 (Conv2D)          (None, 1, 1, 96)             2400      ['conv2d_54[0][0]']
#
#  multiply_2 (Multiply)       (None, 64, 64, 96)           0         ['activation_5[0][0]',
#                                                                      'conv2d_55[0][0]']
#
#  conv2d_56 (Conv2D)          (None, 64, 64, 24)           2304      ['multiply_2[0][0]']
#
#  batch_normalization_53 (Ba  (None, 64, 64, 24)           96        ['conv2d_56[0][0]']
#  tchNormalization)
#
#  dropout_1 (Dropout)         (None, 64, 64, 24)           0         ['batch_normalization_53[0][0]
#                                                                     ']
#
#  add (Add)                   (None, 64, 64, 24)           0         ['dropout_1[0][0]',
#                                                                      'batch_normalization_50[0][0]
#                                                                     ']
#
#  conv2d_57 (Conv2D)          (None, 64, 64, 96)           2304      ['add[0][0]']
#
#  batch_normalization_54 (Ba  (None, 64, 64, 96)           384       ['conv2d_57[0][0]']
#  tchNormalization)
#
#  activation_6 (Activation)   (None, 64, 64, 96)           0         ['batch_normalization_54[0][0]
#                                                                     ']
#
#  depthwise_conv2d_3 (Depthw  (None, 32, 32, 96)           2400      ['activation_6[0][0]']
#  iseConv2D)
#
#  batch_normalization_55 (Ba  (None, 32, 32, 96)           384       ['depthwise_conv2d_3[0][0]']
#  tchNormalization)
#
#  activation_7 (Activation)   (None, 32, 32, 96)           0         ['batch_normalization_55[0][0]
#                                                                     ']
#
#  global_average_pooling2d_4  (None, 1, 1, 96)             0         ['activation_7[0][0]']
#   (GlobalAveragePooling2D)
#
#  conv2d_58 (Conv2D)          (None, 1, 1, 24)             2328      ['global_average_pooling2d_4[0
#                                                                     ][0]']
#
#  conv2d_59 (Conv2D)          (None, 1, 1, 96)             2400      ['conv2d_58[0][0]']
#
#  multiply_3 (Multiply)       (None, 32, 32, 96)           0         ['activation_7[0][0]',
#                                                                      'conv2d_59[0][0]']
#
#  conv2d_60 (Conv2D)          (None, 32, 32, 40)           3840      ['multiply_3[0][0]']
#
#  batch_normalization_56 (Ba  (None, 32, 32, 40)           160       ['conv2d_60[0][0]']
#  tchNormalization)
#
#  conv2d_61 (Conv2D)          (None, 32, 32, 160)          6400      ['batch_normalization_56[0][0]
#                                                                     ']
#
#  batch_normalization_57 (Ba  (None, 32, 32, 160)          640       ['conv2d_61[0][0]']
#  tchNormalization)
#
#  activation_8 (Activation)   (None, 32, 32, 160)          0         ['batch_normalization_57[0][0]
#                                                                     ']
#
#  depthwise_conv2d_4 (Depthw  (None, 32, 32, 160)          4000      ['activation_8[0][0]']
#  iseConv2D)
#
#  batch_normalization_58 (Ba  (None, 32, 32, 160)          640       ['depthwise_conv2d_4[0][0]']
#  tchNormalization)
#
#  activation_9 (Activation)   (None, 32, 32, 160)          0         ['batch_normalization_58[0][0]
#                                                                     ']
#
#  global_average_pooling2d_5  (None, 1, 1, 160)            0         ['activation_9[0][0]']
#   (GlobalAveragePooling2D)
#
#  conv2d_62 (Conv2D)          (None, 1, 1, 40)             6440      ['global_average_pooling2d_5[0
#                                                                     ][0]']
#
#  conv2d_63 (Conv2D)          (None, 1, 1, 160)            6560      ['conv2d_62[0][0]']
#
#  multiply_4 (Multiply)       (None, 32, 32, 160)          0         ['activation_9[0][0]',
#                                                                      'conv2d_63[0][0]']
#
#  conv2d_64 (Conv2D)          (None, 32, 32, 40)           6400      ['multiply_4[0][0]']
#
#  batch_normalization_59 (Ba  (None, 32, 32, 40)           160       ['conv2d_64[0][0]']
#  tchNormalization)
#
#  dropout_2 (Dropout)         (None, 32, 32, 40)           0         ['batch_normalization_59[0][0]
#                                                                     ']
#
#  add_1 (Add)                 (None, 32, 32, 40)           0         ['dropout_2[0][0]',
#                                                                      'batch_normalization_56[0][0]
#                                                                     ']
#
#  conv2d_65 (Conv2D)          (None, 32, 32, 160)          6400      ['add_1[0][0]']
#
#  batch_normalization_60 (Ba  (None, 32, 32, 160)          640       ['conv2d_65[0][0]']
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 32, 32, 160)          0         ['batch_normalization_60[0][0]
#                                                                     ']
#
#  depthwise_conv2d_5 (Depthw  (None, 16, 16, 160)          1440      ['activation_10[0][0]']
#  iseConv2D)
#
#  batch_normalization_61 (Ba  (None, 16, 16, 160)          640       ['depthwise_conv2d_5[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 16, 16, 160)          0         ['batch_normalization_61[0][0]
#                                                                     ']
#
#  global_average_pooling2d_6  (None, 1, 1, 160)            0         ['activation_11[0][0]']
#   (GlobalAveragePooling2D)
#
#  conv2d_66 (Conv2D)          (None, 1, 1, 40)             6440      ['global_average_pooling2d_6[0
#                                                                     ][0]']
#
#  conv2d_67 (Conv2D)          (None, 1, 1, 160)            6560      ['conv2d_66[0][0]']
#
#  multiply_5 (Multiply)       (None, 16, 16, 160)          0         ['activation_11[0][0]',
#                                                                      'conv2d_67[0][0]']
#
#  conv2d_68 (Conv2D)          (None, 16, 16, 80)           12800     ['multiply_5[0][0]']
#
#  batch_normalization_62 (Ba  (None, 16, 16, 80)           320       ['conv2d_68[0][0]']
#  tchNormalization)
#
#  conv2d_69 (Conv2D)          (None, 16, 16, 320)          25600     ['batch_normalization_62[0][0]
#                                                                     ']
#
#  batch_normalization_63 (Ba  (None, 16, 16, 320)          1280      ['conv2d_69[0][0]']
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 16, 16, 320)          0         ['batch_normalization_63[0][0]
#                                                                     ']
#
#  depthwise_conv2d_6 (Depthw  (None, 16, 16, 320)          2880      ['activation_12[0][0]']
#  iseConv2D)
#
#  batch_normalization_64 (Ba  (None, 16, 16, 320)          1280      ['depthwise_conv2d_6[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 16, 16, 320)          0         ['batch_normalization_64[0][0]
#                                                                     ']
#
#  global_average_pooling2d_7  (None, 1, 1, 320)            0         ['activation_13[0][0]']
#   (GlobalAveragePooling2D)
#
#  conv2d_70 (Conv2D)          (None, 1, 1, 80)             25680     ['global_average_pooling2d_7[0
#                                                                     ][0]']
#
#  conv2d_71 (Conv2D)          (None, 1, 1, 320)            25920     ['conv2d_70[0][0]']
#
#  multiply_6 (Multiply)       (None, 16, 16, 320)          0         ['activation_13[0][0]',
#                                                                      'conv2d_71[0][0]']
#
#  conv2d_72 (Conv2D)          (None, 16, 16, 80)           25600     ['multiply_6[0][0]']
#
#  batch_normalization_65 (Ba  (None, 16, 16, 80)           320       ['conv2d_72[0][0]']
#  tchNormalization)
#
#  dropout_3 (Dropout)         (None, 16, 16, 80)           0         ['batch_normalization_65[0][0]
#                                                                     ']
#
#  add_2 (Add)                 (None, 16, 16, 80)           0         ['dropout_3[0][0]',
#                                                                      'batch_normalization_62[0][0]
#                                                                     ']
#
#  conv2d_73 (Conv2D)          (None, 16, 16, 320)          25600     ['add_2[0][0]']
#
#  batch_normalization_66 (Ba  (None, 16, 16, 320)          1280      ['conv2d_73[0][0]']
#  tchNormalization)
#
#  activation_14 (Activation)  (None, 16, 16, 320)          0         ['batch_normalization_66[0][0]
#                                                                     ']
#
#  depthwise_conv2d_7 (Depthw  (None, 16, 16, 320)          2880      ['activation_14[0][0]']
#  iseConv2D)
#
#  batch_normalization_67 (Ba  (None, 16, 16, 320)          1280      ['depthwise_conv2d_7[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 16, 16, 320)          0         ['batch_normalization_67[0][0]
#                                                                     ']
#
#  global_average_pooling2d_8  (None, 1, 1, 320)            0         ['activation_15[0][0]']
#   (GlobalAveragePooling2D)
#
#  conv2d_74 (Conv2D)          (None, 1, 1, 80)             25680     ['global_average_pooling2d_8[0
#                                                                     ][0]']
#
#  conv2d_75 (Conv2D)          (None, 1, 1, 320)            25920     ['conv2d_74[0][0]']
#
#  multiply_7 (Multiply)       (None, 16, 16, 320)          0         ['activation_15[0][0]',
#                                                                      'conv2d_75[0][0]']
#
#  conv2d_76 (Conv2D)          (None, 16, 16, 80)           25600     ['multiply_7[0][0]']
#
#  batch_normalization_68 (Ba  (None, 16, 16, 80)           320       ['conv2d_76[0][0]']
#  tchNormalization)
#
#  dropout_4 (Dropout)         (None, 16, 16, 80)           0         ['batch_normalization_68[0][0]
#                                                                     ']
#
#  add_3 (Add)                 (None, 16, 16, 80)           0         ['dropout_4[0][0]',
#                                                                      'add_2[0][0]']
#
#  conv2d_77 (Conv2D)          (None, 16, 16, 320)          25600     ['add_3[0][0]']
#
#  batch_normalization_69 (Ba  (None, 16, 16, 320)          1280      ['conv2d_77[0][0]']
#  tchNormalization)
#
#  activation_16 (Activation)  (None, 16, 16, 320)          0         ['batch_normalization_69[0][0]
#                                                                     ']
#
#  depthwise_conv2d_8 (Depthw  (None, 16, 16, 320)          8000      ['activation_16[0][0]']
#  iseConv2D)
#
#  batch_normalization_70 (Ba  (None, 16, 16, 320)          1280      ['depthwise_conv2d_8[0][0]']
#  tchNormalization)
#
#  activation_17 (Activation)  (None, 16, 16, 320)          0         ['batch_normalization_70[0][0]
#                                                                     ']
#
#  global_average_pooling2d_9  (None, 1, 1, 320)            0         ['activation_17[0][0]']
#   (GlobalAveragePooling2D)
#
#  conv2d_78 (Conv2D)          (None, 1, 1, 80)             25680     ['global_average_pooling2d_9[0
#                                                                     ][0]']
#
#  conv2d_79 (Conv2D)          (None, 1, 1, 320)            25920     ['conv2d_78[0][0]']
#
#  multiply_8 (Multiply)       (None, 16, 16, 320)          0         ['activation_17[0][0]',
#                                                                      'conv2d_79[0][0]']
#
#  conv2d_80 (Conv2D)          (None, 16, 16, 112)          35840     ['multiply_8[0][0]']
#
#  batch_normalization_71 (Ba  (None, 16, 16, 112)          448       ['conv2d_80[0][0]']
#  tchNormalization)
#
#  conv2d_81 (Conv2D)          (None, 16, 16, 448)          50176     ['batch_normalization_71[0][0]
#                                                                     ']
#
#  batch_normalization_72 (Ba  (None, 16, 16, 448)          1792      ['conv2d_81[0][0]']
#  tchNormalization)
#
#  activation_18 (Activation)  (None, 16, 16, 448)          0         ['batch_normalization_72[0][0]
#                                                                     ']
#
#  depthwise_conv2d_9 (Depthw  (None, 16, 16, 448)          11200     ['activation_18[0][0]']
#  iseConv2D)
#
#  batch_normalization_73 (Ba  (None, 16, 16, 448)          1792      ['depthwise_conv2d_9[0][0]']
#  tchNormalization)
#
#  activation_19 (Activation)  (None, 16, 16, 448)          0         ['batch_normalization_73[0][0]
#                                                                     ']
#
#  global_average_pooling2d_1  (None, 1, 1, 448)            0         ['activation_19[0][0]']
#  0 (GlobalAveragePooling2D)
#
#  conv2d_82 (Conv2D)          (None, 1, 1, 112)            50288     ['global_average_pooling2d_10[
#                                                                     0][0]']
#
#  conv2d_83 (Conv2D)          (None, 1, 1, 448)            50624     ['conv2d_82[0][0]']
#
#  multiply_9 (Multiply)       (None, 16, 16, 448)          0         ['activation_19[0][0]',
#                                                                      'conv2d_83[0][0]']
#
#  conv2d_84 (Conv2D)          (None, 16, 16, 112)          50176     ['multiply_9[0][0]']
#
#  batch_normalization_74 (Ba  (None, 16, 16, 112)          448       ['conv2d_84[0][0]']
#  tchNormalization)
#
#  dropout_5 (Dropout)         (None, 16, 16, 112)          0         ['batch_normalization_74[0][0]
#                                                                     ']
#
#  add_4 (Add)                 (None, 16, 16, 112)          0         ['dropout_5[0][0]',
#                                                                      'batch_normalization_71[0][0]
#                                                                     ']
#
#  conv2d_85 (Conv2D)          (None, 16, 16, 448)          50176     ['add_4[0][0]']
#
#  batch_normalization_75 (Ba  (None, 16, 16, 448)          1792      ['conv2d_85[0][0]']
#  tchNormalization)
#
#  activation_20 (Activation)  (None, 16, 16, 448)          0         ['batch_normalization_75[0][0]
#                                                                     ']
#
#  depthwise_conv2d_10 (Depth  (None, 16, 16, 448)          11200     ['activation_20[0][0]']
#  wiseConv2D)
#
#  batch_normalization_76 (Ba  (None, 16, 16, 448)          1792      ['depthwise_conv2d_10[0][0]']
#  tchNormalization)
#
#  activation_21 (Activation)  (None, 16, 16, 448)          0         ['batch_normalization_76[0][0]
#                                                                     ']
#
#  global_average_pooling2d_1  (None, 1, 1, 448)            0         ['activation_21[0][0]']
#  1 (GlobalAveragePooling2D)
#
#  conv2d_86 (Conv2D)          (None, 1, 1, 112)            50288     ['global_average_pooling2d_11[
#                                                                     0][0]']
#
#  conv2d_87 (Conv2D)          (None, 1, 1, 448)            50624     ['conv2d_86[0][0]']
#
#  multiply_10 (Multiply)      (None, 16, 16, 448)          0         ['activation_21[0][0]',
#                                                                      'conv2d_87[0][0]']
#
#  conv2d_88 (Conv2D)          (None, 16, 16, 112)          50176     ['multiply_10[0][0]']
#
#  batch_normalization_77 (Ba  (None, 16, 16, 112)          448       ['conv2d_88[0][0]']
#  tchNormalization)
#
#  dropout_6 (Dropout)         (None, 16, 16, 112)          0         ['batch_normalization_77[0][0]
#                                                                     ']
#
#  add_5 (Add)                 (None, 16, 16, 112)          0         ['dropout_6[0][0]',
#                                                                      'add_4[0][0]']
#
#  conv2d_89 (Conv2D)          (None, 16, 16, 448)          50176     ['add_5[0][0]']
#
#  batch_normalization_78 (Ba  (None, 16, 16, 448)          1792      ['conv2d_89[0][0]']
#  tchNormalization)
#
#  activation_22 (Activation)  (None, 16, 16, 448)          0         ['batch_normalization_78[0][0]
#                                                                     ']
#
#  depthwise_conv2d_11 (Depth  (None, 8, 8, 448)            11200     ['activation_22[0][0]']
#  wiseConv2D)
#
#  batch_normalization_79 (Ba  (None, 8, 8, 448)            1792      ['depthwise_conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_23 (Activation)  (None, 8, 8, 448)            0         ['batch_normalization_79[0][0]
#                                                                     ']
#
#  global_average_pooling2d_1  (None, 1, 1, 448)            0         ['activation_23[0][0]']
#  2 (GlobalAveragePooling2D)
#
#  conv2d_90 (Conv2D)          (None, 1, 1, 112)            50288     ['global_average_pooling2d_12[
#                                                                     0][0]']
#
#  conv2d_91 (Conv2D)          (None, 1, 1, 448)            50624     ['conv2d_90[0][0]']
#
#  multiply_11 (Multiply)      (None, 8, 8, 448)            0         ['activation_23[0][0]',
#                                                                      'conv2d_91[0][0]']
#
#  conv2d_92 (Conv2D)          (None, 8, 8, 192)            86016     ['multiply_11[0][0]']
#
#  batch_normalization_80 (Ba  (None, 8, 8, 192)            768       ['conv2d_92[0][0]']
#  tchNormalization)
#
#  conv2d_93 (Conv2D)          (None, 8, 8, 768)            147456    ['batch_normalization_80[0][0]
#                                                                     ']
#
#  batch_normalization_81 (Ba  (None, 8, 8, 768)            3072      ['conv2d_93[0][0]']
#  tchNormalization)
#
#  activation_24 (Activation)  (None, 8, 8, 768)            0         ['batch_normalization_81[0][0]
#                                                                     ']
#
#  depthwise_conv2d_12 (Depth  (None, 8, 8, 768)            19200     ['activation_24[0][0]']
#  wiseConv2D)
#
#  batch_normalization_82 (Ba  (None, 8, 8, 768)            3072      ['depthwise_conv2d_12[0][0]']
#  tchNormalization)
#
#  activation_25 (Activation)  (None, 8, 8, 768)            0         ['batch_normalization_82[0][0]
#                                                                     ']
#
#  global_average_pooling2d_1  (None, 1, 1, 768)            0         ['activation_25[0][0]']
#  3 (GlobalAveragePooling2D)
#
#  conv2d_94 (Conv2D)          (None, 1, 1, 192)            147648    ['global_average_pooling2d_13[
#                                                                     0][0]']
#
#  conv2d_95 (Conv2D)          (None, 1, 1, 768)            148224    ['conv2d_94[0][0]']
#
#  multiply_12 (Multiply)      (None, 8, 8, 768)            0         ['activation_25[0][0]',
# ...
#
#  depthwise_conv2d_13 (Depth  (None, 8, 8, 768)            19200     ['activation_26[0][0]']
#  wiseConv2D)
#
#  batch_normalization_85 (Ba  (None, 8, 8, 768)            3072      ['depthwise_conv2d_13[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 8, 8, 768)            0         ['batch_normalization_85[0][0]
#                                                                     ']
#
#  global_average_pooling2d_1  (None, 1, 1, 768)            0         ['activation_27[0][0]']
#  4 (GlobalAveragePooling2D)
#
#  conv2d_98 (Conv2D)          (None, 1, 1, 192)            147648    ['global_average_pooling2d_14[
#                                                                     0][0]']
#
#  conv2d_99 (Conv2D)          (None, 1, 1, 768)            148224    ['conv2d_98[0][0]']
#
#  multiply_13 (Multiply)      (None, 8, 8, 768)            0         ['activation_27[0][0]',
#                                                                      'conv2d_99[0][0]']
#
#  conv2d_100 (Conv2D)         (None, 8, 8, 192)            147456    ['multiply_13[0][0]']
#
#  batch_normalization_86 (Ba  (None, 8, 8, 192)            768       ['conv2d_100[0][0]']
#  tchNormalization)
#
#  dropout_8 (Dropout)         (None, 8, 8, 192)            0         ['batch_normalization_86[0][0]
#                                                                     ']
#
#  add_7 (Add)                 (None, 8, 8, 192)            0         ['dropout_8[0][0]',
#                                                                      'add_6[0][0]']
#
#  conv2d_101 (Conv2D)         (None, 8, 8, 768)            147456    ['add_7[0][0]']
#
#  batch_normalization_87 (Ba  (None, 8, 8, 768)            3072      ['conv2d_101[0][0]']
#  tchNormalization)
#
#  activation_28 (Activation)  (None, 8, 8, 768)            0         ['batch_normalization_87[0][0]
#                                                                     ']
#
#  depthwise_conv2d_14 (Depth  (None, 8, 8, 768)            19200     ['activation_28[0][0]']
#  wiseConv2D)
#
#  batch_normalization_88 (Ba  (None, 8, 8, 768)            3072      ['depthwise_conv2d_14[0][0]']
#  tchNormalization)
#
#  activation_29 (Activation)  (None, 8, 8, 768)            0         ['batch_normalization_88[0][0]
#                                                                     ']
#
#  global_average_pooling2d_1  (None, 1, 1, 768)            0         ['activation_29[0][0]']
#  5 (GlobalAveragePooling2D)
#
#  conv2d_102 (Conv2D)         (None, 1, 1, 192)            147648    ['global_average_pooling2d_15[
#                                                                     0][0]']
#
#  conv2d_103 (Conv2D)         (None, 1, 1, 768)            148224    ['conv2d_102[0][0]']
#
#  multiply_14 (Multiply)      (None, 8, 8, 768)            0         ['activation_29[0][0]',
#                                                                      'conv2d_103[0][0]']
#
#  conv2d_104 (Conv2D)         (None, 8, 8, 192)            147456    ['multiply_14[0][0]']
#
#  batch_normalization_89 (Ba  (None, 8, 8, 192)            768       ['conv2d_104[0][0]']
#  tchNormalization)
#
#  dropout_9 (Dropout)         (None, 8, 8, 192)            0         ['batch_normalization_89[0][0]
#                                                                     ']
#
#  add_8 (Add)                 (None, 8, 8, 192)            0         ['dropout_9[0][0]',
#                                                                      'add_7[0][0]']
#
#  conv2d_105 (Conv2D)         (None, 8, 8, 768)            147456    ['add_8[0][0]']
#
#  batch_normalization_90 (Ba  (None, 8, 8, 768)            3072      ['conv2d_105[0][0]']
#  tchNormalization)
#
#  activation_30 (Activation)  (None, 8, 8, 768)            0         ['batch_normalization_90[0][0]
#                                                                     ']
#
#  depthwise_conv2d_15 (Depth  (None, 8, 8, 768)            6912      ['activation_30[0][0]']
#  wiseConv2D)
#
#  batch_normalization_91 (Ba  (None, 8, 8, 768)            3072      ['depthwise_conv2d_15[0][0]']
#  tchNormalization)
#
#  activation_31 (Activation)  (None, 8, 8, 768)            0         ['batch_normalization_91[0][0]
#                                                                     ']
#
#  global_average_pooling2d_1  (None, 1, 1, 768)            0         ['activation_31[0][0]']
#  6 (GlobalAveragePooling2D)
#
#  conv2d_106 (Conv2D)         (None, 1, 1, 192)            147648    ['global_average_pooling2d_16[
#                                                                     0][0]']
#
#  conv2d_107 (Conv2D)         (None, 1, 1, 768)            148224    ['conv2d_106[0][0]']
#
#  multiply_15 (Multiply)      (None, 8, 8, 768)            0         ['activation_31[0][0]',
#                                                                      'conv2d_107[0][0]']
#
#  conv2d_108 (Conv2D)         (None, 8, 8, 320)            245760    ['multiply_15[0][0]']
#
#  batch_normalization_92 (Ba  (None, 8, 8, 320)            1280      ['conv2d_108[0][0]']
#  tchNormalization)
#
#  conv2d_109 (Conv2D)         (None, 8, 8, 1280)           409600    ['batch_normalization_92[0][0]
#                                                                     ']
#
#  batch_normalization_93 (Ba  (None, 8, 8, 1280)           5120      ['conv2d_109[0][0]']
#  tchNormalization)
#
#  activation_32 (Activation)  (None, 8, 8, 1280)           0         ['batch_normalization_93[0][0]
#                                                                     ']
#
#  global_average_pooling2d_1  (None, 1280)                 0         ['activation_32[0][0]']
#  7 (GlobalAveragePooling2D)
#
#  dropout_10 (Dropout)        (None, 1280)                 0         ['global_average_pooling2d_17[
#                                                                     0][0]']
#
#  dense_1 (Dense)             (None, 3)                    3843      ['dropout_10[0][0]']
#
# ==================================================================================================
# Total params: 4099643 (15.64 MB)
# Trainable params: 4069531 (15.52 MB)
# Non-trainable params: 30112 (117.62 KB)
# __________________________________________________________________________________________________
# Epoch 1/30
# 797/797 [==============================] - 409s 488ms/step - loss: 0.5361 - accuracy: 0.7874 - val_loss: 0.5420 - val_accuracy: 0.8054 - lr: 3.0000e-04
# Epoch 2/30
# 797/797 [==============================] - 394s 490ms/step - loss: 0.2887 - accuracy: 0.8931 - val_loss: 0.6155 - val_accuracy: 0.7732 - lr: 3.0000e-04
# Epoch 3/30
# 797/797 [==============================] - 398s 494ms/step - loss: 0.1970 - accuracy: 0.9280 - val_loss: 0.3866 - val_accuracy: 0.8920 - lr: 3.0000e-04
# Epoch 4/30
# 797/797 [==============================] - 400s 497ms/step - loss: 0.1327 - accuracy: 0.9530 - val_loss: 0.2689 - val_accuracy: 0.9125 - lr: 3.0000e-04
# Epoch 5/30
# 797/797 [==============================] - 402s 500ms/step - loss: 0.1018 - accuracy: 0.9649 - val_loss: 0.2645 - val_accuracy: 0.9071 - lr: 3.0000e-04
# Epoch 6/30
# 797/797 [==============================] - 403s 500ms/step - loss: 0.0934 - accuracy: 0.9672 - val_loss: 0.6030 - val_accuracy: 0.7741 - lr: 3.0000e-04
# Epoch 7/30
# 797/797 [==============================] - 403s 501ms/step - loss: 0.0652 - accuracy: 0.9776 - val_loss: 0.1025 - val_accuracy: 0.9652 - lr: 3.0000e-04
# Epoch 8/30
# 797/797 [==============================] - 403s 500ms/step - loss: 0.0613 - accuracy: 0.9786 - val_loss: 0.0916 - val_accuracy: 0.9643 - lr: 3.0000e-04
# Epoch 9/30
# 797/797 [==============================] - 400s 498ms/step - loss: 0.0475 - accuracy: 0.9838 - val_loss: 0.7089 - val_accuracy: 0.8268 - lr: 3.0000e-04
# Epoch 10/30
# 797/797 [==============================] - 401s 498ms/step - loss: 0.0431 - accuracy: 0.9863 - val_loss: 2.7224 - val_accuracy: 0.6366 - lr: 3.0000e-04
# Epoch 11/30
# 797/797 [==============================] - 399s 495ms/step - loss: 0.0176 - accuracy: 0.9944 - val_loss: 0.0542 - val_accuracy: 0.9795 - lr: 1.5000e-04
# Epoch 12/30
# 797/797 [==============================] - 395s 491ms/step - loss: 0.0165 - accuracy: 0.9947 - val_loss: 0.2602 - val_accuracy: 0.9286 - lr: 1.5000e-04
# Epoch 13/30
# 797/797 [==============================] - 381s 473ms/step - loss: 0.0157 - accuracy: 0.9944 - val_loss: 0.1336 - val_accuracy: 0.9589 - lr: 1.5000e-04
# Epoch 14/30
# 797/797 [==============================] - 395s 491ms/step - loss: 0.0069 - accuracy: 0.9979 - val_loss: 0.0556 - val_accuracy: 0.9812 - lr: 7.5000e-05
# Epoch 15/30
# 797/797 [==============================] - 399s 496ms/step - loss: 0.0058 - accuracy: 0.9980 - val_loss: 0.0556 - val_accuracy: 0.9768 - lr: 7.5000e-05
# Epoch 16/30
# 797/797 [==============================] - 403s 501ms/step - loss: 0.0026 - accuracy: 0.9993 - val_loss: 0.1620 - val_accuracy: 0.9473 - lr: 3.7500e-05
# Epoch 17/30
# 797/797 [==============================] - 409s 507ms/step - loss: 0.0029 - accuracy: 0.9987 - val_loss: 0.0307 - val_accuracy: 0.9911 - lr: 3.7500e-05
# Epoch 18/30
# 797/797 [==============================] - 403s 501ms/step - loss: 0.0025 - accuracy: 0.9990 - val_loss: 0.0399 - val_accuracy: 0.9875 - lr: 3.7500e-05
# Epoch 19/30
# 797/797 [==============================] - 404s 501ms/step - loss: 0.0031 - accuracy: 0.9992 - val_loss: 0.0523 - val_accuracy: 0.9848 - lr: 3.7500e-05
# Epoch 20/30
# 797/797 [==============================] - 403s 501ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 0.0411 - val_accuracy: 0.9866 - lr: 1.8750e-05
# Epoch 21/30
# 797/797 [==============================] - 403s 501ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0478 - val_accuracy: 0.9857 - lr: 1.8750e-05
# Epoch 22/30
# 797/797 [==============================] - 404s 501ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.0376 - val_accuracy: 0.9893 - lr: 9.3750e-06
# 71/71 [==============================] - 8s 104ms/step - loss: 0.0564 - accuracy: 0.9796
# Test accuracy: 0.9796

# %%
# =========================================
# Common setup (TensorFlow / Keras)
# =========================================
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pathlib

# ---- Paths & data ----
DATA_DIR = "/home/jovyan/.cache/kagglehub/datasets/obulisainaren/multi-cancer/versions/3/Multi Cancer/Multi Cancer/Brain Cancer"
IMG_SIZE = (256, 256)   # keep same as second snippet
BATCH_SIZE = 8
SEED = 1337

data_dir = pathlib.Path(DATA_DIR)

# ===== Dataset split: train (70%), val (15%), test (15%) =====
train_ds = keras.utils.image_dataset_from_directory(
    data_dir, labels="inferred", label_mode="int",
    image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    validation_split=0.15, subset="training", seed=SEED, shuffle=True
)

valtest_ds = keras.utils.image_dataset_from_directory(
    data_dir, labels="inferred", label_mode="int",
    image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    validation_split=0.15, subset="validation", seed=SEED, shuffle=False
)

# Split val/test 50/50 from the validation subset
val_batches = int(0.5 * tf.data.experimental.cardinality(valtest_ds).numpy())
val_ds = valtest_ds.take(val_batches)
test_ds = valtest_ds.skip(val_batches)

class_names = train_ds.class_names
num_classes = len(class_names)
print("Classes:", class_names)

# ===== Prefetch for performance (same as second snippet) =====
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.shuffle(1000).prefetch(AUTOTUNE)
val_ds   = val_ds.prefetch(AUTOTUNE)
test_ds  = test_ds.prefetch(AUTOTUNE)

# ===== Data augmentation (same as second snippet) =====
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.05),
    layers.RandomZoom(0.1),
])

# ===== Normalization (same as second snippet) =====
# NOTE: We use simple Rescaling(1./255) for ALL models, including transfer learning.
# This matches the second snippet; it's fine for your experiments.
def normalize_block(x):
    return layers.Rescaling(1./255)(x)

# =========================================
# Classifier head (shared for TL models)
# =========================================
def classifier_head(x, num_classes, dropout=0.3):
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(dropout)(x)
    return layers.Dense(num_classes, activation="softmax")(x)

# =========================================
# 1) Baseline CNN (from scratch)
#   - keep architecture flexible, but preprocessing matches second snippet
# =========================================
def build_baseline_cnn(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)

    # Three conv blocks, two convs per block (as in your first snippet's baseline)
    for filters in [32, 64, 128]:
        x = layers.Conv2D(filters, 3, padding="same", activation="relu")(x)
        x = layers.Conv2D(filters, 3, padding="same", activation="relu")(x)
        x = layers.MaxPooling2D()(x)
        x = layers.Dropout(0.25)(x)

    x = layers.Flatten()(x)
    x = layers.Dense(256, activation="relu")(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)
    return keras.Model(inputs, outputs, name="baseline_cnn")

# =========================================
# 2) ResNet50 (prebuilt)
# =========================================
from tensorflow.keras.applications import ResNet50
def build_resnet50(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = ResNet50(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="resnet50")

# =========================================
# 3) VGG16 (prebuilt)
# =========================================
from tensorflow.keras.applications import VGG16
def build_vgg16(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = VGG16(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="vgg16")

# =========================================
# 4) InceptionV3 (prebuilt)
# =========================================
from tensorflow.keras.applications import InceptionV3
def build_inceptionv3(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = InceptionV3(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="inceptionv3")

# =========================================
# 5) EfficientNetB0 (prebuilt)
# =========================================
from tensorflow.keras.applications import EfficientNetB0
def build_efficientnetb0(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = EfficientNetB0(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="efficientnetb0")

# =========================================
# Pick a model to train (same interface)
# =========================================
MODEL_NAME = "cnn"   # one of: "cnn", "resnet", "vgg", "inception", "efficientnet"
WEIGHTS = "imagenet"          # "imagenet" or None
FINE_TUNE_BASE = False        # set True to unfreeze backbone later

input_shape = (*IMG_SIZE, 3)

if MODEL_NAME == "cnn":
    model = build_baseline_cnn(input_shape, num_classes)
elif MODEL_NAME == "resnet":
    model = build_resnet50(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
elif MODEL_NAME == "vgg":
    model = build_vgg16(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
elif MODEL_NAME == "inception":
    model = build_inceptionv3(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
elif MODEL_NAME == "efficientnet":
    model = build_efficientnetb0(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
else:
    raise ValueError("Unknown MODEL_NAME")

# =========================================
# Compile & Train
# =========================================
model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss=keras.losses.SparseCategoricalCrossentropy(),
    metrics=["accuracy"]
)

callbacks = [
    keras.callbacks.EarlyStopping(patience=4, restore_best_weights=True, monitor="val_accuracy"),
]

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=20,
    callbacks=callbacks
)

# ===== Evaluate on the held-out TEST set (matches second snippet practice) =====
test_loss, test_acc = model.evaluate(test_ds, verbose=0)
print(f"{model.name}  |  Test acc: {test_acc:.4f}  |  Test loss: {test_loss:.4f}")
# Out:
# 2025-09-21 01:21:04.077833: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-09-21 01:21:05.305185: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Found 15000 files belonging to 3 classes.
# Using 12750 files for training.
# 2025-09-21 01:21:08.286900: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22280 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:c2:00.0, compute capability: 8.6
# Found 15000 files belonging to 3 classes.
# Using 2250 files for validation.
# Classes: ['brain_glioma', 'brain_menin', 'brain_tumor']
# Epoch 1/20
# 2025-09-21 01:21:11.078592: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inbaseline_cnn/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2025-09-21 01:21:21.240543: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 304 of 1000
# 2025-09-21 01:21:31.262926: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 832 of 1000
# 2025-09-21 01:21:33.581804: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] Shuffle buffer filled.
# 2025-09-21 01:21:34.890373: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2025-09-21 01:21:35.344551: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2025-09-21 01:21:35.421158: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x55b480b57350 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-09-21 01:21:35.421245: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2025-09-21 01:21:35.456608: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-09-21 01:21:35.708326: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1594/1594 [==============================] - 61s 20ms/step - loss: 0.7411 - accuracy: 0.6601 - val_loss: 0.6376 - val_accuracy: 0.7376
# Epoch 2/20
# 1594/1594 [==============================] - 31s 18ms/step - loss: 0.5972 - accuracy: 0.7545 - val_loss: 0.3865 - val_accuracy: 0.8812
# Epoch 3/20
# 1594/1594 [==============================] - 31s 18ms/step - loss: 0.5053 - accuracy: 0.7997 - val_loss: 0.1972 - val_accuracy: 0.9371
# Epoch 4/20
# 1594/1594 [==============================] - 31s 18ms/step - loss: 0.4440 - accuracy: 0.8220 - val_loss: 0.3110 - val_accuracy: 0.8998
# Epoch 5/20
# 1594/1594 [==============================] - 31s 18ms/step - loss: 0.4062 - accuracy: 0.8428 - val_loss: 0.2845 - val_accuracy: 0.9087
# Epoch 6/20
# 1594/1594 [==============================] - 31s 18ms/step - loss: 0.3784 - accuracy: 0.8529 - val_loss: 0.2100 - val_accuracy: 0.9238
# Epoch 7/20
# 1594/1594 [==============================] - 31s 18ms/step - loss: 0.3526 - accuracy: 0.8631 - val_loss: 0.1963 - val_accuracy: 0.9291
# baseline_cnn  |  Test acc: 0.9287  |  Test loss: 0.2152

# %%
# =========================================
# Common setup (TensorFlow / Keras)
# =========================================
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pathlib

# ---- Paths & data ----
DATA_DIR = "/home/jovyan/.cache/kagglehub/datasets/obulisainaren/multi-cancer/versions/3/Multi Cancer/Multi Cancer/Brain Cancer"
IMG_SIZE = (256, 256)   # keep same as second snippet
BATCH_SIZE = 8
SEED = 1337

data_dir = pathlib.Path(DATA_DIR)

# ===== Dataset split: train (70%), val (15%), test (15%) =====
train_ds = keras.utils.image_dataset_from_directory(
    data_dir, labels="inferred", label_mode="int",
    image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    validation_split=0.15, subset="training", seed=SEED, shuffle=True
)

valtest_ds = keras.utils.image_dataset_from_directory(
    data_dir, labels="inferred", label_mode="int",
    image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    validation_split=0.15, subset="validation", seed=SEED, shuffle=False
)

# Split val/test 50/50 from the validation subset
val_batches = int(0.5 * tf.data.experimental.cardinality(valtest_ds).numpy())
val_ds = valtest_ds.take(val_batches)
test_ds = valtest_ds.skip(val_batches)

class_names = train_ds.class_names
num_classes = len(class_names)
print("Classes:", class_names)

# ===== Prefetch for performance (same as second snippet) =====
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.shuffle(1000).prefetch(AUTOTUNE)
val_ds   = val_ds.prefetch(AUTOTUNE)
test_ds  = test_ds.prefetch(AUTOTUNE)

# ===== Data augmentation (same as second snippet) =====
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.05),
    layers.RandomZoom(0.1),
])

# ===== Normalization (same as second snippet) =====
# NOTE: We use simple Rescaling(1./255) for ALL models, including transfer learning.
# This matches the second snippet; it's fine for your experiments.
def normalize_block(x):
    return layers.Rescaling(1./255)(x)

# =========================================
# Classifier head (shared for TL models)
# =========================================
def classifier_head(x, num_classes, dropout=0.3):
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(dropout)(x)
    return layers.Dense(num_classes, activation="softmax")(x)

# =========================================
# 1) Baseline CNN (from scratch)
#   - keep architecture flexible, but preprocessing matches second snippet
# =========================================
def build_baseline_cnn(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)

    # Three conv blocks, two convs per block (as in your first snippet's baseline)
    for filters in [32, 64, 128]:
        x = layers.Conv2D(filters, 3, padding="same", activation="relu")(x)
        x = layers.Conv2D(filters, 3, padding="same", activation="relu")(x)
        x = layers.MaxPooling2D()(x)
        x = layers.Dropout(0.25)(x)

    x = layers.Flatten()(x)
    x = layers.Dense(256, activation="relu")(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)
    return keras.Model(inputs, outputs, name="baseline_cnn")

# =========================================
# 2) ResNet50 (prebuilt)
# =========================================
from tensorflow.keras.applications import ResNet50
def build_resnet50(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = ResNet50(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="resnet50")

# =========================================
# 3) VGG16 (prebuilt)
# =========================================
from tensorflow.keras.applications import VGG16
def build_vgg16(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = VGG16(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="vgg16")

# =========================================
# 4) InceptionV3 (prebuilt)
# =========================================
from tensorflow.keras.applications import InceptionV3
def build_inceptionv3(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = InceptionV3(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="inceptionv3")

# =========================================
# 5) EfficientNetB0 (prebuilt)
# =========================================
from tensorflow.keras.applications import EfficientNetB0
def build_efficientnetb0(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = EfficientNetB0(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="efficientnetb0")

# =========================================
# Pick a model to train (same interface)
# =========================================
MODEL_NAME = "resnet"   # one of: "cnn", "resnet", "vgg", "inception", "efficientnet"
WEIGHTS = "imagenet"          # "imagenet" or None
FINE_TUNE_BASE = False        # set True to unfreeze backbone later

input_shape = (*IMG_SIZE, 3)

if MODEL_NAME == "cnn":
    model = build_baseline_cnn(input_shape, num_classes)
elif MODEL_NAME == "resnet":
    model = build_resnet50(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
elif MODEL_NAME == "vgg":
    model = build_vgg16(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
elif MODEL_NAME == "inception":
    model = build_inceptionv3(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
elif MODEL_NAME == "efficientnet":
    model = build_efficientnetb0(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
else:
    raise ValueError("Unknown MODEL_NAME")

# =========================================
# Compile & Train
# =========================================
model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss=keras.losses.SparseCategoricalCrossentropy(),
    metrics=["accuracy"]
)

callbacks = [
    keras.callbacks.EarlyStopping(patience=4, restore_best_weights=True, monitor="val_accuracy"),
]

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=20,
    callbacks=callbacks
)

# ===== Evaluate on the held-out TEST set (matches second snippet practice) =====
test_loss, test_acc = model.evaluate(test_ds, verbose=0)
print(f"{model.name}  |  Test acc: {test_acc:.4f}  |  Test loss: {test_loss:.4f}")
# Out:
# 2025-09-22 20:45:25.426763: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-09-22 20:45:26.712634: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Found 15000 files belonging to 3 classes.
# Using 12750 files for training.
# 2025-09-22 20:45:30.387759: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9556 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:44:00.0, compute capability: 7.5
# 2025-09-22 20:45:30.389297: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 9556 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:64:00.0, compute capability: 7.5
# Found 15000 files belonging to 3 classes.
# Using 2250 files for validation.
# Classes: ['brain_glioma', 'brain_menin', 'brain_tumor']
# Epoch 1/20
# 2025-09-22 20:45:51.738548: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 372 of 1000
# 2025-09-22 20:46:01.744685: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 884 of 1000
# 2025-09-22 20:46:04.167659: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] Shuffle buffer filled.
# 2025-09-22 20:46:04.884493: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2025-09-22 20:46:05.646195: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x74e364028240 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-09-22 20:46:05.646261: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2025-09-22 20:46:05.646277: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (1): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2025-09-22 20:46:05.654683: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-09-22 20:46:05.838750: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1594/1594 [==============================] - 69s 26ms/step - loss: 1.0296 - accuracy: 0.4666 - val_loss: 0.7699 - val_accuracy: 0.7447
# Epoch 2/20
# 1594/1594 [==============================] - 42s 24ms/step - loss: 0.9162 - accuracy: 0.5676 - val_loss: 0.9569 - val_accuracy: 0.4592
# Epoch 3/20
# 1594/1594 [==============================] - 41s 24ms/step - loss: 0.8841 - accuracy: 0.5910 - val_loss: 0.8749 - val_accuracy: 0.5488
# Epoch 4/20
# 1594/1594 [==============================] - 41s 24ms/step - loss: 0.8633 - accuracy: 0.6013 - val_loss: 0.9406 - val_accuracy: 0.5009
# Epoch 5/20
# 1594/1594 [==============================] - 43s 25ms/step - loss: 0.8501 - accuracy: 0.6112 - val_loss: 0.6381 - val_accuracy: 0.7562
# Epoch 6/20
# 1594/1594 [==============================] - 43s 25ms/step - loss: 0.8373 - accuracy: 0.6160 - val_loss: 0.6741 - val_accuracy: 0.6924
# Epoch 7/20
# 1594/1594 [==============================] - 41s 23ms/step - loss: 0.8333 - accuracy: 0.6232 - val_loss: 0.4282 - val_accuracy: 0.8963
# Epoch 8/20
# 1594/1594 [==============================] - 43s 25ms/step - loss: 0.8211 - accuracy: 0.6220 - val_loss: 0.3910 - val_accuracy: 0.9184
# Epoch 9/20
# 1594/1594 [==============================] - 42s 24ms/step - loss: 0.8124 - accuracy: 0.6343 - val_loss: 0.3274 - val_accuracy: 0.9433
# Epoch 10/20
# 1594/1594 [==============================] - 42s 25ms/step - loss: 0.8095 - accuracy: 0.6394 - val_loss: 0.5242 - val_accuracy: 0.7996
# Epoch 11/20
# 1594/1594 [==============================] - 43s 25ms/step - loss: 0.8017 - accuracy: 0.6424 - val_loss: 0.4065 - val_accuracy: 0.8839
# Epoch 12/20
# 1594/1594 [==============================] - 41s 24ms/step - loss: 0.7979 - accuracy: 0.6418 - val_loss: 0.4988 - val_accuracy: 0.8298
# Epoch 13/20
# 1594/1594 [==============================] - 42s 24ms/step - loss: 0.7933 - accuracy: 0.6476 - val_loss: 0.4061 - val_accuracy: 0.8936
# resnet50  |  Test acc: 0.9412  |  Test loss: 0.3261

# %%
# =========================================
# Common setup (TensorFlow / Keras)
# =========================================
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pathlib

# ---- Paths & data ----
DATA_DIR = "/home/jovyan/.cache/kagglehub/datasets/obulisainaren/multi-cancer/versions/3/Multi Cancer/Multi Cancer/Brain Cancer"
IMG_SIZE = (256, 256)   # keep same as second snippet
BATCH_SIZE = 8
SEED = 1337

data_dir = pathlib.Path(DATA_DIR)

# ===== Dataset split: train (70%), val (15%), test (15%) =====
train_ds = keras.utils.image_dataset_from_directory(
    data_dir, labels="inferred", label_mode="int",
    image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    validation_split=0.15, subset="training", seed=SEED, shuffle=True
)

valtest_ds = keras.utils.image_dataset_from_directory(
    data_dir, labels="inferred", label_mode="int",
    image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    validation_split=0.15, subset="validation", seed=SEED, shuffle=False
)

# Split val/test 50/50 from the validation subset
val_batches = int(0.5 * tf.data.experimental.cardinality(valtest_ds).numpy())
val_ds = valtest_ds.take(val_batches)
test_ds = valtest_ds.skip(val_batches)

class_names = train_ds.class_names
num_classes = len(class_names)
print("Classes:", class_names)

# ===== Prefetch for performance (same as second snippet) =====
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.shuffle(1000).prefetch(AUTOTUNE)
val_ds   = val_ds.prefetch(AUTOTUNE)
test_ds  = test_ds.prefetch(AUTOTUNE)

# ===== Data augmentation (same as second snippet) =====
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.05),
    layers.RandomZoom(0.1),
])

# ===== Normalization (same as second snippet) =====
# NOTE: We use simple Rescaling(1./255) for ALL models, including transfer learning.
# This matches the second snippet; it's fine for your experiments.
def normalize_block(x):
    return layers.Rescaling(1./255)(x)

# =========================================
# Classifier head (shared for TL models)
# =========================================
def classifier_head(x, num_classes, dropout=0.3):
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(dropout)(x)
    return layers.Dense(num_classes, activation="softmax")(x)

# =========================================
# 1) Baseline CNN (from scratch)
#   - keep architecture flexible, but preprocessing matches second snippet
# =========================================
def build_baseline_cnn(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)

    # Three conv blocks, two convs per block (as in your first snippet's baseline)
    for filters in [32, 64, 128]:
        x = layers.Conv2D(filters, 3, padding="same", activation="relu")(x)
        x = layers.Conv2D(filters, 3, padding="same", activation="relu")(x)
        x = layers.MaxPooling2D()(x)
        x = layers.Dropout(0.25)(x)

    x = layers.Flatten()(x)
    x = layers.Dense(256, activation="relu")(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)
    return keras.Model(inputs, outputs, name="baseline_cnn")

# =========================================
# 2) ResNet50 (prebuilt)
# =========================================
from tensorflow.keras.applications import ResNet50
def build_resnet50(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = ResNet50(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="resnet50")

# =========================================
# 3) VGG16 (prebuilt)
# =========================================
from tensorflow.keras.applications import VGG16
def build_vgg16(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = VGG16(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="vgg16")

# =========================================
# 4) InceptionV3 (prebuilt)
# =========================================
from tensorflow.keras.applications import InceptionV3
def build_inceptionv3(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = InceptionV3(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="inceptionv3")

# =========================================
# 5) EfficientNetB0 (prebuilt)
# =========================================
from tensorflow.keras.applications import EfficientNetB0
def build_efficientnetb0(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = EfficientNetB0(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="efficientnetb0")

# =========================================
# Pick a model to train (same interface)
# =========================================
MODEL_NAME = "vgg"   # one of: "cnn", "resnet", "vgg", "inception", "efficientnet"
WEIGHTS = "imagenet"          # "imagenet" or None
FINE_TUNE_BASE = False        # set True to unfreeze backbone later

input_shape = (*IMG_SIZE, 3)

if MODEL_NAME == "cnn":
    model = build_baseline_cnn(input_shape, num_classes)
elif MODEL_NAME == "resnet":
    model = build_resnet50(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
elif MODEL_NAME == "vgg":
    model = build_vgg16(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
elif MODEL_NAME == "inception":
    model = build_inceptionv3(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
elif MODEL_NAME == "efficientnet":
    model = build_efficientnetb0(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
else:
    raise ValueError("Unknown MODEL_NAME")

# =========================================
# Compile & Train
# =========================================
model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss=keras.losses.SparseCategoricalCrossentropy(),
    metrics=["accuracy"]
)

callbacks = [
    keras.callbacks.EarlyStopping(patience=4, restore_best_weights=True, monitor="val_accuracy"),
]

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=20,
    callbacks=callbacks
)

# ===== Evaluate on the held-out TEST set (matches second snippet practice) =====
test_loss, test_acc = model.evaluate(test_ds, verbose=0)
print(f"{model.name}  |  Test acc: {test_acc:.4f}  |  Test loss: {test_loss:.4f}")
# Out:
# 2025-09-24 20:03:36.264309: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-09-24 20:03:36.309229: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-09-24 20:03:37.088056: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Found 15000 files belonging to 3 classes.
# Using 12750 files for training.
# 2025-09-24 20:03:40.455124: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9559 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:61:00.0, compute capability: 7.5
# 2025-09-24 20:03:40.456712: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 9559 MB memory:  -> device: 1, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:b1:00.0, compute capability: 7.5
# 2025-09-24 20:03:40.458079: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 9559 MB memory:  -> device: 2, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:da:00.0, compute capability: 7.5
# Found 15000 files belonging to 3 classes.
# Using 2250 files for validation.
# Classes: ['brain_glioma', 'brain_menin', 'brain_tumor']
# Epoch 1/20
# 2025-09-24 20:03:55.499628: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:422] Filling up shuffle buffer (this may take a while): 521 of 1000
# 2025-09-24 20:04:03.147395: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] Shuffle buffer filled.
# 2025-09-24 20:04:03.610945: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2025-09-24 20:04:04.543287: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f03b7af8290 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-09-24 20:04:04.543320: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2025-09-24 20:04:04.543327: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (1): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2025-09-24 20:04:04.543332: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (2): NVIDIA GeForce RTX 2080 Ti, Compute Capability 7.5
# 2025-09-24 20:04:04.548252: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-09-24 20:04:04.659407: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1594/1594 [==============================] - 63s 27ms/step - loss: 0.6939 - accuracy: 0.7256 - val_loss: 0.3590 - val_accuracy: 0.9468
# Epoch 2/20
# 1594/1594 [==============================] - 43s 26ms/step - loss: 0.4936 - accuracy: 0.8207 - val_loss: 0.2977 - val_accuracy: 0.9441
# Epoch 3/20
# 1594/1594 [==============================] - 44s 27ms/step - loss: 0.4445 - accuracy: 0.8333 - val_loss: 0.2330 - val_accuracy: 0.9548
# Epoch 4/20
# 1594/1594 [==============================] - 44s 26ms/step - loss: 0.4168 - accuracy: 0.8435 - val_loss: 0.1755 - val_accuracy: 0.9654
# Epoch 5/20
# 1594/1594 [==============================] - 44s 27ms/step - loss: 0.4024 - accuracy: 0.8475 - val_loss: 0.2455 - val_accuracy: 0.9433
# Epoch 6/20
# 1594/1594 [==============================] - 44s 27ms/step - loss: 0.3875 - accuracy: 0.8525 - val_loss: 0.1530 - val_accuracy: 0.9716
# Epoch 7/20
# 1594/1594 [==============================] - 44s 26ms/step - loss: 0.3858 - accuracy: 0.8517 - val_loss: 0.1744 - val_accuracy: 0.9610
# Epoch 8/20
# 1594/1594 [==============================] - 44s 27ms/step - loss: 0.3769 - accuracy: 0.8555 - val_loss: 0.1330 - val_accuracy: 0.9734
# Epoch 9/20
# 1594/1594 [==============================] - 45s 27ms/step - loss: 0.3656 - accuracy: 0.8600 - val_loss: 0.1337 - val_accuracy: 0.9716
# Epoch 10/20
# 1594/1594 [==============================] - 45s 27ms/step - loss: 0.3689 - accuracy: 0.8587 - val_loss: 0.0998 - val_accuracy: 0.9796
# Epoch 11/20
# 1594/1594 [==============================] - 46s 28ms/step - loss: 0.3633 - accuracy: 0.8577 - val_loss: 0.1272 - val_accuracy: 0.9761
# Epoch 12/20
# 1594/1594 [==============================] - 45s 27ms/step - loss: 0.3654 - accuracy: 0.8620 - val_loss: 0.1202 - val_accuracy: 0.9752
# Epoch 13/20
# 1594/1594 [==============================] - 46s 28ms/step - loss: 0.3502 - accuracy: 0.8659 - val_loss: 0.1122 - val_accuracy: 0.9770
# Epoch 14/20
# 1594/1594 [==============================] - 44s 27ms/step - loss: 0.3525 - accuracy: 0.8597 - val_loss: 0.1674 - val_accuracy: 0.9583
# vgg16  |  Test acc: 0.9831  |  Test loss: 0.0994

# %%
# =========================================
# Common setup (TensorFlow / Keras)
# =========================================
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pathlib

# ---- Paths & data ----
DATA_DIR = "/home/jovyan/.cache/kagglehub/datasets/obulisainaren/multi-cancer/versions/3/Multi Cancer/Multi Cancer/Brain Cancer"
IMG_SIZE = (256, 256)   # keep same as second snippet
BATCH_SIZE = 8
SEED = 1337

data_dir = pathlib.Path(DATA_DIR)

# ===== Dataset split: train (70%), val (15%), test (15%) =====
train_ds = keras.utils.image_dataset_from_directory(
    data_dir, labels="inferred", label_mode="int",
    image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    validation_split=0.15, subset="training", seed=SEED, shuffle=True
)

valtest_ds = keras.utils.image_dataset_from_directory(
    data_dir, labels="inferred", label_mode="int",
    image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    validation_split=0.15, subset="validation", seed=SEED, shuffle=False
)

# Split val/test 50/50 from the validation subset
val_batches = int(0.5 * tf.data.experimental.cardinality(valtest_ds).numpy())
val_ds = valtest_ds.take(val_batches)
test_ds = valtest_ds.skip(val_batches)

class_names = train_ds.class_names
num_classes = len(class_names)
print("Classes:", class_names)

# ===== Prefetch for performance (same as second snippet) =====
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.shuffle(1000).prefetch(AUTOTUNE)
val_ds   = val_ds.prefetch(AUTOTUNE)
test_ds  = test_ds.prefetch(AUTOTUNE)

# ===== Data augmentation (same as second snippet) =====
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.05),
    layers.RandomZoom(0.1),
])

# ===== Normalization (same as second snippet) =====
# NOTE: We use simple Rescaling(1./255) for ALL models, including transfer learning.
# This matches the second snippet; it's fine for your experiments.
def normalize_block(x):
    return layers.Rescaling(1./255)(x)

# =========================================
# Classifier head (shared for TL models)
# =========================================
def classifier_head(x, num_classes, dropout=0.3):
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(dropout)(x)
    return layers.Dense(num_classes, activation="softmax")(x)

# =========================================
# 1) Baseline CNN (from scratch)
#   - keep architecture flexible, but preprocessing matches second snippet
# =========================================
def build_baseline_cnn(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)

    # Three conv blocks, two convs per block (as in your first snippet's baseline)
    for filters in [32, 64, 128]:
        x = layers.Conv2D(filters, 3, padding="same", activation="relu")(x)
        x = layers.Conv2D(filters, 3, padding="same", activation="relu")(x)
        x = layers.MaxPooling2D()(x)
        x = layers.Dropout(0.25)(x)

    x = layers.Flatten()(x)
    x = layers.Dense(256, activation="relu")(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)
    return keras.Model(inputs, outputs, name="baseline_cnn")

# =========================================
# 2) ResNet50 (prebuilt)
# =========================================
from tensorflow.keras.applications import ResNet50
def build_resnet50(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = ResNet50(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="resnet50")

# =========================================
# 3) VGG16 (prebuilt)
# =========================================
from tensorflow.keras.applications import VGG16
def build_vgg16(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = VGG16(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="vgg16")

# =========================================
# 4) InceptionV3 (prebuilt)
# =========================================
from tensorflow.keras.applications import InceptionV3
def build_inceptionv3(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = InceptionV3(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="inceptionv3")

# =========================================
# 5) EfficientNetB0 (prebuilt)
# =========================================
from tensorflow.keras.applications import EfficientNetB0
def build_efficientnetb0(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = EfficientNetB0(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="efficientnetb0")

# =========================================
# Pick a model to train (same interface)
# =========================================
MODEL_NAME = "inception"   # one of: "cnn", "resnet", "vgg", "inception", "efficientnet"
WEIGHTS = "imagenet"          # "imagenet" or None
FINE_TUNE_BASE = False        # set True to unfreeze backbone later

input_shape = (*IMG_SIZE, 3)

if MODEL_NAME == "cnn":
    model = build_baseline_cnn(input_shape, num_classes)
elif MODEL_NAME == "resnet":
    model = build_resnet50(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
elif MODEL_NAME == "vgg":
    model = build_vgg16(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
elif MODEL_NAME == "inception":
    model = build_inceptionv3(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
elif MODEL_NAME == "efficientnet":
    model = build_efficientnetb0(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
else:
    raise ValueError("Unknown MODEL_NAME")

# =========================================
# Compile & Train
# =========================================
model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss=keras.losses.SparseCategoricalCrossentropy(),
    metrics=["accuracy"]
)

callbacks = [
    keras.callbacks.EarlyStopping(patience=4, restore_best_weights=True, monitor="val_accuracy"),
]

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=20,
    callbacks=callbacks
)

# ===== Evaluate on the held-out TEST set (matches second snippet practice) =====
test_loss, test_acc = model.evaluate(test_ds, verbose=0)
print(f"{model.name}  |  Test acc: {test_acc:.4f}  |  Test loss: {test_loss:.4f}")
# Out:
# Found 15000 files belonging to 3 classes.
# Using 12750 files for training.
# Found 15000 files belonging to 3 classes.
# Using 2250 files for validation.
# Classes: ['brain_glioma', 'brain_menin', 'brain_tumor']
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 [==============================] - 1s 0us/step
# Epoch 1/20
# 1594/1594 [==============================] - 38s 20ms/step - loss: 0.4117 - accuracy: 0.8351 - val_loss: 0.0551 - val_accuracy: 0.9858
# Epoch 2/20
# 1594/1594 [==============================] - 31s 19ms/step - loss: 0.3159 - accuracy: 0.8799 - val_loss: 0.0359 - val_accuracy: 0.9920
# Epoch 3/20
# 1594/1594 [==============================] - 31s 18ms/step - loss: 0.2839 - accuracy: 0.8902 - val_loss: 0.0094 - val_accuracy: 1.0000
# Epoch 4/20
# 1594/1594 [==============================] - 31s 19ms/step - loss: 0.2839 - accuracy: 0.8940 - val_loss: 0.0292 - val_accuracy: 0.9920
# Epoch 5/20
# 1594/1594 [==============================] - 31s 18ms/step - loss: 0.2814 - accuracy: 0.8948 - val_loss: 0.1265 - val_accuracy: 0.9574
# Epoch 6/20
# 1594/1594 [==============================] - 32s 19ms/step - loss: 0.2834 - accuracy: 0.8927 - val_loss: 0.0397 - val_accuracy: 0.9902
# Epoch 7/20
# 1594/1594 [==============================] - 31s 19ms/step - loss: 0.2801 - accuracy: 0.8967 - val_loss: 0.0202 - val_accuracy: 0.9938
# inceptionv3  |  Test acc: 0.9964  |  Test loss: 0.0146

# %%
# =========================================
# Common setup (TensorFlow / Keras)
# =========================================
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import pathlib

# ---- Paths & data ----
DATA_DIR = "/home/jovyan/.cache/kagglehub/datasets/obulisainaren/multi-cancer/versions/3/Multi Cancer/Multi Cancer/Brain Cancer"
IMG_SIZE = (256, 256)   # keep same as second snippet
BATCH_SIZE = 8
SEED = 1337

data_dir = pathlib.Path(DATA_DIR)

# ===== Dataset split: train (70%), val (15%), test (15%) =====
train_ds = keras.utils.image_dataset_from_directory(
    data_dir, labels="inferred", label_mode="int",
    image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    validation_split=0.15, subset="training", seed=SEED, shuffle=True
)

valtest_ds = keras.utils.image_dataset_from_directory(
    data_dir, labels="inferred", label_mode="int",
    image_size=IMG_SIZE, batch_size=BATCH_SIZE,
    validation_split=0.15, subset="validation", seed=SEED, shuffle=False
)

# Split val/test 50/50 from the validation subset
val_batches = int(0.5 * tf.data.experimental.cardinality(valtest_ds).numpy())
val_ds = valtest_ds.take(val_batches)
test_ds = valtest_ds.skip(val_batches)

class_names = train_ds.class_names
num_classes = len(class_names)
print("Classes:", class_names)

# ===== Prefetch for performance (same as second snippet) =====
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.shuffle(1000).prefetch(AUTOTUNE)
val_ds   = val_ds.prefetch(AUTOTUNE)
test_ds  = test_ds.prefetch(AUTOTUNE)

# ===== Data augmentation (same as second snippet) =====
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.05),
    layers.RandomZoom(0.1),
])

# ===== Normalization (same as second snippet) =====
# NOTE: We use simple Rescaling(1./255) for ALL models, including transfer learning.
# This matches the second snippet; it's fine for your experiments.
def normalize_block(x):
    return layers.Rescaling(1./255)(x)

# =========================================
# Classifier head (shared for TL models)
# =========================================
def classifier_head(x, num_classes, dropout=0.3):
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(dropout)(x)
    return layers.Dense(num_classes, activation="softmax")(x)

# =========================================
# 1) Baseline CNN (from scratch)
#   - keep architecture flexible, but preprocessing matches second snippet
# =========================================
def build_baseline_cnn(input_shape, num_classes):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)

    # Three conv blocks, two convs per block (as in your first snippet's baseline)
    for filters in [32, 64, 128]:
        x = layers.Conv2D(filters, 3, padding="same", activation="relu")(x)
        x = layers.Conv2D(filters, 3, padding="same", activation="relu")(x)
        x = layers.MaxPooling2D()(x)
        x = layers.Dropout(0.25)(x)

    x = layers.Flatten()(x)
    x = layers.Dense(256, activation="relu")(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(num_classes, activation="softmax")(x)
    return keras.Model(inputs, outputs, name="baseline_cnn")

# =========================================
# 2) ResNet50 (prebuilt)
# =========================================
from tensorflow.keras.applications import ResNet50
def build_resnet50(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = ResNet50(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="resnet50")

# =========================================
# 3) VGG16 (prebuilt)
# =========================================
from tensorflow.keras.applications import VGG16
def build_vgg16(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = VGG16(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="vgg16")

# =========================================
# 4) InceptionV3 (prebuilt)
# =========================================
from tensorflow.keras.applications import InceptionV3
def build_inceptionv3(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = InceptionV3(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="inceptionv3")

# =========================================
# 5) EfficientNetB0 (prebuilt)
# =========================================
from tensorflow.keras.applications import EfficientNetB0
def build_efficientnetb0(input_shape, num_classes, weights="imagenet", train_base=False):
    inputs = keras.Input(shape=input_shape)
    x = data_augmentation(inputs)
    x = normalize_block(x)
    base = EfficientNetB0(include_top=False, weights=weights, input_tensor=x)
    base.trainable = train_base
    outputs = classifier_head(base.output, num_classes, dropout=0.3)
    return keras.Model(inputs, outputs, name="efficientnetb0")

# =========================================
# Pick a model to train (same interface)
# =========================================
MODEL_NAME = "efficientnet"   # one of: "cnn", "resnet", "vgg", "inception", "efficientnet"
WEIGHTS = "imagenet"          # "imagenet" or None
FINE_TUNE_BASE = False        # set True to unfreeze backbone later

input_shape = (*IMG_SIZE, 3)

if MODEL_NAME == "cnn":
    model = build_baseline_cnn(input_shape, num_classes)
elif MODEL_NAME == "resnet":
    model = build_resnet50(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
elif MODEL_NAME == "vgg":
    model = build_vgg16(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
elif MODEL_NAME == "inception":
    model = build_inceptionv3(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
elif MODEL_NAME == "efficientnet":
    model = build_efficientnetb0(input_shape, num_classes, weights=WEIGHTS, train_base=FINE_TUNE_BASE)
else:
    raise ValueError("Unknown MODEL_NAME")

# =========================================
# Compile & Train
# =========================================
model.compile(
    optimizer=keras.optimizers.Adam(1e-3),
    loss=keras.losses.SparseCategoricalCrossentropy(),
    metrics=["accuracy"]
)

callbacks = [
    keras.callbacks.EarlyStopping(patience=4, restore_best_weights=True, monitor="val_accuracy"),
]

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=20,
    callbacks=callbacks
)

# ===== Evaluate on the held-out TEST set (matches second snippet practice) =====
test_loss, test_acc = model.evaluate(test_ds, verbose=0)
print(f"{model.name}  |  Test acc: {test_acc:.4f}  |  Test loss: {test_loss:.4f}")
# Out:
# Found 15000 files belonging to 3 classes.
# Using 12750 files for training.
# Found 15000 files belonging to 3 classes.
# Using 2250 files for validation.
# Classes: ['brain_glioma', 'brain_menin', 'brain_tumor']
# Epoch 1/20
# 2025-09-24 20:50:33.687417: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inefficientnetb0/block2b_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 1594/1594 [==============================] - 35s 18ms/step - loss: 1.1296 - accuracy: 0.3316 - val_loss: 1.3225 - val_accuracy: 0.0000e+00
# Epoch 2/20
# 1594/1594 [==============================] - 27s 16ms/step - loss: 1.1259 - accuracy: 0.3317 - val_loss: 1.1238 - val_accuracy: 0.0000e+00
# Epoch 3/20
# 1594/1594 [==============================] - 27s 16ms/step - loss: 1.1270 - accuracy: 0.3369 - val_loss: 0.8188 - val_accuracy: 1.0000
# Epoch 4/20
# 1594/1594 [==============================] - 28s 17ms/step - loss: 1.1223 - accuracy: 0.3432 - val_loss: 1.2434 - val_accuracy: 0.0000e+00
# Epoch 5/20
# 1594/1594 [==============================] - 27s 16ms/step - loss: 1.1267 - accuracy: 0.3354 - val_loss: 1.0062 - val_accuracy: 1.0000
# Epoch 6/20
# 1594/1594 [==============================] - 27s 16ms/step - loss: 1.1260 - accuracy: 0.3344 - val_loss: 1.3159 - val_accuracy: 0.0000e+00
# Epoch 7/20
# 1594/1594 [==============================] - 27s 16ms/step - loss: 1.1225 - accuracy: 0.3382 - val_loss: 1.2182 - val_accuracy: 0.0000e+00
# efficientnetb0  |  Test acc: 1.0000  |  Test loss: 0.8189
